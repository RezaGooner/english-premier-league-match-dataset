# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_clubs = pd.read_csv("clubs.csv")
df_clubs
# Out:
#                    0
# 0           West Ham
# 1        Southampton
# 2   Sheffield United
# 3             Oldham
# 4          Newcastle
# 5            Arsenal
# 6          Liverpool
# 7            Chelsea
# 8        Aston Villa
# 9           Man City
# 10           Norwich
# 11         Tottenham
# 12           Ipswich
# 13             Leeds
# 14         Wimbledon
# 15           Everton
# 16         Blackburn
# 17          Coventry
# 18        Man United
# 19               QPR
# 20    Sheffield Weds
# 21           Swindon
# 22    Crystal Palace
# 23         Leicester
# 24     Nott'm Forest
# 25            Bolton
# 26     Middlesbrough
# 27        Sunderland
# 28             Derby
# 29          Barnsley
# 30          Charlton
# 31           Watford
# 32          Bradford
# 33            Fulham
# 34         West Brom
# 35        Birmingham
# 36        Portsmouth
# 37            Wolves
# 38             Wigan
# 39           Reading
# 40              Hull
# 41             Stoke
# ...

# %%
df1 = pd.read_csv("ExtraData/EPL Standings 2000-2022.csv")
df1.head()
# Out:
#     Season  Pos               Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 0  2000-01    1  Manchester United   38  24   8   6  79  31  48   80
# 1  2000-01    2            Arsenal   38  20  10   8  63  38  25   70
# 2  2000-01    3          Liverpool   38  20   9   9  71  39  32   69
# 3  2000-01    4       Leeds United   38  20   8  10  64  43  21   68
# 4  2000-01    5       Ipswich Town   38  20   6  12  57  42  15   66
#
#                          Qualification or relegation
# 0  Qualification for the Champions League first g...
# 1  Qualification for the Champions League first g...
# 2  Qualification for the Champions League third q...
# 3      Qualification for the UEFA Cup first round[a]
# 4      Qualification for the UEFA Cup first round[a]

# %%
df1.shape
# Out:
# (440, 12)

# %%
df1[['year1', 'year2']] = df1['Season'].str.split('-', expand=True)
df1['Season'] = df1['year1'].str[-2:] + df1['year2']
df1 = df1.drop(columns=['year1', 'year2'])
df1.head()
# Out:
#   Season  Pos               Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 0   0001    1  Manchester United   38  24   8   6  79  31  48   80
# 1   0001    2            Arsenal   38  20  10   8  63  38  25   70
# 2   0001    3          Liverpool   38  20   9   9  71  39  32   69
# 3   0001    4       Leeds United   38  20   8  10  64  43  21   68
# 4   0001    5       Ipswich Town   38  20   6  12  57  42  15   66
#
#                          Qualification or relegation
# 0  Qualification for the Champions League first g...
# 1  Qualification for the Champions League first g...
# 2  Qualification for the Champions League third q...
# 3      Qualification for the UEFA Cup first round[a]
# 4      Qualification for the UEFA Cup first round[a]

# %%
df1[ 'Qualification or relegation' ].unique()
# Out:
# array(['Qualification for the Champions League first group stage',
#        'Qualification for the Champions League third qualifying round[a]',
#        'Qualification for the UEFA Cup first round[a]', 'Not Applicable',
#        'Qualification for the Intertoto Cup third round',
#        'Relegation to the Football League First Division',
#        'Qualification for the Champions League third qualifying round',
#        'Qualification for the UEFA Cup first round[b]',
#        'Qualification for the UEFA Cup first round[c]',
#        'Qualification for the Intertoto Cup second round',
#        'Qualification for the UEFA Cup qualifying round[a]Relegation to the Football League First Division',
#        'Qualification for the Champions League group stage',
#        'Qualification for the UEFA Cup qualifying round[c]',
#        'Relegation to Football League First Division',
#        'Qualification for the UEFA Cup first round',
# ...

# %%
df1['Season'] = df1['Season'].astype(str)

# %%
records_9900 = [
    {'Season': '9900', 'Pos': 1, 'Team': 'Man United', 'Pld': 38, 'W': 28, 'D': 7, 'L': 3, 'GF': 97, 'GA': 45, 'GD': 52, 'Pts': 91, 'Qualification or relegation': 'Qualification for the Champions League first group stage'},
    {'Season': '9900', 'Pos': 2, 'Team': 'Arsenal', 'Pld': 38, 'W': 22, 'D': 7, 'L': 9, 'GF': 73, 'GA': 43, 'GD': 30, 'Pts': 73, 'Qualification or relegation': 'Qualification for the Champions League first group stage'},
    {'Season': '9900', 'Pos': 3, 'Team': 'Liverpool', 'Pld': 38, 'W': 21, 'D': 6, 'L': 11, 'GF': 58, 'GA': 43, 'GD': 15, 'Pts': 69, 'Qualification or relegation': 'Qualification for the Champions League third qualifying round'},
    {'Season': '9900', 'Pos': 4, 'Team': 'Chelsea', 'Pld': 38, 'W': 19, 'D': 10, 'L': 9, 'GF': 51, 'GA': 30, 'GD': 21, 'Pts': 67, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9900', 'Pos': 5, 'Team': 'Leeds', 'Pld': 38, 'W': 18, 'D': 11, 'L': 9, 'GF': 53, 'GA': 34, 'GD': 19, 'Pts': 65, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9900', 'Pos': 6, 'Team': 'Aston Villa', 'Pld': 38, 'W': 15, 'D': 13, 'L': 10, 'GF': 46, 'GA': 35, 'GD': 11, 'Pts': 58, 'Qualification or relegation': 'Qualification for the Intertoto Cup third round'},
    {'Season': '9900', 'Pos': 7, 'Team': 'West Ham', 'Pld': 38, 'W': 16, 'D': 10, 'L': 12, 'GF': 57, 'GA': 56, 'GD': 1, 'Pts': 58, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9900', 'Pos': 8, 'Team': 'Sunderland', 'Pld': 38, 'W': 16, 'D': 7, 'L': 15, 'GF': 55, 'GA': 55, 'GD': 0, 'Pts': 55, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9900', 'Pos': 9, 'Team': 'Leicester', 'Pld': 38, 'W': 15, 'D': 10, 'L': 13, 'GF': 52, 'GA': 53, 'GD': -1, 'Pts': 55, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9900', 'Pos': 10, 'Team': 'Tottenham', 'Pld': 38, 'W': 15, 'D': 8, 'L': 15, 'GF': 57, 'GA': 49, 'GD': 8, 'Pts': 53, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9900', 'Pos': 11, 'Team': 'Newcastle', 'Pld': 38, 'W': 14, 'D': 10, 'L': 14, 'GF': 63, 'GA': 54, 'GD': 9, 'Pts': 52, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9900', 'Pos': 12, 'Team': 'Middlesbrough', 'Pld': 38, 'W': 14, 'D': 10, 'L': 14, 'GF': 46, 'GA': 52, 'GD': -6, 'Pts': 52, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9900', 'Pos': 13, 'Team': 'Everton', 'Pld': 38, 'W': 12, 'D': 14, 'L': 12, 'GF': 59, 'GA': 49, 'GD': 10, 'Pts': 50, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9900', 'Pos': 14, 'Team': 'Coventry', 'Pld': 38, 'W': 12, 'D': 8, 'L': 18, 'GF': 47, 'GA': 54, 'GD': -7, 'Pts': 44, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9900', 'Pos': 15, 'Team': 'Southampton', 'Pld': 38, 'W': 12, 'D': 8, 'L': 18, 'GF': 45, 'GA': 62, 'GD': -17, 'Pts': 44, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9900', 'Pos': 16, 'Team': 'Derby', 'Pld': 38, 'W': 9, 'D': 11, 'L': 18, 'GF': 44, 'GA': 57, 'GD': -13, 'Pts': 38, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9900', 'Pos': 17, 'Team': 'Bradford', 'Pld': 38, 'W': 9, 'D': 9, 'L': 20, 'GF': 38, 'GA': 68, 'GD': -30, 'Pts': 36, 'Qualification or relegation': 'Qualification for the Intertoto Cup third round'},
    {'Season': '9900', 'Pos': 18, 'Team': 'Wimbledon', 'Pld': 38, 'W': 7, 'D': 12, 'L': 19, 'GF': 46, 'GA': 74, 'GD': -28, 'Pts': 33, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9900', 'Pos': 19, 'Team': 'Sheffield Weds', 'Pld': 38, 'W': 8, 'D': 7, 'L': 23, 'GF': 38, 'GA': 70, 'GD': -32, 'Pts': 31, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9900', 'Pos': 20, 'Team': 'Watford', 'Pld': 38, 'W': 6, 'D': 6, 'L': 26, 'GF': 35, 'GA': 77, 'GD': -42, 'Pts': 24, 'Qualification or relegation': 'Relegation to the Football League First Division'},
]
df1 = pd.concat([df1, pd.DataFrame(records_9900)], ignore_index=True)
df1.head()
# Out:
#   Season  Pos               Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 0   0001    1  Manchester United   38  24   8   6  79  31  48   80
# 1   0001    2            Arsenal   38  20  10   8  63  38  25   70
# 2   0001    3          Liverpool   38  20   9   9  71  39  32   69
# 3   0001    4       Leeds United   38  20   8  10  64  43  21   68
# 4   0001    5       Ipswich Town   38  20   6  12  57  42  15   66
#
#                          Qualification or relegation
# 0  Qualification for the Champions League first g...
# 1  Qualification for the Champions League first g...
# 2  Qualification for the Champions League third q...
# 3      Qualification for the UEFA Cup first round[a]
# 4      Qualification for the UEFA Cup first round[a]

# %%
df1.tail()
# Out:
#     Season  Pos            Team  Pld  W   D   L  GF  GA  GD  Pts  \
# 455   9900   16           Derby   38  9  11  18  44  57 -13   38
# 456   9900   17        Bradford   38  9   9  20  38  68 -30   36
# 457   9900   18       Wimbledon   38  7  12  19  46  74 -28   33
# 458   9900   19  Sheffield Weds   38  8   7  23  38  70 -32   31
# 459   9900   20         Watford   38  6   6  26  35  77 -42   24
#
#                           Qualification or relegation
# 455                                    Not Applicable
# 456   Qualification for the Intertoto Cup third round
# 457  Relegation to the Football League First Division
# 458  Relegation to the Football League First Division
# 459  Relegation to the Football League First Division

# %%
records_9899 = [
    {'Season': '9899', 'Pos': 1, 'Team': 'Man United', 'Pld': 38, 'W': 22, 'D': 13, 'L': 3, 'GF': 80, 'GA': 37, 'GD': 43, 'Pts': 79, 'Qualification or relegation': 'Qualification for the Champions League first group stage'},
    {'Season': '9899', 'Pos': 2, 'Team': 'Arsenal', 'Pld': 38, 'W': 22, 'D': 12, 'L': 4, 'GF': 59, 'GA': 17, 'GD': 42, 'Pts': 78, 'Qualification or relegation': 'Qualification for the Champions League first group stage'},
    {'Season': '9899', 'Pos': 3, 'Team': 'Chelsea', 'Pld': 38, 'W': 20, 'D': 15, 'L': 3, 'GF': 57, 'GA': 30, 'GD': 27, 'Pts': 75, 'Qualification or relegation': 'Qualification for the Champions League third qualifying round'}, 
    {'Season': '9899', 'Pos': 4, 'Team': 'Leeds', 'Pld': 38, 'W': 18, 'D': 13, 'L': 7, 'GF': 62, 'GA': 34, 'GD': 28, 'Pts': 67, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},  #
    {'Season': '9899', 'Pos': 5, 'Team': 'Aston Villa', 'Pld': 38, 'W': 16, 'D': 9, 'L': 13, 'GF': 46, 'GA': 53, 'GD': -7, 'Pts': 57, 'Qualification or relegation': 'Qualification for the Intertoto Cup third round'},
    {'Season': '9899', 'Pos': 6, 'Team': 'West Ham', 'Pld': 38, 'W': 15, 'D': 10, 'L': 13, 'GF': 51, 'GA': 46, 'GD': 5, 'Pts': 55, 'Qualification or relegation': 'Not Applicable'}, 
    {'Season': '9899', 'Pos': 7, 'Team': 'Liverpool', 'Pld': 38, 'W': 15, 'D': 9, 'L': 14, 'GF': 68, 'GA': 49, 'GD': 19, 'Pts': 54, 'Qualification or relegation': 'Not Applicable'}, 
    {'Season': '9899', 'Pos': 8, 'Team': 'Derby', 'Pld': 38, 'W': 13, 'D': 13, 'L': 12, 'GF': 40, 'GA': 45, 'GD': -5, 'Pts': 52, 'Qualification or relegation': 'Not Applicable'}, 
    {'Season': '9899', 'Pos': 9, 'Team': 'Middlesbrough', 'Pld': 38, 'W': 12, 'D': 15, 'L': 11, 'GF': 48, 'GA': 54, 'GD': -6, 'Pts': 51, 'Qualification or relegation': 'Not Applicable'}, 
    {'Season': '9899', 'Pos': 10, 'Team': 'Leicester', 'Pld': 38, 'W': 12, 'D': 13, 'L': 13, 'GF': 40, 'GA': 46, 'GD': -6, 'Pts': 49, 'Qualification or relegation': 'Not Applicable'}, 
    {'Season': '9899', 'Pos': 11, 'Team': 'Tottenham', 'Pld': 38, 'W': 11, 'D': 14, 'L': 13, 'GF': 47, 'GA': 50, 'GD': -3, 'Pts': 47, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9899', 'Pos': 12, 'Team': 'Newcastle', 'Pld': 38, 'W': 13, 'D': 7, 'L': 18, 'GF': 41, 'GA': 42, 'GD': -1, 'Pts': 46, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9899', 'Pos': 13, 'Team': 'Sheffield Weds', 'Pld': 38, 'W': 11, 'D': 13, 'L': 14, 'GF': 48, 'GA': 54, 'GD': -6, 'Pts': 46, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'}, 
    {'Season': '9899', 'Pos': 14, 'Team': 'Everton', 'Pld': 38, 'W': 11, 'D': 10, 'L': 17, 'GF': 42, 'GA': 47, 'GD': -5, 'Pts': 43, 'Qualification or relegation': 'Not Applicable'}, 
    {'Season': '9899', 'Pos': 15, 'Team': 'Coventry', 'Pld': 38, 'W': 11, 'D': 9, 'L': 18, 'GF': 39, 'GA': 51, 'GD': -12, 'Pts': 42, 'Qualification or relegation': 'Not Applicable'}, 
    {'Season': '9899', 'Pos': 16, 'Team': 'Wimbledon', 'Pld': 38, 'W': 10, 'D': 12, 'L': 16, 'GF': 40, 'GA': 63, 'GD': -23, 'Pts': 42, 'Qualification or relegation': 'Not Applicable'},  
    {'Season': '9899', 'Pos': 17, 'Team': 'Southampton', 'Pld': 38, 'W': 11, 'D': 8, 'L': 19, 'GF': 37, 'GA': 64, 'GD': -27, 'Pts': 41, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9899', 'Pos': 18, 'Team': 'Charlton', 'Pld': 38, 'W': 8, 'D': 12, 'L': 18, 'GF': 41, 'GA': 56, 'GD': -15, 'Pts': 36, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9899', 'Pos': 19, 'Team': 'Blackburn', 'Pld': 38, 'W': 7, 'D': 14, 'L': 17, 'GF': 38, 'GA': 52, 'GD': -14, 'Pts': 35, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9899', 'Pos': 20, 'Team': 'Nottm Forest', 'Pld': 38, 'W': 7, 'D': 9, 'L': 22, 'GF': 35, 'GA': 69, 'GD': -34, 'Pts': 30, 'Qualification or relegation': 'Relegation to the Football League First Division'},
]
df1 = pd.concat([df1, pd.DataFrame(records_9899)], ignore_index=True)

# %%
records_9798 = [
    {'Season': '9798', 'Pos': 1, 'Team': 'Arsenal', 'Pld': 38, 'W': 23, 'D': 9, 'L': 6, 'GF': 68, 'GA': 33, 'GD': 35, 'Pts': 78, 'Qualification or relegation': 'Qualification for the Champions League group stage'},
    {'Season': '9798', 'Pos': 2, 'Team': 'Man United', 'Pld': 38, 'W': 23, 'D': 8, 'L': 7, 'GF': 73, 'GA': 26, 'GD': 47, 'Pts': 77, 'Qualification or relegation': 'Qualification for the Champions League second qualifying round'},
    {'Season': '9798', 'Pos': 3, 'Team': 'Liverpool', 'Pld': 38, 'W': 18, 'D': 11, 'L': 9, 'GF': 68, 'GA': 42, 'GD': 26, 'Pts': 65, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9798', 'Pos': 4, 'Team': 'Chelsea', 'Pld': 38, 'W': 20, 'D': 3, 'L': 15, 'GF': 71, 'GA': 43, 'GD': 28, 'Pts': 63, 'Qualification or relegation': 'Qualification for the UEFA Cup Winners\' Cup'},
    {'Season': '9798', 'Pos': 5, 'Team': 'West Ham', 'Pld': 38, 'W': 17, 'D': 8, 'L': 13, 'GF': 57, 'GA': 46, 'GD': 11, 'Pts': 59, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9798', 'Pos': 6, 'Team': 'Leeds', 'Pld': 38, 'W': 16, 'D': 10, 'L': 12, 'GF': 57, 'GA': 52, 'GD': 5, 'Pts': 58, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9798', 'Pos': 7, 'Team': 'Blackburn', 'Pld': 38, 'W': 17, 'D': 6, 'L': 15, 'GF': 49, 'GA': 48, 'GD': 1, 'Pts': 57, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9798', 'Pos': 8, 'Team': 'Aston Villa', 'Pld': 38, 'W': 16, 'D': 8, 'L': 14, 'GF': 56, 'GA': 57, 'GD': -1, 'Pts': 56, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9798', 'Pos': 9, 'Team': 'Derby', 'Pld': 38, 'W': 16, 'D': 7, 'L': 15, 'GF': 52, 'GA': 49, 'GD': 3, 'Pts': 55, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9798', 'Pos': 10, 'Team': 'Leicester', 'Pld': 38, 'W': 13, 'D': 14, 'L': 11, 'GF': 51, 'GA': 41, 'GD': 10, 'Pts': 53, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9798', 'Pos': 11, 'Team': 'Coventry', 'Pld': 38, 'W': 12, 'D': 16, 'L': 10, 'GF': 46, 'GA': 44, 'GD': 2, 'Pts': 52, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9798', 'Pos': 12, 'Team': 'Southampton', 'Pld': 38, 'W': 14, 'D': 6, 'L': 18, 'GF': 50, 'GA': 55, 'GD': -5, 'Pts': 48, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9798', 'Pos': 13, 'Team': 'Tottenham', 'Pld': 38, 'W': 11, 'D': 11, 'L': 16, 'GF': 35, 'GA': 44, 'GD': -9, 'Pts': 44, 'Qualification or relegation': 'Qualification for the UEFA Cup Winners\' Cup'},
    {'Season': '9798', 'Pos': 14, 'Team': 'Newcastle', 'Pld': 38, 'W': 11, 'D': 11, 'L': 16, 'GF': 44, 'GA': 56, 'GD': -12, 'Pts': 44, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9798', 'Pos': 15, 'Team': 'Wimbledon', 'Pld': 38, 'W': 10, 'D': 14, 'L': 14, 'GF': 34, 'GA': 46, 'GD': -12, 'Pts': 44, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9798', 'Pos': 16, 'Team': 'Sheffield W', 'Pld': 38, 'W': 12, 'D': 8, 'L': 18, 'GF': 52, 'GA': 67, 'GD': -15, 'Pts': 44, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9798', 'Pos': 17, 'Team': 'Everton', 'Pld': 38, 'W': 9, 'D': 13, 'L': 16, 'GF': 41, 'GA': 56, 'GD': -15, 'Pts': 40, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9798', 'Pos': 18, 'Team': 'Bolton', 'Pld': 38, 'W': 9, 'D': 13, 'L': 16, 'GF': 41, 'GA': 61, 'GD': -20, 'Pts': 40, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9798', 'Pos': 19, 'Team': 'Barnsley', 'Pld': 38, 'W': 10, 'D': 5, 'L': 23, 'GF': 37, 'GA': 82, 'GD': -45, 'Pts': 35, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9798', 'Pos': 20, 'Team': 'Crystal Palace', 'Pld': 38, 'W': 8, 'D': 9, 'L': 21, 'GF': 37, 'GA': 71, 'GD': -34, 'Pts': 33, 'Qualification or relegation': 'Qualification for the Intertoto Cup third round'},
]
df1 = pd.concat([df1, pd.DataFrame(records_9798)], ignore_index=True)

# %%
records_9697 = [
    {'Season': '9697', 'Pos': 1, 'Team': 'Man United', 'Pld': 38, 'W': 21, 'D': 12, 'L': 5, 'GF': 76, 'GA': 44, 'GD': 32, 'Pts': 75, 'Qualification or relegation': 'Qualification for the Champions League group stage'},
    {'Season': '9697', 'Pos': 2, 'Team': 'Newcastle', 'Pld': 38, 'W': 19, 'D': 11, 'L': 8, 'GF': 73, 'GA': 40, 'GD': 33, 'Pts': 68, 'Qualification or relegation': 'Qualification for the Champions League second qualifying round'},
    {'Season': '9697', 'Pos': 3, 'Team': 'Arsenal', 'Pld': 38, 'W': 19, 'D': 11, 'L': 8, 'GF': 62, 'GA': 32, 'GD': 30, 'Pts': 68, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9697', 'Pos': 4, 'Team': 'Liverpool', 'Pld': 38, 'W': 18, 'D': 11, 'L': 9, 'GF': 62, 'GA': 37, 'GD': 25, 'Pts': 65, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9697', 'Pos': 5, 'Team': 'Aston Villa', 'Pld': 38, 'W': 17, 'D': 10, 'L': 11, 'GF': 47, 'GA': 34, 'GD': 13, 'Pts': 61, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9697', 'Pos': 6, 'Team': 'Chelsea', 'Pld': 38, 'W': 16, 'D': 11, 'L': 11, 'GF': 58, 'GA': 55, 'GD': 3, 'Pts': 59, 'Qualification or relegation': 'Qualification for the UEFA Cup Winners\' Cup'},
    {'Season': '9697', 'Pos': 7, 'Team': 'Sheffield W', 'Pld': 38, 'W': 14, 'D': 15, 'L': 9, 'GF': 50, 'GA': 51, 'GD': -1, 'Pts': 57, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 8, 'Team': 'Wimbledon', 'Pld': 38, 'W': 15, 'D': 11, 'L': 12, 'GF': 49, 'GA': 46, 'GD': 3, 'Pts': 56, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 9, 'Team': 'Leicester', 'Pld': 38, 'W': 12, 'D': 11, 'L': 15, 'GF': 46, 'GA': 54, 'GD': -8, 'Pts': 47, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 10, 'Team': 'Tottenham', 'Pld': 38, 'W': 13, 'D': 7, 'L': 18, 'GF': 44, 'GA': 51, 'GD': -7, 'Pts': 46, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 11, 'Team': 'Leeds', 'Pld': 38, 'W': 11, 'D': 13, 'L': 14, 'GF': 28, 'GA': 38, 'GD': -10, 'Pts': 46, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 12, 'Team': 'Derby', 'Pld': 38, 'W': 11, 'D': 13, 'L': 14, 'GF': 45, 'GA': 58, 'GD': -13, 'Pts': 46, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 13, 'Team': 'West Ham', 'Pld': 38, 'W': 9, 'D': 15, 'L': 14, 'GF': 42, 'GA': 43, 'GD': -1, 'Pts': 42, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 14, 'Team': 'Blackburn', 'Pld': 38, 'W': 10, 'D': 12, 'L': 16, 'GF': 39, 'GA': 48, 'GD': -9, 'Pts': 42, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 15, 'Team': 'Everton', 'Pld': 38, 'W': 10, 'D': 12, 'L': 16, 'GF': 44, 'GA': 57, 'GD': -13, 'Pts': 42, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 16, 'Team': 'Southampton', 'Pld': 38, 'W': 10, 'D': 11, 'L': 17, 'GF': 50, 'GA': 56, 'GD': -6, 'Pts': 41, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 17, 'Team': 'Coventry', 'Pld': 38, 'W': 9, 'D': 14, 'L': 15, 'GF': 38, 'GA': 54, 'GD': -16, 'Pts': 41, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9697', 'Pos': 18, 'Team': 'Sunderland', 'Pld': 38, 'W': 10, 'D': 10, 'L': 18, 'GF': 35, 'GA': 53, 'GD': -18, 'Pts': 40, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9697', 'Pos': 19, 'Team': 'Middlesbrough', 'Pld': 38, 'W': 10, 'D': 12, 'L': 16, 'GF': 51, 'GA': 60, 'GD': -9, 'Pts': 39, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9697', 'Pos': 20, 'Team': 'Nottm Forest', 'Pld': 38, 'W': 6, 'D': 16, 'L': 16, 'GF': 31, 'GA': 59, 'GD': -28, 'Pts': 34, 'Qualification or relegation': 'Relegation to the Football League First Division'},
]
df1 = pd.concat([df1, pd.DataFrame(records_9697)], ignore_index=True)

# %%
records_9596 = [
    {'Season': '9596', 'Pos': 1, 'Team': 'Man United', 'Pld': 38, 'W': 25, 'D': 7, 'L': 6, 'GF': 73, 'GA': 35, 'GD': 38, 'Pts': 82, 'Qualification or relegation': 'Qualification for the Champions League group stage'},
    {'Season': '9596', 'Pos': 2, 'Team': 'Newcastle', 'Pld': 38, 'W': 20, 'D': 11, 'L': 7, 'GF': 49, 'GA': 32, 'GD': 17, 'Pts': 71, 'Qualification or relegation': 'Qualification for the Champions League second qualifying round'},
    {'Season': '9596', 'Pos': 3, 'Team': 'Liverpool', 'Pld': 38, 'W': 19, 'D': 11, 'L': 8, 'GF': 66, 'GA': 41, 'GD': 25, 'Pts': 68, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9596', 'Pos': 4, 'Team': 'Arsenal', 'Pld': 38, 'W': 18, 'D': 11, 'L': 9, 'GF': 70, 'GA': 34, 'GD': 36, 'Pts': 65, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9596', 'Pos': 5, 'Team': 'Blackburn', 'Pld': 38, 'W': 18, 'D': 7, 'L': 13, 'GF': 52, 'GA': 39, 'GD': 13, 'Pts': 61, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9596', 'Pos': 6, 'Team': 'Aston Villa', 'Pld': 38, 'W': 16, 'D': 9, 'L': 13, 'GF': 58, 'GA': 55, 'GD': 3, 'Pts': 57, 'Qualification or relegation': 'Qualification for the UEFA Cup Winners\' Cup'},
    {'Season': '9596', 'Pos': 7, 'Team': 'Everton', 'Pld': 38, 'W': 15, 'D': 10, 'L': 13, 'GF': 61, 'GA': 47, 'GD': 14, 'Pts': 55, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 8, 'Team': 'Tottenham', 'Pld': 38, 'W': 16, 'D': 6, 'L': 16, 'GF': 50, 'GA': 54, 'GD': -4, 'Pts': 54, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 9, 'Team': 'Nottm Forest', 'Pld': 38, 'W': 15, 'D': 5, 'L': 18, 'GF': 50, 'GA': 61, 'GD': -11, 'Pts': 50, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 10, 'Team': 'West Ham', 'Pld': 38, 'W': 13, 'D': 10, 'L': 15, 'GF': 48, 'GA': 51, 'GD': -3, 'Pts': 49, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 11, 'Team': 'Chelsea', 'Pld': 38, 'W': 13, 'D': 9, 'L': 16, 'GF': 44, 'GA': 51, 'GD': -7, 'Pts': 48, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 12, 'Team': 'Middlesbrough', 'Pld': 38, 'W': 11, 'D': 13, 'L': 14, 'GF': 42, 'GA': 53, 'GD': -11, 'Pts': 46, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 13, 'Team': 'Leeds', 'Pld': 38, 'W': 11, 'D': 13, 'L': 14, 'GF': 46, 'GA': 51, 'GD': -5, 'Pts': 46, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 14, 'Team': 'Wimbledon', 'Pld': 38, 'W': 11, 'D': 12, 'L': 15, 'GF': 37, 'GA': 48, 'GD': -11, 'Pts': 45, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 15, 'Team': 'Sheffield Weds', 'Pld': 38, 'W': 10, 'D': 14, 'L': 14, 'GF': 34, 'GA': 44, 'GD': -10, 'Pts': 44, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 16, 'Team': 'Coventry', 'Pld': 38, 'W': 11, 'D': 10, 'L': 17, 'GF': 44, 'GA': 55, 'GD': -11, 'Pts': 43, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 17, 'Team': 'Southampton', 'Pld': 38, 'W': 9, 'D': 11, 'L': 18, 'GF': 33, 'GA': 58, 'GD': -25, 'Pts': 38, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9596', 'Pos': 18, 'Team': 'Man City', 'Pld': 38, 'W': 10, 'D': 8, 'L': 20, 'GF': 41, 'GA': 63, 'GD': -22, 'Pts': 38, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9596', 'Pos': 19, 'Team': 'QPR', 'Pld': 38, 'W': 8, 'D': 13, 'L': 17, 'GF': 39, 'GA': 66, 'GD': -27, 'Pts': 37, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9596', 'Pos': 20, 'Team': 'Bolton', 'Pld': 38, 'W': 7, 'D': 12, 'L': 19, 'GF': 36, 'GA': 60, 'GD': -24, 'Pts': 33, 'Qualification or relegation': 'Relegation to the Football League First Division'},
]
df1 = pd.concat([df1, pd.DataFrame(records_9596)], ignore_index=True)

# %%
records_9495 = [
    {'Season': '9495', 'Pos': 1, 'Team': 'Man United', 'Pld': 42, 'W': 27, 'D': 8, 'L': 7, 'GF': 80, 'GA': 39, 'GD': 41, 'Pts': 89, 'Qualification or relegation': 'Qualification for the Champions League group stage'},
    {'Season': '9495', 'Pos': 2, 'Team': 'Blackburn', 'Pld': 42, 'W': 26, 'D': 10, 'L': 6, 'GF': 77, 'GA': 28, 'GD': 49, 'Pts': 88, 'Qualification or relegation': 'Qualification for the Champions League group stage'},
    {'Season': '9495', 'Pos': 3, 'Team': 'Nottm Forest', 'Pld': 42, 'W': 22, 'D': 11, 'L': 9, 'GF': 72, 'GA': 43, 'GD': 29, 'Pts': 77, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9495', 'Pos': 4, 'Team': 'Liverpool', 'Pld': 42, 'W': 21, 'D': 11, 'L': 10, 'GF': 65, 'GA': 37, 'GD': 28, 'Pts': 74, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9495', 'Pos': 5, 'Team': 'Leeds', 'Pld': 42, 'W': 20, 'D': 13, 'L': 9, 'GF': 59, 'GA': 38, 'GD': 21, 'Pts': 73, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9495', 'Pos': 6, 'Team': 'Newcastle', 'Pld': 42, 'W': 20, 'D': 12, 'L': 10, 'GF': 67, 'GA': 47, 'GD': 20, 'Pts': 72, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 7, 'Team': 'Tottenham', 'Pld': 42, 'W': 20, 'D': 10, 'L': 12, 'GF': 65, 'GA': 50, 'GD': 15, 'Pts': 70, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 8, 'Team': 'QPR', 'Pld': 42, 'W': 19, 'D': 12, 'L': 11, 'GF': 56, 'GA': 46, 'GD': 10, 'Pts': 69, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 9, 'Team': 'Wimbledon', 'Pld': 42, 'W': 18, 'D': 13, 'L': 11, 'GF': 55, 'GA': 44, 'GD': 11, 'Pts': 67, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 10, 'Team': 'Southampton', 'Pld': 42, 'W': 18, 'D': 13, 'L': 11, 'GF': 54, 'GA': 46, 'GD': 8, 'Pts': 67, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 11, 'Team': 'Chelsea', 'Pld': 42, 'W': 17, 'D': 14, 'L': 11, 'GF': 60, 'GA': 41, 'GD': 19, 'Pts': 65, 'Qualification or relegation': 'Qualification for the UEFA Cup Winners\' Cup'},
    {'Season': '9495', 'Pos': 12, 'Team': 'Arsenal', 'Pld': 42, 'W': 16, 'D': 16, 'L': 10, 'GF': 63, 'GA': 52, 'GD': 11, 'Pts': 64, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 13, 'Team': 'Sheffield Weds', 'Pld': 42, 'W': 17, 'D': 8, 'L': 17, 'GF': 54, 'GA': 55, 'GD': -1, 'Pts': 59, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 14, 'Team': 'West Ham', 'Pld': 42, 'W': 15, 'D': 11, 'L': 16, 'GF': 56, 'GA': 55, 'GD': 1, 'Pts': 56, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 15, 'Team': 'Everton', 'Pld': 42, 'W': 14, 'D': 12, 'L': 16, 'GF': 53, 'GA': 56, 'GD': -3, 'Pts': 54, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 16, 'Team': 'Coventry', 'Pld': 42, 'W': 13, 'D': 15, 'L': 14, 'GF': 52, 'GA': 49, 'GD': 3, 'Pts': 54, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 17, 'Team': 'Man City', 'Pld': 42, 'W': 15, 'D': 8, 'L': 19, 'GF': 56, 'GA': 64, 'GD': -8, 'Pts': 53, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 18, 'Team': 'Aston Villa', 'Pld': 42, 'W': 12, 'D': 16, 'L': 14, 'GF': 46, 'GA': 54, 'GD': -8, 'Pts': 52, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 19, 'Team': 'Crystal Palace', 'Pld': 42, 'W': 11, 'D': 18, 'L': 13, 'GF': 49, 'GA': 57, 'GD': -8, 'Pts': 51, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9495', 'Pos': 20, 'Team': 'Norwich', 'Pld': 42, 'W': 11, 'D': 17, 'L': 14, 'GF': 42, 'GA': 50, 'GD': -8, 'Pts': 50, 'Qualification or relegation': 'Relegation to the Football League First Division'},
]
df1 = pd.concat([df1, pd.DataFrame(records_9495)], ignore_index=True)

# %%
records_9394 = [
    {'Season': '9394', 'Pos': 1, 'Team': 'Man United', 'Pld': 42, 'W': 27, 'D': 8, 'L': 7, 'GF': 80, 'GA': 38, 'GD': 42, 'Pts': 92, 'Qualification or relegation': 'Qualification for the Champions League group stage'},
    {'Season': '9394', 'Pos': 2, 'Team': 'Blackburn', 'Pld': 42, 'W': 25, 'D': 9, 'L': 8, 'GF': 63, 'GA': 36, 'GD': 27, 'Pts': 84, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9394', 'Pos': 3, 'Team': 'Newcastle', 'Pld': 42, 'W': 23, 'D': 8, 'L': 11, 'GF': 82, 'GA': 41, 'GD': 41, 'Pts': 77, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9394', 'Pos': 4, 'Team': 'Arsenal', 'Pld': 42, 'W': 18, 'D': 17, 'L': 7, 'GF': 53, 'GA': 28, 'GD': 25, 'Pts': 71, 'Qualification or relegation': 'Qualification for the UEFA Cup Winners\' Cup'},
    {'Season': '9394', 'Pos': 5, 'Team': 'Leeds', 'Pld': 42, 'W': 18, 'D': 16, 'L': 8, 'GF': 65, 'GA': 39, 'GD': 26, 'Pts': 70, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9394', 'Pos': 6, 'Team': 'Wimbledon', 'Pld': 42, 'W': 18, 'D': 16, 'L': 8, 'GF': 56, 'GA': 53, 'GD': 3, 'Pts': 70, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 7, 'Team': 'Sheffield Weds', 'Pld': 42, 'W': 16, 'D': 19, 'L': 7, 'GF': 53, 'GA': 47, 'GD': 6, 'Pts': 67, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 8, 'Team': 'Liverpool', 'Pld': 42, 'W': 17, 'D': 15, 'L': 10, 'GF': 59, 'GA': 47, 'GD': 12, 'Pts': 66, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 9, 'Team': 'QPR', 'Pld': 42, 'W': 16, 'D': 16, 'L': 10, 'GF': 62, 'GA': 52, 'GD': 10, 'Pts': 64, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 10, 'Team': 'Aston Villa', 'Pld': 42, 'W': 15, 'D': 18, 'L': 9, 'GF': 46, 'GA': 43, 'GD': 3, 'Pts': 63, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 11, 'Team': 'Coventry', 'Pld': 42, 'W': 16, 'D': 14, 'L': 12, 'GF': 55, 'GA': 51, 'GD': 4, 'Pts': 62, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 12, 'Team': 'Norwich', 'Pld': 42, 'W': 12, 'D': 22, 'L': 8, 'GF': 47, 'GA': 42, 'GD': 5, 'Pts': 58, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 13, 'Team': 'West Ham', 'Pld': 42, 'W': 13, 'D': 17, 'L': 12, 'GF': 47, 'GA': 48, 'GD': -1, 'Pts': 56, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 14, 'Team': 'Chelsea', 'Pld': 42, 'W': 13, 'D': 15, 'L': 14, 'GF': 49, 'GA': 52, 'GD': -3, 'Pts': 54, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 15, 'Team': 'Tottenham', 'Pld': 42, 'W': 11, 'D': 18, 'L': 13, 'GF': 54, 'GA': 53, 'GD': 1, 'Pts': 51, 'Qualification or relegation': 'Qualification for the UEFA Cup first round'},
    {'Season': '9394', 'Pos': 16, 'Team': 'Man City', 'Pld': 42, 'W': 9, 'D': 23, 'L': 10, 'GF': 38, 'GA': 43, 'GD': -5, 'Pts': 50, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 17, 'Team': 'Everton', 'Pld': 42, 'W': 12, 'D': 13, 'L': 17, 'GF': 41, 'GA': 43, 'GD': -2, 'Pts': 49, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 18, 'Team': 'Southampton', 'Pld': 42, 'W': 12, 'D': 12, 'L': 18, 'GF': 49, 'GA': 57, 'GD': -8, 'Pts': 48, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 19, 'Team': 'Ipswich', 'Pld': 42, 'W': 9, 'D': 18, 'L': 15, 'GF': 35, 'GA': 48, 'GD': -13, 'Pts': 45, 'Qualification or relegation': 'Not Applicable'},
    {'Season': '9394', 'Pos': 20, 'Team': 'Sheffield', 'Pld': 42, 'W': 13, 'D': 5, 'L': 24, 'GF': 43, 'GA': 60, 'GD': -17, 'Pts': 44, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9394', 'Pos': 21, 'Team': 'Oldham', 'Pld': 42, 'W': 9, 'D': 16, 'L': 17, 'GF': 42, 'GA': 56, 'GD': -14, 'Pts': 43, 'Qualification or relegation': 'Relegation to the Football League First Division'},
    {'Season': '9394', 'Pos': 22, 'Team': 'Swindon', 'Pld': 42, 'W': 7, 'D': 9, 'L': 26, 'GF': 38, 'GA': 83, 'GD': -45, 'Pts': 30, 'Qualification or relegation': 'Relegation to the Football League First Division'},
]
df1 = pd.concat([df1, pd.DataFrame(records_9394)], ignore_index=True)

# %%
df1[ 'Team' ].unique()
# Out:
# array(['Manchester United', 'Arsenal', 'Liverpool', 'Leeds United',
#        'Ipswich Town', 'Chelsea', 'Sunderland', 'Aston Villa',
#        'Charlton Athletic', 'Southampton', 'Newcastle United',
#        'Tottenham Hotspur', 'Leicester City', 'Middlesbrough',
#        'West Ham United', 'Everton', 'Derby County', 'Manchester City',
#        'Coventry City', 'Bradford City', 'Blackburn Rovers', 'Fulham',
#        'Bolton Wanderers', 'Birmingham City', 'West Bromwich Albion',
#        'Portsmouth', 'Wolverhampton Wanderers', 'Crystal Palace',
#        'Norwich City', 'Wigan Athletic', 'Reading', 'Sheffield United',
#        'Watford', 'Stoke City', 'Hull City', 'Burnley', 'Blackpool',
#        'Swansea City', 'Queens Park Rangers', 'Cardiff City',
#        'Bournemouth', 'Brighton & Hove Albion', 'Huddersfield Town',
#        'Brentford', 'Man United', 'Leeds', 'West Ham', 'Leicester',
#        'Tottenham', 'Newcastle', 'Coventry', 'Derby', 'Bradford',
# ...

# %%
df1[ 'Team' ].nunique()
# Out:
# 68

# %%
df_tmp = pd.concat([
    pd.DataFrame(df1['Team'].unique(), columns=['Team'])
        .sort_values(by='Team', ascending=True)
        .reset_index(drop=True),
    
    df_clubs
        .sort_values(by='0', ascending=True)
        .reset_index(drop=True)
], axis=1)
df_tmp
# Out:
#                        Team                 0
# 0                   Arsenal           Arsenal
# 1               Aston Villa       Aston Villa
# 2                  Barnsley          Barnsley
# 3           Birmingham City        Birmingham
# 4                 Blackburn         Blackburn
# 5          Blackburn Rovers         Blackpool
# 6                 Blackpool            Bolton
# 7                    Bolton       Bournemouth
# 8          Bolton Wanderers          Bradford
# 9               Bournemouth         Brentford
# 10                 Bradford          Brighton
# 11            Bradford City           Burnley
# 12                Brentford           Cardiff
# 13   Brighton & Hove Albion          Charlton
# 14                  Burnley           Chelsea
# 15             Cardiff City          Coventry
# 16                 Charlton    Crystal Palace
# 17        Charlton Athletic             Derby
# 18                  Chelsea           Everton
# ...

# %%
team_mapping = {
    'Blackburn Rovers': 'Blackburn',
    'Bradford City': 'Bradford',
    'Brighton & Hove Albion': 'Brighton',
    'Cardiff City': 'Cardiff',
    'Charlton Athletic': 'Charlton',
    'Coventry City': 'Coventry',
    'Derby County': 'Derby',
    'Huddersfield Town': 'Huddersfield',
    'Hull City': 'Hull',
    'Ipswich Town': 'Ipswich',
    'Leeds United': 'Leeds',
    'Leicester City': 'Leicester',
    'Manchester City': 'Man City',
    'Manchester United': 'Man United',
    'Newcastle United': 'Newcastle',
    'Norwich City': 'Norwich',
    'Nottm Forest': 'Nottingham',
    "Nott'm Forest": 'Nottingham',
    'Queens Park Rangers': 'QPR',
    'Sheffield United': 'Sheffield',
    'Sheffield W': 'Sheffield Weds',
    'Stoke City': 'Stoke',
    'Swansea City': 'Swansea',
    'Tottenham Hotspur': 'Tottenham',
    'West Bromwich Albion': 'West Brom',
    'West Ham United': 'West Ham',
    'Wigan Athletic': 'Wigan',
    'Wolverhampton Wanderers': 'Wolves'
}

# %%
df1['Team'] = df1['Team'].replace(team_mapping)

# %%
df1[ 'Team' ].unique()
# Out:
# array(['Man United', 'Arsenal', 'Liverpool', 'Leeds', 'Ipswich',
#        'Chelsea', 'Sunderland', 'Aston Villa', 'Charlton', 'Southampton',
#        'Newcastle', 'Tottenham', 'Leicester', 'Middlesbrough', 'West Ham',
#        'Everton', 'Derby', 'Man City', 'Coventry', 'Bradford',
#        'Blackburn', 'Fulham', 'Bolton Wanderers', 'Birmingham City',
#        'West Brom', 'Portsmouth', 'Wolves', 'Crystal Palace', 'Norwich',
#        'Wigan', 'Reading', 'Sheffield', 'Watford', 'Stoke', 'Hull',
#        'Burnley', 'Blackpool', 'Swansea', 'QPR', 'Cardiff', 'Bournemouth',
#        'Brighton', 'Huddersfield', 'Brentford', 'Wimbledon',
#        'Sheffield Weds', 'Nottingham', 'Bolton', 'Barnsley', 'Oldham',
#        'Swindon'], dtype=object)

# %%
df1.head()
# Out:
#   Season  Pos        Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 0   0001    1  Man United   38  24   8   6  79  31  48   80
# 1   0001    2     Arsenal   38  20  10   8  63  38  25   70
# 2   0001    3   Liverpool   38  20   9   9  71  39  32   69
# 3   0001    4       Leeds   38  20   8  10  64  43  21   68
# 4   0001    5     Ipswich   38  20   6  12  57  42  15   66
#
#                          Qualification or relegation
# 0  Qualification for the Champions League first g...
# 1  Qualification for the Champions League first g...
# 2  Qualification for the Champions League third q...
# 3      Qualification for the UEFA Cup first round[a]
# 4      Qualification for the UEFA Cup first round[a]

# %% [markdown]
# ---

# %%
df = pd.read_csv("Data/Data1.csv")
df.head()
# Out:
#    Year  Month  Day          HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  1993      8   14          West Ham  Wimbledon     0     2   A   NaN   NaN
# 1  1993      8   14       Southampton    Everton     0     2   A   NaN   NaN
# 2  1993      8   14  Sheffield United    Swindon     3     1   H   NaN   NaN
# 3  1993      8   14            Oldham    Ipswich     0     3   A   NaN   NaN
# 4  1993      8   14         Newcastle  Tottenham     0     1   A   NaN   NaN
#
#    HTR Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  Season
# 0  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN    9394
# 1  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN    9394
# 2  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN    9394
# 3  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN    9394
# 4  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN    9394

# %%
df['HomeTeam'] = df['HomeTeam'].replace(team_mapping)
df['AwayTeam'] = df['AwayTeam'].replace(team_mapping)

# %%
df1['Season'][:10]
# Out:
# 0    0001
# 1    0001
# 2    0001
# 3    0001
# 4    0001
# 5    0001
# 6    0001
# 7    0001
# 8    0001
# 9    0001
# Name: Season, dtype: object

# %%
df1['Season'][450:460]
# Out:
# 450    9900
# 451    9900
# 452    9900
# 453    9900
# 454    9900
# 455    9900
# 456    9900
# 457    9900
# 458    9900
# 459    9900
# Name: Season, dtype: object

# %%
df['Season'][3000:3010]
# Out:
# 3000    1
# 3001    1
# 3002    1
# 3003    1
# 3004    1
# 3005    1
# 3006    1
# 3007    1
# 3008    1
# 3009    1
# Name: Season, dtype: int64

# %%
df1['Season'].dtype, df['Season'].dtype
# Out:
# (dtype('O'), dtype('int64'))

# %%
df1['Season'] = df1['Season'].astype(str)
df['Season'] = df['Season'].astype(str)

# %%
df1['Season'].dtype, df['Season'].dtype
# Out:
# (dtype('O'), dtype('O'))

# %%
df.loc[df['Season'] == '1', 'Season'] = '0001'
df.loc[df['Season'] == '102', 'Season'] = '0102'
df.loc[df['Season'] == '203', 'Season'] = '0203'
df.loc[df['Season'] == '304', 'Season'] = '0304'
df.loc[df['Season'] == '405', 'Season'] = '0405'
df.loc[df['Season'] == '506', 'Season'] = '0506'
df.loc[df['Season'] == '607', 'Season'] = '0607'
df.loc[df['Season'] == '708', 'Season'] = '0708'
df.loc[df['Season'] == '809', 'Season'] = '0809'
df.loc[df['Season'] == '910', 'Season'] = '0910'

df1.loc[df1['Season'] == '1', 'Season'] = '0001'
df1.loc[df1['Season'] == '102', 'Season'] = '0102'
df1.loc[df1['Season'] == '203', 'Season'] = '0203'
df1.loc[df1['Season'] == '304', 'Season'] = '0304'
df1.loc[df1['Season'] == '405', 'Season'] = '0405'
df1.loc[df1['Season'] == '506', 'Season'] = '0506'
df1.loc[df1['Season'] == '607', 'Season'] = '0607'
df1.loc[df1['Season'] == '708', 'Season'] = '0708'
df1.loc[df1['Season'] == '809', 'Season'] = '0809'
df1.loc[df1['Season'] == '910', 'Season'] = '0910'

# %%
df['Season'][3000:3010]
# Out:
# 3000    0001
# 3001    0001
# 3002    0001
# 3003    0001
# 3004    0001
# 3005    0001
# 3006    0001
# 3007    0001
# 3008    0001
# 3009    0001
# Name: Season, dtype: object

# %%
df1['Season'] = df1['Season'].astype(str)
df['Season'] = df['Season'].astype(str)
df1['Team'] = df1['Team'].astype(str)
df['HomeTeam'] = df['HomeTeam'].astype(str)

df_combined = df1.merge(
    df,
    left_on=['Team', 'Season'],
    right_on=['HomeTeam', 'Season'],
    how='right'
)

#df_combined = df_combined.drop(columns=['HomeTeam'])
df_combined.head()
# Out:
#   Season   Pos         Team   Pld     W     D     L    GF    GA    GD   Pts  \
# 0   9394  13.0     West Ham  42.0  13.0  17.0  12.0  47.0  48.0  -1.0  56.0
# 1   9394  18.0  Southampton  42.0  12.0  12.0  18.0  49.0  57.0  -8.0  48.0
# 2   9394  20.0    Sheffield  42.0  13.0   5.0  24.0  43.0  60.0 -17.0  44.0
# 3   9394  21.0       Oldham  42.0   9.0  16.0  17.0  42.0  56.0 -14.0  43.0
# 4   9394   3.0    Newcastle  42.0  23.0   8.0  11.0  82.0  41.0  41.0  77.0
#
#                         Qualification or relegation  Year  Month  Day  \
# 0                                    Not Applicable  1993      8   14
# 1                                    Not Applicable  1993      8   14
# 2  Relegation to the Football League First Division  1993      8   14
# 3  Relegation to the Football League First Division  1993      8   14
# 4        Qualification for the UEFA Cup first round  1993      8   14
#
#       HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR Referee  HS  AS  \
# ...

# %%
df_combined.shape
# Out:
# (12704, 36)

# %%
df_combined.head()
# Out:
#   Season   Pos         Team   Pld     W     D     L    GF    GA    GD   Pts  \
# 0   9394  13.0     West Ham  42.0  13.0  17.0  12.0  47.0  48.0  -1.0  56.0
# 1   9394  18.0  Southampton  42.0  12.0  12.0  18.0  49.0  57.0  -8.0  48.0
# 2   9394  20.0    Sheffield  42.0  13.0   5.0  24.0  43.0  60.0 -17.0  44.0
# 3   9394  21.0       Oldham  42.0   9.0  16.0  17.0  42.0  56.0 -14.0  43.0
# 4   9394   3.0    Newcastle  42.0  23.0   8.0  11.0  82.0  41.0  41.0  77.0
#
#                         Qualification or relegation  Year  Month  Day  \
# 0                                    Not Applicable  1993      8   14
# 1                                    Not Applicable  1993      8   14
# 2  Relegation to the Football League First Division  1993      8   14
# 3  Relegation to the Football League First Division  1993      8   14
# 4        Qualification for the UEFA Cup first round  1993      8   14
#
#       HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR Referee  HS  AS  \
# ...

# %%
desired_columns = [
    'Season', 'Year', 'Month', 'Day', 
    'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 
    'HTHG', 'HTAG', 'HTR', 'Referee', 
    'HS', 'AS', 'HST', 'AST', 
    'HF', 'AF', 'HC', 'AC', 
    'HY', 'AY', 'HR', 'AR', 
    'Pos', 'Pld', 'W', 'D', 'L', 
    'GF', 'GA', 'GD', 'Pts', 
    'Qualification or relegation'
]

df_ordered = df_combined.reindex(columns=desired_columns)

# %%
df_ordered.head()
# Out:
#   Season  Year  Month  Day     HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   9394  1993      8   14     West Ham  Wimbledon     0     2   A   NaN
# 1   9394  1993      8   14  Southampton    Everton     0     2   A   NaN
# 2   9394  1993      8   14    Sheffield    Swindon     3     1   H   NaN
# 3   9394  1993      8   14       Oldham    Ipswich     0     3   A   NaN
# 4   9394  1993      8   14    Newcastle  Tottenham     0     1   A   NaN
#
#    HTAG  HTR Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR   Pos  \
# 0   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN  13.0
# 1   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN  18.0
# 2   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN  20.0
# 3   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN  21.0
# 4   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN   3.0
#
#     Pld     W     D     L    GF    GA    GD   Pts  \
# ...

# %%
df_ordered.tail()
# Out:
#       Season  Year  Month  Day        HomeTeam    AwayTeam  FTHG  FTAG FTR  \
# 12699   2526  2026      5   24  Crystal Palace     Arsenal     1     2   A
# 12700   2526  2026      5   24         Burnley      Wolves     1     1   D
# 12701   2526  2026      5   24        Brighton  Man United     0     3   A
# 12702   2526  2026      5   24          Fulham   Newcastle     2     0   H
# 12703   2526  2026      5   24       Tottenham     Everton     1     0   H
#
#        HTHG  HTAG HTR    Referee    HS    AS  HST  AST    HF    AF   HC   AC  \
# 12699   0.0   1.0   A   F Hallam   8.0  17.0  3.0  7.0   9.0  12.0  3.0  4.0
# 12700   0.0   1.0   A  A Kitchen  16.0  16.0  8.0  4.0  10.0  11.0  7.0  7.0
# 12701   0.0   2.0   A  S Barrott  13.0  11.0  2.0  7.0  11.0   8.0  0.0  3.0
# 12702   1.0   0.0   H    R Jones  21.0   7.0  6.0  2.0  13.0   6.0  6.0  6.0
# 12703   1.0   0.0   H   M Oliver  21.0   8.0  6.0  3.0  15.0  12.0  6.0  2.0
#
# ...

# %%
df_ordered[155:165]
# Out:
#     Season  Year  Month  Day        HomeTeam     AwayTeam  FTHG  FTAG FTR  \
# 155   9394  1993     11   20       Tottenham        Leeds     1     1   D
# 156   9394  1993     11   20         Swindon      Ipswich     2     2   D
# 157   9394  1993     11   20  Sheffield Weds     Coventry     0     0   D
# 158   9394  1993     11   20      Man United    Wimbledon     3     1   H
# 159   9394  1993     11   20         Everton          QPR     0     3   A
# 160   9394  1993     11   20         Chelsea      Arsenal     0     2   A
# 161   9394  1993     11   20       Blackburn  Southampton     2     0   H
# 162   9394  1993     11   20     Aston Villa    Sheffield     1     0   H
# 163   9394  1993     11   20         Norwich     Man City     1     1   D
# 164   9394  1993     11   21       Newcastle    Liverpool     3     0   H
#
#      HTHG  HTAG  HTR Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  \
# 155   NaN   NaN  NaN     NaN NaN NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN
# ...

# %%
df = df_ordered
df.to_csv("Data/Data2.csv", index=False)

# %% [markdown]
# ---

# %%
df.isna().sum()
# Out:
# Season                            0
# Year                              0
# Month                             0
# Day                               0
# HomeTeam                          0
# AwayTeam                          0
# FTHG                              0
# FTAG                              0
# FTR                               0
# HTHG                            924
# HTAG                            924
# HTR                             924
# Referee                        2824
# HS                             2824
# AS                             2824
# HST                            2824
# AST                            2824
# HF                             2824
# AF                             2824
# HC                             2824
# AC                             2824
# HY                             2824
# AY                             2824
# HR                             2824
# AR                             2824
# Pos                            1904
# ...

# %%
df[ df['Qualification or relegation'].isna() ].shape
# Out:
# (1904, 35)

# %%
df[ df['Qualification or relegation'].isna() ][ ['Season', 'HomeTeam']].iloc[100]
# Out:
# Season        0304
# HomeTeam    Bolton
# Name: 3978, dtype: object

# %%
null_count_per_season = df[df['Qualification or relegation'].isna()]['Season'].value_counts()
print(null_count_per_season)
# Out:
# Season
# 2223    380
# 2324    380
# 2425    380
# 2526    380
# 9495     42
# 0203     38
# 0304     38
# 0405     38
# 0506     38
# 0708     38
# 0910     38
# 1011     38
# 0102     19
# 0607     19
# 0809     19
# 1112     19
# Name: count, dtype: int64

# %%
df[(df['Season'] == '9495') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Ipswich', 'Leicester'], dtype=object)

# %%
df.loc[
    (df['Season'] == '9495') & (df['HomeTeam'] == 'Ipswich'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [22, 42, 7, 6, 29, 36, 93, -57, 27, 'Relegation to the Football League First Division']

df.loc[
    (df['Season'] == '9495') & (df['HomeTeam'] == 'Leicester'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [21, 42, 6, 11, 25, 45, 80, -35, 29, 'Relegation to the Football League First Division']

# %%
df[(df['Season'] == '0203') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Bolton', 'Birmingham'], dtype=object)

# %%
df.loc[
    (df['Season'] == '9495') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [17, 38, 10, 14, 14, 41, 51, -10, 44, 'Not Applicable']

df.loc[
    (df['Season'] == '9495') & (df['HomeTeam'] == 'Birmingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [13, 38, 13, 9, 16, 41, 49, -8, 48, 'Not Applicable']

# %%
df[(df['Season'] == '0304') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Birmingham', 'Bolton'], dtype=object)

# %%
df.loc[
    (df['Season'] == '0304') & (df['HomeTeam'] == 'Birmingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [10, 38, 12, 14, 12, 52, 46, 6, 50, 'Not Applicable']

df.loc[
    (df['Season'] == '0304') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [8, 38, 14, 11, 13, 48, 56, -8, 53, 'Not Applicable']

# %%
df[(df['Season'] == '0405') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Bolton', 'Birmingham'], dtype=object)

# %%
df.loc[
    (df['Season'] == '0405') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [6, 38, 16, 10, 12, 49, 44, 5, 58, 'Not Applicable']

df.loc[
    (df['Season'] == '0405') & (df['HomeTeam'] == 'Birmingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [12, 38, 11, 12, 15, 40, 46, -6, 45, 'Not Applicable']

# %%
df[(df['Season'] == '0506') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Birmingham', 'Bolton'], dtype=object)

# %%
df.loc[
    (df['Season'] == '0506') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [9, 38, 15, 11, 12, 49, 41, 8, 56, 'Not Applicable']

df.loc[
    (df['Season'] == '0506') & (df['HomeTeam'] == 'Birmingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [18, 38, 8, 10, 20, 28, 50, -22, 34, 'Relegation to the Football League First Division']

# %%
df[(df['Season'] == '0708') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Bolton', 'Birmingham'], dtype=object)

# %%
df.loc[
    (df['Season'] == '0708') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [16, 38, 9, 10, 19, 36, 54, -28, 37, 'Not Applicable']

df.loc[
    (df['Season'] == '0708') & (df['HomeTeam'] == 'Birmingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [19, 38, 8, 11, 19, 46, 62, -16, 35, 'Relegation to the Football League First Division']

# %%
df[(df['Season'] == '0910') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Bolton', 'Birmingham'], dtype=object)

# %%
df.loc[
    (df['Season'] == '0910') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [14, 38, 10, 9, 19, 42, 67, -25, 39, 'Not Applicable']

df.loc[
    (df['Season'] == '0910') & (df['HomeTeam'] == 'Birmingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [9, 38, 13, 11, 14, 38, 47, -9, 50, 'Not Applicable']

# %%
df[(df['Season'] == '1011') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Bolton', 'Birmingham'], dtype=object)

# %%
df.loc[
    (df['Season'] == '1011') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [14, 38, 12, 10, 16, 52, 56, -4, 46, 'Not Applicable']

df.loc[
    (df['Season'] == '1011') & (df['HomeTeam'] == 'Birmingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [18, 38, 8, 15, 15, 37, 58, -21, 39, 'Relegation to the Football League First Division']

# %%
df[(df['Season'] == '0102') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Bolton'], dtype=object)

# %%
df.loc[
    (df['Season'] == '0102') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [16, 38, 9, 13, 16, 44, 62, -18, 40, 'Not Applicable']

# %%
df[(df['Season'] == '0607') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Bolton'], dtype=object)

# %%
df.loc[
    (df['Season'] == '0607') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [7, 38, 16, 8, 14, 47, 52, -5, 56, 'Not Applicable']

# %%
df[(df['Season'] == '0809') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Bolton'], dtype=object)

# %%
df.loc[
    (df['Season'] == '0809') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [13, 38, 11, 8, 19, 41, 53, -12, 41, 'Not Applicable']

# %%
df[(df['Season'] == '2223') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Crystal Palace', 'Tottenham', 'Everton', 'Newcastle', 'Fulham',
#        'Bournemouth', 'Leeds', 'Leicester', 'Man United', 'West Ham',
#        'Wolves', 'Southampton', 'Man City', 'Brentford', 'Arsenal',
#        'Aston Villa', 'Brighton', 'Nottingham', 'Chelsea', 'Liverpool'],
#       dtype=object)

# %%
df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Crystal Palace'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [11, 38, 11, 12, 15, 40, 49, -9, 45, 'Not Applicable']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Tottenham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [8, 38, 18, 6, 14, 70, 63, 7, 60, 'Not Applicable']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Everton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [17, 38, 8, 12, 18, 34, 57, -23, 36, 'Not Applicable']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Newcastle'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [4, 38, 19, 14, 5, 68, 33, 35, 71, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Fulham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [10, 38, 15, 7, 16, 55, 53, 2, 52, 'Not Applicable']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Bournemouth'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [15, 38, 11, 6, 21, 37, 71, -34, 39, 'Not Applicable']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Leeds'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [19, 38, 7, 10, 21, 48, 78, -30, 31, 'Relegation to the EFL Championship']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Leicester'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [18, 38, 9, 7, 22, 51, 68, -17, 34, 'Relegation to the EFL Championship']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Man United'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [3, 38, 23, 6, 9, 58, 43, 15, 75, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'West Ham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [14, 38, 11, 7, 20, 42, 55, -13, 40, 'Qualification for the Europa Conference League play-off round']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Wolves'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [13, 38, 11, 8, 19, 31, 58, -27, 41, 'Not Applicable']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Southampton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [20, 38, 6, 7, 25, 36, 73, -37, 25, 'Relegation to the EFL Championship']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Man City'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [1, 38, 28, 5, 5, 94, 33, 61, 89, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Brentford'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [9, 38, 15, 14, 9, 58, 46, 12, 59, 'Not Applicable']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Arsenal'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [2, 38, 26, 6, 6, 88, 43, 45, 84, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Aston Villa'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [7, 38, 18, 7, 13, 51, 46, 5, 61, 'Qualification for the Europa Conference League play-off round']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Brighton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [6, 38, 18, 8, 12, 72, 53, 19, 62, 'Qualification for the Europa League group stage']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Nottingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [16, 38, 9, 11, 18, 38, 68, -30, 38, 'Not Applicable']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Chelsea'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [12, 38, 11, 11, 16, 38, 47, -9, 44, 'Not Applicable']

df.loc[
    (df['Season'] == '2223') & (df['HomeTeam'] == 'Liverpool'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [5, 38, 19, 10, 9, 75, 47, 28, 67, 'Qualification for the Europa League group stage']

# %%
df.loc[
    (df['Season'] == '0607') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [7, 38, 16, 8, 14, 47, 52, -5, 56, 'Not Applicable']

# %%
df[(df['Season'] == '2324') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Burnley', 'Sheffield', 'Arsenal', 'Bournemouth', 'Brighton',
#        'Everton', 'Newcastle', 'Chelsea', 'Brentford', 'Man United',
#        'Nottingham', 'Fulham', 'Liverpool', 'Wolves', 'Tottenham',
#        'Man City', 'Aston Villa', 'West Ham', 'Crystal Palace', 'Luton'],
#       dtype=object)

# %%
df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Burnley'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [19, 38, 5, 9, 24, 41, 78, -37, 24, 'Relegation to the EFL Championship']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Sheffield'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [20, 38, 3, 7, 28, 35, 104, -69, 16, 'Relegation to the EFL Championship']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Arsenal'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [2, 38, 28, 5, 5, 91, 29, 62, 89, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Bournemouth'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [12, 38, 13, 9, 16, 54, 67, -13, 48, 'Not Applicable']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Brighton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [11, 38, 12, 12, 14, 55, 62, -7, 48, 'Not Applicable']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Everton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [15, 38, 13, 9, 16, 40, 51, -11, 40, 'Not Applicable']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Newcastle'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [7, 38, 18, 6, 14, 85, 62, 23, 60, 'Not Applicable']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Chelsea'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [6, 38, 18, 9, 11, 77, 63, 14, 63, 'Qualification for the Europa Conference League play-off round']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Brentford'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [16, 38, 10, 9, 19, 56, 65, -9, 39, 'Not Applicable']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Man United'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [8, 38, 18, 6, 14, 57, 58, -1, 60, 'Qualification for the Europa League group stage']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Nottingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [17, 38, 9, 9, 20, 49, 67, -18, 36, 'Not Applicable']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Fulham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [13, 38, 13, 8, 17, 55, 61, -6, 47, 'Not Applicable']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Liverpool'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [3, 38, 24, 10, 4, 86, 41, 45, 82, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Wolves'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [14, 38, 13, 7, 18, 50, 65, -15, 46, 'Not Applicable']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Tottenham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [5, 38, 20, 6, 12, 74, 61, 13, 66, 'Qualification for the Europa League group stage']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Man City'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [1, 38, 28, 7, 3, 96, 34, 62, 91, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Aston Villa'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [4, 38, 20, 8, 10, 76, 61, 15, 68, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'West Ham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [9, 38, 14, 10, 14, 60, 74, -14, 52, 'Not Applicable']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Crystal Palace'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [10, 38, 13, 10, 15, 57, 58, -1, 49, 'Not Applicable']

df.loc[
    (df['Season'] == '2324') & (df['HomeTeam'] == 'Luton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [18, 38, 6, 8, 24, 52, 85, -33, 26, 'Relegation to the EFL Championship']

# %%
df[(df['Season'] == '2425') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Man United', 'West Ham', 'Ipswich', 'Arsenal', 'Everton',
#        'Newcastle', 'Nottingham', 'Chelsea', 'Brentford', 'Leicester',
#        'Brighton', 'Crystal Palace', 'Fulham', 'Man City', 'Southampton',
#        'Tottenham', 'Aston Villa', 'Liverpool', 'Wolves', 'Bournemouth'],
#       dtype=object)

# %%
df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Man United'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [8, 38, 17, 6, 15, 57, 58, -1, 57, 'Qualification for the Europa League group stage']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'West Ham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [9, 38, 14, 10, 14, 60, 74, -14, 52, 'Not Applicable']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Ipswich'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [19, 38, 6, 8, 24, 52, 85, -33, 26, 'Relegation to the EFL Championship']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Arsenal'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [2, 38, 27, 8, 3, 91, 29, 62, 89, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Everton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [15, 38, 13, 9, 16, 40, 51, -11, 40, 'Not Applicable']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Newcastle'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [7, 38, 18, 6, 14, 85, 62, 23, 60, 'Not Applicable']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Nottingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [17, 38, 9, 9, 20, 49, 67, -18, 36, 'Not Applicable']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Chelsea'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [6, 38, 18, 9, 11, 77, 63, 14, 63, 'Qualification for the Europa Conference League play-off round']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Brentford'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [16, 38, 10, 9, 19, 56, 65, -9, 39, 'Not Applicable']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Leicester'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [18, 38, 9, 7, 22, 51, 68, -17, 34, 'Relegation to the EFL Championship']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Brighton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [11, 38, 12, 12, 14, 55, 62, -7, 48, 'Not Applicable']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Crystal Palace'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [10, 38, 13, 10, 15, 57, 58, -1, 49, 'Not Applicable']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Fulham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [13, 38, 13, 8, 17, 55, 61, -6, 47, 'Not Applicable']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Man City'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [1, 38, 28, 7, 3, 96, 34, 62, 91, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Southampton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [20, 38, 3, 7, 28, 35, 104, -69, 16, 'Relegation to the EFL Championship']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Tottenham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [5, 38, 20, 6, 12, 74, 61, 13, 66, 'Qualification for the Europa League group stage']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Aston Villa'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [4, 38, 20, 8, 10, 76, 61, 15, 68, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Liverpool'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [3, 38, 24, 10, 4, 86, 41, 45, 82, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Wolves'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [14, 38, 13, 7, 18, 50, 65, -15, 46, 'Not Applicable']

df.loc[
    (df['Season'] == '2425') & (df['HomeTeam'] == 'Bournemouth'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [12, 38, 13, 9, 16, 54, 67, -13, 48, 'Not Applicable']

# %%
df[(df['Season'] == '2526') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Liverpool', 'Tottenham', 'Wolves', 'Brighton', 'Aston Villa',
#        'Sunderland', 'Chelsea', 'Nottingham', 'Man United', 'Leeds',
#        'West Ham', 'Burnley', 'Arsenal', 'Bournemouth', 'Man City',
#        'Brentford', 'Crystal Palace', 'Everton', 'Fulham', 'Newcastle'],
#       dtype=object)

# %%
df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Arsenal'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [1, 38, 26, 7, 5, 71, 27, 44, 85, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Man City'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [2, 38, 23, 9, 6, 77, 35, 42, 78, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Man United'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [3, 38, 20, 11, 7, 69, 50, 19, 71, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Aston Villa'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [4, 38, 19, 8, 11, 56, 49, 7, 65, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Liverpool'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [5, 38, 17, 9, 12, 63, 53, 10, 60, 'Qualification for the Champions League group stage']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Bournemouth'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [6, 38, 13, 18, 7, 58, 54, 4, 57, 'Qualification for the Europa League group stage']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Sunderland'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [7, 38, 14, 12, 12, 42, 48, -6, 54, 'Qualification for the Europa League group stage']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Brighton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [8, 38, 14, 11, 13, 52, 46, 6, 53, 'Qualification for the Europa Conference League play-off round']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Brentford'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [9, 38, 14, 11, 13, 55, 52, 3, 53, 'Not Applicable']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Chelsea'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [10, 38, 14, 10, 14, 58, 52, 6, 52, 'Not Applicable']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Fulham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [11, 38, 15, 7, 16, 47, 51, -4, 52, 'Not Applicable']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Newcastle'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [12, 38, 14, 7, 17, 53, 55, -2, 49, 'Not Applicable']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Everton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [13, 38, 13, 10, 15, 47, 50, -3, 49, 'Not Applicable']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Leeds'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [14, 38, 11, 14, 13, 49, 56, -7, 47, 'Not Applicable']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Crystal Palace'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [15, 38, 11, 12, 15, 41, 51, -10, 45, 'Not Applicable']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Nottingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [16, 38, 11, 11, 16, 48, 51, -3, 44, 'Not Applicable']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Tottenham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [17, 38, 10, 11, 17, 48, 57, -9, 41, 'Not Applicable']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'West Ham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [18, 38, 10, 9, 19, 46, 65, -19, 39, 'Relegation to the EFL Championship']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Burnley'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [19, 38, 4, 10, 24, 38, 75, -37, 22, 'Relegation to the EFL Championship']

df.loc[
    (df['Season'] == '2526') & (df['HomeTeam'] == 'Wolves'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [20, 38, 3, 11, 24, 27, 68, -41, 20, 'Relegation to the EFL Championship']

# %%
df[(df['Season'] == '0203') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Bolton', 'Birmingham'], dtype=object)

# %%
df.loc[
    (df['Season'] == '0203') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [17, 38, 10, 14, 14, 42, 59, -17, 44, 'Not Applicable']

df.loc[
    (df['Season'] == '0203') & (df['HomeTeam'] == 'Birmingham'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [13, 38, 13, 9, 16, 41, 49, -8, 48, 'Not Applicable']

# %%
df[(df['Season'] == '1112') & (df['Qualification or relegation'].isna())]['HomeTeam'].unique()
# Out:
# array(['Bolton'], dtype=object)

# %%
df.loc[
    (df['Season'] == '1112') & (df['HomeTeam'] == 'Bolton'),
    ['Pos', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation']
] = [18, 38, 10, 6, 22, 46, 77, -31, 36, 'Relegation to the Football League First Division']

# %%
null_count_per_season = df[df['Qualification or relegation'].isna()]['Season'].value_counts()
print(null_count_per_season)
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.to_csv("Data/Data2.csv", index=False)

# %%
df.tail()
# Out:
#       Season  Year  Month  Day        HomeTeam    AwayTeam  FTHG  FTAG FTR  \
# 12699   2526  2026      5   24  Crystal Palace     Arsenal     1     2   A
# 12700   2526  2026      5   24         Burnley      Wolves     1     1   D
# 12701   2526  2026      5   24        Brighton  Man United     0     3   A
# 12702   2526  2026      5   24          Fulham   Newcastle     2     0   H
# 12703   2526  2026      5   24       Tottenham     Everton     1     0   H
#
#        HTHG  HTAG HTR    Referee    HS    AS  HST  AST    HF    AF   HC   AC  \
# 12699   0.0   1.0   A   F Hallam   8.0  17.0  3.0  7.0   9.0  12.0  3.0  4.0
# 12700   0.0   1.0   A  A Kitchen  16.0  16.0  8.0  4.0  10.0  11.0  7.0  7.0
# 12701   0.0   2.0   A  S Barrott  13.0  11.0  2.0  7.0  11.0   8.0  0.0  3.0
# 12702   1.0   0.0   H    R Jones  21.0   7.0  6.0  2.0  13.0   6.0  6.0  6.0
# 12703   1.0   0.0   H   M Oliver  21.0   8.0  6.0  3.0  15.0  12.0  6.0  2.0
#
# ...

# %% [markdown]
# ---

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# HTHG        924
# HTAG        924
# HTR         924
# Referee    2824
# HS         2824
# AS         2824
# HST        2824
# AST        2824
# HF         2824
# AF         2824
# HC         2824
# AC         2824
# HY         2824
# AY         2824
# HR         2824
# AR         2824
# dtype: int64

# %%
null_count_per_season = df[df['Referee'].isna()]['Season'].value_counts()
print(null_count_per_season)
# Out:
# Season
# 9394    462
# 9495    462
# 9596    380
# 9697    380
# 9798    380
# 9899    380
# 9900    380
# Name: count, dtype: int64

# %%
df[(df['Season'] == '9394') & (df['Referee'].isna())]['HomeTeam'].unique()
# Out:
# array(['West Ham', 'Southampton', 'Sheffield', 'Oldham', 'Newcastle',
#        'Arsenal', 'Liverpool', 'Chelsea', 'Aston Villa', 'Man City',
#        'Norwich', 'Tottenham', 'Ipswich', 'Leeds', 'Wimbledon', 'Everton',
#        'Blackburn', 'Coventry', 'Man United', 'QPR', 'Sheffield Weds',
#        'Swindon'], dtype=object)

# %%
df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Aston Villa') & (df['AwayTeam'] == 'QPR'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 0, 1, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Everton') & (df['AwayTeam'] == 'Aston Villa'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 0, 1, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Leeds') & (df['AwayTeam'] == 'Oldham'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 1, 0, 'H']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Newcastle') & (df['AwayTeam'] == 'Blackburn'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 0, 0, 'D']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Southampton') & (df['AwayTeam'] == 'Man United'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 1, 2, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'West Ham') & (df['AwayTeam'] == 'QPR'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 0, 1, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Sheffield') & (df['AwayTeam'] == 'Swindon'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 1, 0, 'H']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Sheffield') & (df['AwayTeam'] == 'Swindon'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 1, 0, 'H']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Oldham') & (df['AwayTeam'] == 'Ipswich'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 0, 2, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Newcastle') & (df['AwayTeam'] == 'Tottenham'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 0, 1, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Man City') & (df['AwayTeam'] == 'Leeds'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 0, 0, 'D']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Liverpool') & (df['AwayTeam'] == 'Sheffield Weds'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 1, 1, 0, 'H']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Chelsea') & (df['AwayTeam'] == 'Blackburn'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 0, 0, 'D']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Aston  Villa') & (df['AwayTeam'] == 'QPR'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 1, 1, 'D']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Arsenal') & (df['AwayTeam'] == 'Coventry'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0,, 0, 1, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Oldham') & (df['AwayTeam'] == 'Tottenham'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'HTAG', 'HTHG', 'HTR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 1, 0, 0, 0, 1, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Blackburn') & (df['AwayTeam'] == 'Ipswich'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 1, 0, 0, 0, 0, 0, 'D']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Norwich') & (df['AwayTeam'] == 'Oldham'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 1, 0, 0, 0, 1, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Swindon') & (df['AwayTeam'] == 'Leeds'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 1, 0, 0, 0, 2, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Everton') & (df['AwayTeam'] == 'Wimbledon'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 1, 2, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'West Ham') & (df['AwayTeam'] == 'Southampton'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 1, 0, 0, 1, 1, 'D']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Tottenham') & (df['AwayTeam'] == 'QPR'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 1, 1, 'D']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Newcastle') & (df['AwayTeam'] == 'Arsenal'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 1, 0, 0, 0, 0, 'D']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Sheffield Weds') & (df['AwayTeam'] == 'Man City'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 1, 0, 'H']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Chelsea') & (df['AwayTeam'] == 'Sheffield'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2, 1, 0, 0, 0, 1, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Aston Villa') & (df['AwayTeam'] == 'Liverpool'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 0, 1, 'A']

df.loc[
    (df['Season'] == '9394') & (df['HomeTeam'] == 'Man United') & (df['AwayTeam'] == 'Coventry'),
    ['Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 0, 0, 0, 0, 0, 'D']
