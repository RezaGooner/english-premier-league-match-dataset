# %%
import pandas as pd
from tools.utils import *

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("Data/Data5.csv", dtype={'Season': str})

# %%
missing_report(df,"0910")
# Out:
# WeekDay                          380
# Time                             380
# Round                            380
# Attendance                       380
# XGHome                           380
# XGAway                           380
# SeasonPosAway                     38
# SeasonPlayedAway                  38
# SeasonWinAway                     38
# SeasonDrawAway                    38
# SeasonLossAway                    38
# SeasonGFAway                      38
# SeasonGAAway                      38
# SeasonGDAway                      38
# SeasonPointsAway                  38
# QualificationOrRelegationAway     38
# dtype: int64

# %%
null_rows(df, "0910", 'WeekDay')[:100]
# Out:
#          HomeTeam     AwayTeam  Year  Month  Day
# 6244      Everton      Arsenal  2009      8   15
# 6245      Chelsea         Hull  2009      8   15
# 6246       Bolton   Sunderland  2009      8   15
# 6247       Wolves     West Ham  2009      8   15
# 6248  Aston Villa        Wigan  2009      8   15
# 6249   Portsmouth       Fulham  2009      8   15
# 6250    Blackburn     Man City  2009      8   15
# 6251        Stoke      Burnley  2009      8   15
# 6252    Tottenham    Liverpool  2009      8   16
# 6253   Man United   Birmingham  2009      8   16
# 6254        Wigan       Wolves  2009      8   18
# 6255   Sunderland      Chelsea  2009      8   18
# 6256   Birmingham   Portsmouth  2009      8   19
# 6257      Burnley   Man United  2009      8   19
# 6258         Hull    Tottenham  2009      8   19
# 6259    Liverpool        Stoke  2009      8   19
# 6260     Man City       Wolves  2009      8   22
# 6261      Arsenal   Portsmouth  2009      8   22
# ...

# %%
match_data = {
    # ==================== 15 August 2009 - Matchweek 1 ====================
    ('Everton', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': 39309
    },  # Source: FBref [3L12-L13]
    ('Chelsea', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': 41597
    },  # Source: FBref [3L9-L10]
    ('Bolton', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': 22247
    },  # Source: FBref [3L16-L17]
    ('Wolves', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': 28674
    },  # Source: FBref [3L19-L20]
    ('Aston Villa', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': 35578
    },  # Source: FBref [3L18-L19]
    ('Portsmouth', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': 17510
    },  # Source: FBref [3L14-L15]
    ('Blackburn', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': 29584
    },  # Source: FBref [3L15-L16]
    ('Stoke', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': 27385
    },  # Source: FBref [3L11-L12]
    ('Tottenham', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 1,
        'Attendance': 35935
    },  # Source: FBref [3L20-L21]
    ('Man United', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 1,
        'Attendance': 75062
    },  # Source: FBref [3L22-L23]

    # ==================== 18 August 2009 - Matchweek 2 ====================
    ('Wigan', 'Wolves'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 2,
        'Attendance': 16661
    },  # Source: FBref [3L23-L24]
    ('Sunderland', 'Chelsea'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 2,
        'Attendance': 41179
    },  # Source: FBref [3L25-L26]

    # ==================== 19 August 2009 - Matchweek 2 ====================
    ('Birmingham', 'Portsmouth'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 2,
        'Attendance': 19922
    },  # Source: FBref [3L30-L31]
    ('Burnley', 'Man United'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 2,
        'Attendance': 20872
    },  # Source: FBref [3L26-L27]
    ('Hull', 'Tottenham'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 2,
        'Attendance': 24735
    },  # Source: FBref [3L27-L28]
    ('Liverpool', 'Stoke'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 2,
        'Attendance': 44318
    },  # Source: FBref [3L29-L30]

    # ==================== 22 August 2009 - Matchweek 3 ====================
    ('Man City', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': 47287
    },  # Source: FBref [4L34-L35]
    ('Arsenal', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': 60049
    },  # Source: FBref [4L31-L32]
    ('Birmingham', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': 21694
    },  # Source: FBref [4L38-L39]
    ('Hull', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': 22999
    },  # Source: FBref [4L37-L38]
    ('Sunderland', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': 37106
    },  # Source: FBref [4L33-L34]
    ('Wigan', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': 18164
    },  # Source: FBref [4L35-L36]
    ('Burnley', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 3,
        'Attendance': 19983
    },  # Source: FBref [4L42-L43]
    ('Fulham', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 3,
        'Attendance': 25404
    },  # Source: FBref [4L40-L41]
    ('West Ham', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 3,
        'Attendance': 33095
    },  # Source: FBref [4L41-L42]
    ('Liverpool', 'Aston Villa'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 3,
        'Attendance': 43667
    },  # Source: FBref [4L43-L44]

    # ==================== 29 August 2009 - Matchweek 4 ====================
    ('Tottenham', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': 35318
    },  # Source: FBref [4L53-L54]
    ('Wolves', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': 27906
    },  # Source: FBref [4L49-L50]
    ('Man United', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 4,
        'Attendance': 75095
    },  # Source: FBref [4L45-L46]
    ('Stoke', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': 27091
    },  # Source: FBref [4L50-L51]
    ('Bolton', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': 23284
    },  # Source: FBref [4L47-L48]
    ('Blackburn', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': 23421
    },  # Source: FBref [4L46-L47]
    ('Chelsea', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': 40906
    },  # Source: FBref [4L52-L53]
    ('Aston Villa', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 4,
        'Attendance': 32917
    },  # Source: FBref [4L54-L55]
    ('Everton', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 4,
        'Attendance': 35122
    },  # Source: FBref [4L57-L58]
    ('Portsmouth', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 4,
        'Attendance': 17826
    },  # Source: FBref [4L56-L57]

    # ==================== 12 September 2009 - Matchweek 5 ====================
    ('Wigan', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': 17142
    },  # Source: FBref [5L65-L66]
    ('Tottenham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 5,
        'Attendance': 35785
    },  # Source: FBref [5L63-L64]
    ('Sunderland', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': 38997
    },  # Source: FBref [5L61-L62]
    ('Stoke', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': 27440
    },  # Source: FBref [5L68-L69]
    ('Portsmouth', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': 17564
    },  # Source: FBref [5L64-L65]
    ('Liverpool', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': 43817
    },  # Source: FBref [5L58-L59]
    ('Blackburn', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': 24845
    },  # Source: FBref [5L67-L68]
    ('Man City', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': 47339
    },  # Source: FBref [5L60-L61]
    ('Birmingham', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '12:00', 'Round': 5,
        'Attendance': 25196
    },  # Source: FBref [5L71-L72]
    ('Fulham', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 5,
        'Attendance': 24191
    },  # Source: FBref [5L69-L70]

    # ==================== 19 September 2009 - Matchweek 6 ====================
    ('West Ham', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': 34658
    },  # Source: FBref [5L79-L80]
    ('Burnley', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': 20196
    },  # Source: FBref [5L78-L79]
    ('Arsenal', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': 59103
    },  # Source: FBref [5L80-L81]
    ('Aston Villa', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': 35979
    },  # Source: FBref [5L73-L74]
    ('Bolton', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': 20265
    },  # Source: FBref [5L75-L76]
    ('Hull', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': 23759
    },  # Source: FBref [5L76-L77]
    ('Man United', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 6,
        'Attendance': 75066
    },  # Source: FBref [5L82-L83]
    ('Wolves', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 6,
        'Attendance': 27670
    },  # Source: FBref [5L83-L84]
    ('Everton', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 6,
        'Attendance': 35546
    },  # Source: FBref [5L86-L87]
    ('Chelsea', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 6,
        'Attendance': 41623
    },  # Source: FBref [5L84-L85]

    # ==================== 26 September 2009 - Matchweek 7 ====================
    ('Tottenham', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': 35462
    },  # Source: FBref [6L95-L96]
    ('Birmingham', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': 28671
    },  # Source: FBref [6L88-L89]
    ('Blackburn', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': 25172
    },  # Source: FBref [6L93-L94]
    ('Fulham', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': 25700
    },  # Source: FBref [6L96-L97]
    ('Liverpool', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': 44392
    },  # Source: FBref [6L87-L88]
    ('Portsmouth', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': 18116
    },  # Source: FBref [6L90-L91]
    ('Stoke', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': 27500
    },  # Source: FBref [6L91-L92]
    ('Wigan', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': 18542
    },  # Source: FBref [6L94-L95]
    ('Sunderland', 'Wolves'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 7,
        'Attendance': None  # Attendance not listed in source
    },  # Source: FBref [6L98]
    ('Man City', 'West Ham'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 7,
        'Attendance': 42745
    },  # Source: FBref [6L99-L100]

    # ==================== 3 October 2009 - Matchweek 8 ====================
    ('Wolves', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': 29023
    },  # Source: FBref [6L106-L107]
    ('Bolton', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': 21305
    },  # Source: FBref [6L102-L103]
    ('Burnley', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': 20102
    },  # Source: FBref [6L100-L101]
    ('Hull', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': 22822
    },  # Source: FBref [6L103-L104]
    ('Man United', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': 75114
    },  # Source: FBref [6L104-L105]
    ('West Ham', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 8,
        'Attendance': 32612
    },  # Source: FBref [6L110-L111]
    ('Everton', 'Stoke'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 8,
        'Attendance': 36753
    },  # Source: FBref [6L107-L108]
    ('Chelsea', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 8,
        'Attendance': 41732
    },  # Source: FBref [6L111-L112]
    ('Arsenal', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 8,
        'Attendance': 59431
    },  # Source: FBref [6L109-L110]
    ('Aston Villa', 'Man City'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 8,
        'Attendance': 37924
    },  # Source: FBref [6L113-L114]

    # ==================== 17 October 2009 - Matchweek 9 ====================
    ('Stoke', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9,
        'Attendance': None  # Attendance not listed in source
    },  # Source: FBref [6L120-L122]
    ('Portsmouth', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9,
        'Attendance': 20821
    },  # Source: FBref [6L114-L115]
    ('Man United', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9,
        'Attendance': 75103
    },  # Source: FBref [7L122-L123]
    ('Sunderland', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9,
        'Attendance': 47327
    },  # Source: FBref [6L118-L119]
    ('Aston Villa', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 9,
        'Attendance': 39047
    },  # Source: FBref [6L115-L116]
    ('Arsenal', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9,
        'Attendance': None  # Attendance not listed in source
    },  # Source: FBref [6L119-L120]
    ('Everton', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9,
        'Attendance': None  # Attendance not listed in source
    },  # Source: FBref [6L117-L118]
    ('Blackburn', 'Burnley'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 9,
        'Attendance': 26689
    },  # Source: FBref [7L125-L126]
    ('Wigan', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 9,
        'Attendance': 20005
    },  # Source: FBref [7L123-L124]
    ('Fulham', 'Hull'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 9,
        'Attendance': 22943
    },  # Source: FBref [7L126-L127]

    # ==================== 24 October 2009 - Matchweek 10 ====================
    ('Tottenham', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10,
        'Attendance': 35842
    },  # Source: worldfootball
    ('Birmingham', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10,
        'Attendance': 25539
    },  # Source: worldfootball
    ('Burnley', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10,
        'Attendance': 19270
    },  # Source: worldfootball
    ('Chelsea', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10,
        'Attendance': 40836
    },  # Source: worldfootball
    ('Hull', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10,
        'Attendance': 23720
    },  # Source: worldfootball
    ('Wolves', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10,
        'Attendance': 28152
    },  # Source: worldfootball
    ('Liverpool', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 10,
        'Attendance': 44188
    },  # Source: worldfootball
    ('West Ham', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:15', 'Round': 10,
        'Attendance': 34641
    },  # Source: worldfootball
    ('Man City', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 10,
        'Attendance': 44906
    },  # Source: worldfootball
    ('Bolton', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 10,
        'Attendance': 22694
    },  # Source: worldfootball

    # ==================== 31 October 2009 - Matchweek 11 ====================
    ('Man United', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 11,
        'Attendance': 74658
    },  # Source: ESPN [12L7]
    ('Fulham', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 25700
    },  # Source: ESPN [13L7]
    ('Portsmouth', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 17600
    },  # Source: worldfootball
    ('Everton', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 36648
    },  # Source: FBref [11L7-L8]
}

# Columns to fill
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

fill_from_dict(
    df,
    season='0910',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0910", 'WeekDay')[:100]
# Out:
#          HomeTeam     AwayTeam  Year  Month  Day
# 6344   Sunderland     West Ham  2009     10   31
# 6345       Bolton      Chelsea  2009     10   31
# 6346      Arsenal    Tottenham  2009     10   31
# 6347        Stoke       Wolves  2009     10   31
# 6348      Burnley         Hull  2009     10   31
# 6349   Birmingham     Man City  2009     11    1
# 6350     West Ham  Aston Villa  2009     11    4
# 6351     Man City      Burnley  2009     11    7
# 6352    Blackburn   Portsmouth  2009     11    7
# 6353  Aston Villa       Bolton  2009     11    7
# 6354    Tottenham   Sunderland  2009     11    7
# 6355       Wolves      Arsenal  2009     11    7
# 6356        Wigan       Fulham  2009     11    8
# 6357      Chelsea   Man United  2009     11    8
# 6358         Hull        Stoke  2009     11    8
# 6359     West Ham      Everton  2009     11    8
# 6360    Liverpool   Birmingham  2009     11    9
# 6361      Chelsea       Wolves  2009     11   21
# ...

# %%
match_data = {
    # ==================== Matchweek 11 (31 Oct - 1 Nov 2009) ====================
    ('Sunderland', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 39033
    },  # Source: FBref [4L18-L19]
    ('Bolton', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 22680
    },  # Source: FBref [4L19-L20]
    ('Arsenal', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 11,
        'Attendance': 60103
    },  # Source: FBref [4L20-L21]
    ('Stoke', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 27500
    },  # Source: FBref [4L27-L28]
    ('Burnley', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 20219
    },  # Source: FBref [4L25-L26]
    ('Birmingham', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 11,
        'Attendance': 21462
    },  # Source: FBref [4L29-L30]
    ('Everton', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 36648
    },  # Source: FBref [4L16-L17]
    ('Fulham', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 25700
    },  # Source: FBref [4L22-L23]
    ('Man United', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 11,
        'Attendance': 74658
    },  # Source: FBref [4L23-L24]
    ('Portsmouth', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 18212
    },  # Source: FBref [4L26-L27]

    # ==================== 4 November 2009 (Midweek) ====================
    ('West Ham', 'Aston Villa'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 11,
        'Attendance': 30024
    },  # Source: FBref [4L30-L31]

    # ==================== Matchweek 12 (7-8 November 2009) ====================
    ('Tottenham', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': 35955
    },  # Source: FBref [21L7-L8]
    ('Aston Villa', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': 38101
    },  # Source: FBref [21L9-L10]
    ('Man City', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': 47205
    },  # Source: FBref [21L13-L14]
    ('Wolves', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': 28937
    },  # Source: FBref [21L14-L15]
    ('Blackburn', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': 23110
    },  # Source: FBref [21L15-L16]
    ('Hull', 'Stoke'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 12,
        'Attendance': 24516
    },  # Source: FBref [21L19-L20]
    ('Wigan', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 12,
        'Attendance': 16172
    },  # Source: FBref [21L20-L21]
    ('West Ham', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 12,
        'Attendance': 32466
    },  # Source: FBref [21L21-L22]

    # ==================== Matchweek 13 (21-22 November 2009) ====================
    ('Sunderland', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': 44918
    },  # Source: FBref [22L1-L2]
    ('Man United', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 13,
        'Attendance': 75169
    },  # Source: FBref [22L3-L4]
    ('Birmingham', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': 23659
    },  # Source: FBref [22L4-L5]
    ('Chelsea', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': 41786
    },  # Source: FBref [22L7-L8]
    ('Hull', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': 24909
    },  # Source: FBref [22L9-L10]
    ('Liverpool', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': 44164
    },  # Source: FBref [22L10-L11]
    ('Burnley', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': 21178
    },  # Source: FBref [22L14-L15]
    ('Stoke', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 13,
        'Attendance': 27069
    },  # Source: FBref [22L15-L16]
    ('Tottenham', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 13,
        'Attendance': 35650
    },  # Source: FBref [22L16-L17]
    ('Bolton', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 13,
        'Attendance': 21777
    },  # Source: FBref [22L20-L21]

    # ==================== 25 November 2009 (Midweek) ====================
    ('Fulham', 'Blackburn'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 13,
        'Attendance': 21414
    },  # Source: FBref [22L21-L22]
    ('Hull', 'Everton'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 13,
        'Attendance': 24685
    },  # Source: FBref [23L2-L3]

    # ==================== Matchweek 14 (28-29 November 2009) ====================
    ('Aston Villa', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 14,
        'Attendance': 39866
    },  # Source: FBref [23L4-L5]
    ('Portsmouth', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 14,
        'Attendance': 20482
    },  # Source: FBref [23L7-L8]
    ('Fulham', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': 23554
    },  # Source: FBref [23L8-L9]
    ('Blackburn', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': 25143
    },  # Source: FBref [23L10-L11]
    ('West Ham', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': 34003
    },  # Source: FBref [23L13-L14]
    ('Man City', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': 46382
    },  # Source: FBref [23L16-L17]
    ('Wigan', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': 20447
    },  # Source: FBref [23L19-L20]
    ('Everton', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 14,
        'Attendance': 39652
    },  # Source: FBref [23L20-L21]
    ('Wolves', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '12:00', 'Round': 14,
        'Attendance': 26668
    },  # Source: FBref [23L22-L23]
    ('Arsenal', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 14,
        'Attendance': 60067
    },  # Source: FBref [23L25-L26]

    # ==================== Matchweek 15 (5-6 December 2009) ====================
    ('Aston Villa', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': 39748
    },  # Source: FBref [24L2-L3]
    ('Arsenal', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': 60048
    },  # Source: FBref [24L3-L4]
    ('Wigan', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': 18797
    },  # Source: FBref [24L7-L8]
    ('Wolves', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': 27362
    },  # Source: FBref [24L8-L9]
    ('West Ham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': 34980
    },  # Source: FBref [24L9-L10]
    ('Portsmouth', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': 17822
    },  # Source: FBref [24L13-L14]
    ('Blackburn', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': 29660
    },  # Source: FBref [24L14-L15]
    ('Fulham', 'Sunderland'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 15,
        'Attendance': 23168
    },  # Source: FBref [24L16-L17]
    ('Everton', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 15,
        'Attendance': 34003
    },  # Source: FBref [24L19-L20]

    # ==================== Matchweek 16 (12-13 December 2009) ====================
    ('Birmingham', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': 28203
    },  # Source: FBref [25L7-L8]
    ('Chelsea', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': 41579
    },  # Source: FBref [25L9-L10]
    ('Bolton', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': 22735
    },  # Source: FBref [25L10-L11]
    ('Stoke', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': 26728
    },  # Source: FBref [25L13-L14]
    ('Burnley', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': 18397
    },  # Source: FBref [25L15-L16]
    ('Sunderland', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': 37578
    },  # Source: FBref [25L19-L20]
    ('Tottenham', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': 36012
    },  # Source: FBref [25L20-L21]
    ('Hull', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': 24124
    },  # Source: FBref [25L21-L22]
    ('Man United', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 16,
        'Attendance': 75130
    },  # Source: FBref [25L23-L24]
    ('Liverpool', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 16,
        'Attendance': 43853
    },  # Source: FBref [25L25-L26]

    # ==================== Matchweek 17 (15-16 December 2009) ====================
    ('Man United', 'Wolves'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 17,
        'Attendance': 73709
    },  # Source: FBref [26L7-L8]
    ('Birmingham', 'Blackburn'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 17,
        'Attendance': 23187
    },  # Source: FBref [26L9-L10]
    ('Sunderland', 'Aston Villa'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 17,
        'Attendance': 34821
    },  # Source: FBref [26L13-L14]
    ('Bolton', 'West Ham'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 17,
        'Attendance': 17849
    },  # Source: FBref [26L14-L15]
    ('Tottenham', 'Man City'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 17,
        'Attendance': 35891
    },  # Source: FBref [26L15-L16]
    ('Chelsea', 'Portsmouth'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 17,
        'Attendance': 40137
    },  # Source: FBref [26L19-L20]
    ('Liverpool', 'Wigan'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 17,
        'Attendance': 41116
    },  # Source: FBref [26L22-L23]
    ('Burnley', 'Arsenal'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 17,
        'Attendance': 21309
    },  # Source: FBref [26L24-L25]

    # ==================== Matchweek 18 (19-20 December 2009) ====================
    ('Arsenal', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': 60006
    },  # Source: FBref [27L7-L8]
    ('Fulham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': 25700
    },  # Source: FBref [27L9-L10]
    ('Blackburn', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': 26490
    },  # Source: FBref [27L10-L11]
    ('Aston Villa', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': 35852
    },  # Source: FBref [27L13-L14]
    ('Man City', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': 44735
    },  # Source: FBref [27L15-L16]
    ('Portsmouth', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': 20534
    },  # Source: FBref [27L19-L20]
    ('Wolves', 'Burnley'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 18,
        'Attendance': 27410
    },  # Source: FBref [27L20-L21]
    ('West Ham', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 18,
        'Attendance': 33388
    },  # Source: FBref [27L21-L22]

    # ==================== Matchweek 19 (26-30 December 2009) ====================
    ('West Ham', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Data not found
    },
    ('Wigan', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Data not found
    },
    ('Sunderland', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Data not found
    },
    ('Burnley', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Data not found
    },
    ('Liverpool', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Data not found
    },
    ('Fulham', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Data not found
    },
    ('Man City', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Data not found
    },
    ('Birmingham', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Data not found
    },
    ('Arsenal', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 19,
        'Attendance': None  # Data not found
    },
    ('Hull', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Data not found
    },

    # ==================== Matchweek 20 (28 December 2009) ====================
    ('Blackburn', 'Sunderland'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Data not found
    },
    ('Chelsea', 'Fulham'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Data not found
    },
    ('Everton', 'Burnley'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Data not found
    },
    ('Stoke', 'Birmingham'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Data not found
    },
    ('Tottenham', 'West Ham'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Data not found
    },
    ('Wolves', 'Man City'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Data not found
    },
    ('Aston Villa', 'Liverpool'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 20,
        'Attendance': None  # Data not found
    },
    ('Bolton', 'Hull'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 20,
        'Attendance': None  # Data not found
    },

    # ==================== Matchweek 21 (30 December 2009) ====================
    ('Man United', 'Wigan'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 21,
        'Attendance': None  # Data not found
    },
    ('Portsmouth', 'Arsenal'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 21,
        'Attendance': None  # Data not found
    },

    # ==================== Matchweek 22 (5-6 January 2010) ====================
    ('Stoke', 'Fulham'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 22,
        'Attendance': None  # Data not found
    },

    # ==================== Matchweek 23 (9-11 January 2010) ====================
    ('Birmingham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23,
        'Attendance': None  # Data not found
    },
    ('Arsenal', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23,
        'Attendance': None  # Data not found
    },
    ('Man City', 'Blackburn'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 23,
        'Attendance': None  # Data not found
    },
}

fill_from_dict(
    df,
    season='0910',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0910", 'WeekDay')[:100]
# Out:
#          HomeTeam     AwayTeam  Year  Month  Day
# 6357      Chelsea   Man United  2009     11    8
# 6360    Liverpool   Birmingham  2009     11    9
# 6389     Man City      Chelsea  2009     12    5
# 6417      Everton   Birmingham  2009     12   20
# 6444   Man United      Burnley  2010      1   16
# 6445        Stoke    Liverpool  2010      1   16
# 6446    Tottenham         Hull  2010      1   16
# 6447       Wolves        Wigan  2010      1   16
# 6448      Everton     Man City  2010      1   16
# 6449      Chelsea   Sunderland  2010      1   16
# 6450  Aston Villa     West Ham  2010      1   17
# 6451    Blackburn       Fulham  2010      1   17
# 6452       Bolton      Arsenal  2010      1   17
# 6453      Arsenal       Bolton  2010      1   20
# 6454    Liverpool    Tottenham  2010      1   20
# 6455   Man United         Hull  2010      1   23
# 6456       Wolves    Liverpool  2010      1   26
# 6457       Bolton      Burnley  2010      1   26
# ...

# %%
match_data = {
    # -------------------- 8 November 2009 --------------------
    ('Chelsea', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 12,
        'Attendance': 41836
    },  # Source: ESPN [3L5-L7], 11v11 [3L23-L24]

    # -------------------- 9 November 2009 --------------------
    ('Liverpool', 'Birmingham'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 12,
        'Attendance': 42560
    },  # Source: 11v11 [4L10-L12], Sky Sports [4L6-L7]

    # -------------------- 5 December 2009 --------------------
    ('Man City', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 15,
        'Attendance': 47348
    },  # Source: Sky Sports [5L6-L7], ESPN [5L9-L11]

    # -------------------- 20 December 2009 --------------------
    ('Everton', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 18,
        'Attendance': 34003
    },  # Source: FBref [28L35-L36]

    # -------------------- 16 January 2010 --------------------
    ('Man United', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 22,
        'Attendance': 75000  # Estimate from home average
    },
    ('Stoke', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 22,
        'Attendance': 27500  # Estimate from home average
    },
    ('Tottenham', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 22,
        'Attendance': 36000  # Estimate from home average
    },
    ('Wolves', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 22,
        'Attendance': 27000  # Estimate from home average
    },
    ('Everton', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 22,
        'Attendance': 37000  # Estimate from home average
    },
    ('Chelsea', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 22,
        'Attendance': 41000  # Estimate from home average
    },
    ('Aston Villa', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 22,
        'Attendance': 39000  # Estimate from home average
    },
    ('Blackburn', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 22,
        'Attendance': 25000  # Estimate from home average
    },
    ('Bolton', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 22,
        'Attendance': 23000  # Estimate from home average
    },

    # -------------------- 20 January 2010 --------------------
    ('Arsenal', 'Bolton'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 22,
        'Attendance': 60000  # Estimate from home average
    },
    ('Liverpool', 'Tottenham'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 22,
        'Attendance': 43000  # Estimate from home average
    },

    # -------------------- 23 January 2010 --------------------
    ('Man United', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23,
        'Attendance': 75000  # Estimate from home average
    },

    # -------------------- 26 January 2010 --------------------
    ('Wolves', 'Liverpool'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 23,
        'Attendance': 28000  # Estimate from home average
    },
    ('Bolton', 'Burnley'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 23,
        'Attendance': 21000  # Estimate from home average
    },
    ('Portsmouth', 'West Ham'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 23,
        'Attendance': 18000  # Estimate from home average
    },
    ('Tottenham', 'Fulham'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 23,
        'Attendance': 36000  # Estimate from home average
    },

    # -------------------- 27 January 2010 --------------------
    ('Aston Villa', 'Arsenal'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 23,
        'Attendance': 40000  # Estimate from home average
    },
    ('Blackburn', 'Wigan'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 23,
        'Attendance': 25000  # Estimate from home average
    },
    ('Chelsea', 'Birmingham'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 23,
        'Attendance': 41000  # Estimate from home average
    },
    ('Everton', 'Sunderland'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 23,
        'Attendance': 36000  # Estimate from home average
    },

    # -------------------- 30 January 2010 --------------------
    ('Wigan', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': 18000  # Estimate from home average
    },
    ('West Ham', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': 33000  # Estimate from home average
    },
    ('Burnley', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': 21000  # Estimate from home average
    },
    ('Hull', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': 24000  # Estimate from home average
    },
    ('Liverpool', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': 43000  # Estimate from home average
    },
    ('Birmingham', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': 27000  # Estimate from home average
    },
    ('Fulham', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': 25000  # Estimate from home average
    },

    # -------------------- 31 January 2010 --------------------
    ('Man City', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 24,
        'Attendance': 45000  # Estimate from home average
    },
    ('Arsenal', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 24,
        'Attendance': 60000  # Estimate from home average
    },

    # -------------------- 1 February 2010 --------------------
    ('Sunderland', 'Stoke'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 24,
        'Attendance': 39000  # Estimate from home average
    },

    # -------------------- 2 February 2010 --------------------
    ('Hull', 'Chelsea'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 25,
        'Attendance': 24000  # Estimate from home average
    },

    # -------------------- 3 February 2010 --------------------
    ('Fulham', 'Portsmouth'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 25,
        'Attendance': 23000  # Estimate from home average
    },

    # -------------------- 6 February 2010 --------------------
    ('Bolton', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25,
        'Attendance': 22000  # Estimate from home average
    },
    ('Hull', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25,
        'Attendance': 24000  # Estimate from home average
    },
    ('Liverpool', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 25,
        'Attendance': 44000  # Estimate from home average
    },
    ('Man United', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25,
        'Attendance': 75000  # Estimate from home average
    },
    ('Stoke', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25,
        'Attendance': 27000  # Estimate from home average
    },
    ('Sunderland', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25,
        'Attendance': 39000  # Estimate from home average
    },
    ('Tottenham', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 25,
        'Attendance': 36000  # Estimate from home average
    },
    ('Burnley', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25,
        'Attendance': 20000  # Estimate from home average
    },

    # -------------------- 7 February 2010 --------------------
    ('Chelsea', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 25,
        'Attendance': 41000  # Estimate from home average
    },
    ('Birmingham', 'Wolves'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 25,
        'Attendance': 27000  # Estimate from home average
    },

    # -------------------- 9 February 2010 --------------------
    ('Man City', 'Bolton'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 26,
        'Attendance': 45000  # Estimate from home average
    },
    ('Portsmouth', 'Sunderland'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 26,
        'Attendance': 18000  # Estimate from home average
    },
    ('Wigan', 'Stoke'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 26,
        'Attendance': 18000  # Estimate from home average
    },
    ('Fulham', 'Burnley'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 26,
        'Attendance': 23000  # Estimate from home average
    },

    # -------------------- 10 February 2010 --------------------
    ('Arsenal', 'Liverpool'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 26,
        'Attendance': 60000  # Estimate from home average
    },
    ('Aston Villa', 'Man United'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 26,
        'Attendance': 40000  # Estimate from home average
    },
    ('Blackburn', 'Hull'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 26,
        'Attendance': 25000  # Estimate from home average
    },
    ('Everton', 'Chelsea'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 26,
        'Attendance': 36000  # Estimate from home average
    },
    ('West Ham', 'Birmingham'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 26,
        'Attendance': 33000  # Estimate from home average
    },
    ('Wolves', 'Tottenham'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 26,
        'Attendance': 27000  # Estimate from home average
    },

    # -------------------- 16 February 2010 --------------------
    ('Stoke', 'Man City'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 27,
        'Attendance': 27000  # Estimate from home average
    },

    # -------------------- 17 February 2010 --------------------
    ('Wigan', 'Bolton'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 27,
        'Attendance': 18000  # Estimate from home average
    },

    # -------------------- 20 February 2010 --------------------
    ('Everton', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 27,
        'Attendance': 36000  # Estimate from home average
    },
    ('Portsmouth', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27,
        'Attendance': 18000  # Estimate from home average
    },
    ('West Ham', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27,
        'Attendance': 33000  # Estimate from home average
    },
    ('Wolves', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 27,
        'Attendance': 27000  # Estimate from home average
    },
    ('Arsenal', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27,
        'Attendance': 60000  # Estimate from home average
    },

    # -------------------- 21 February 2010 --------------------
    ('Man City', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 27,
        'Attendance': 45000  # Estimate from home average
    },
    ('Wigan', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 27,
        'Attendance': 18000  # Estimate from home average
    },
    ('Blackburn', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 27,
        'Attendance': 25000  # Estimate from home average
    },
    ('Fulham', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 27,
        'Attendance': 23000  # Estimate from home average
    },
    ('Aston Villa', 'Burnley'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 27,
        'Attendance': 39000  # Estimate from home average
    },

    # -------------------- 23 February 2010 --------------------
    ('Man United', 'West Ham'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 27,
        'Attendance': 75000  # Estimate from home average
    },

    # -------------------- 27 February 2010 --------------------
    ('Birmingham', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28,
        'Attendance': 27000  # Estimate from home average
    },
    ('Bolton', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28,
        'Attendance': 22000  # Estimate from home average
    },
    ('Burnley', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28,
        'Attendance': 20000  # Estimate from home average
    },
    ('Chelsea', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 28,
        'Attendance': 41000  # Estimate from home average
    },
    ('Stoke', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28,
        'Attendance': 27000  # Estimate from home average
    },

    # -------------------- 28 February 2010 --------------------
    ('Liverpool', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 28,
        'Attendance': 43000  # Estimate from home average
    },
    ('Sunderland', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 28,
        'Attendance': 39000  # Estimate from home average
    },
    ('Tottenham', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 28,
        'Attendance': 36000  # Estimate from home average
    },

    # -------------------- 6 March 2010 --------------------
    ('Arsenal', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29,
        'Attendance': 60000  # Estimate from home average
    },
    ('West Ham', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29,
        'Attendance': 33000  # Estimate from home average
    },
    ('Wolves', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 29,
        'Attendance': 27000  # Estimate from home average
    },

    # -------------------- 7 March 2010 --------------------
    ('Everton', 'Hull'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 29,
        'Attendance': 36000  # Estimate from home average
    },

    # -------------------- 8 March 2010 --------------------
    ('Wigan', 'Liverpool'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 29,
        'Attendance': 18000  # Estimate from home average
    },

    # -------------------- 9 March 2010 --------------------
    ('Portsmouth', 'Birmingham'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 29,
        'Attendance': 18000  # Estimate from home average
    },
    ('Sunderland', 'Bolton'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 29,
        'Attendance': 39000  # Estimate from home average
    },

    # -------------------- 10 March 2010 --------------------
    ('Burnley', 'Stoke'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 29,
        'Attendance': 20000  # Estimate from home average
    },

    # -------------------- 13 March 2010 --------------------
    ('Stoke', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30,
        'Attendance': 27000  # Estimate from home average
    },
    ('Hull', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30,
        'Attendance': 24000  # Estimate from home average
    },
    ('Tottenham', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30,
        'Attendance': 36000  # Estimate from home average
    },
    ('Burnley', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30,
        'Attendance': 20000  # Estimate from home average
    },
    ('Birmingham', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30,
        'Attendance': 27000  # Estimate from home average
    },
    ('Bolton', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30,
        'Attendance': 22000  # Estimate from home average
    },
    ('Chelsea', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30,
        'Attendance': 41000  # Estimate from home average
    },

    # -------------------- 14 March 2010 --------------------
    ('Man United', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 30,
        'Attendance': 75000  # Estimate from home average
    },
    ('Sunderland', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 30,
        'Attendance': 39000  # Estimate from home average
    },

    # -------------------- 15 March 2010 --------------------
    ('Liverpool', 'Portsmouth'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 30,
        'Attendance': 43000  # Estimate from home average
    },

    # -------------------- 16 March 2010 --------------------
    ('Wigan', 'Aston Villa'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 30,
        'Attendance': 18000  # Estimate from home average
    },

    # -------------------- 20 March 2010 --------------------
    ('Sunderland', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31,
        'Attendance': 39000  # Estimate from home average
    },
    ('Stoke', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31,
        'Attendance': 27000  # Estimate from home average
    },
    ('Wigan', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31,
        'Attendance': 18000  # Estimate from home average
    },
    ('Everton', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31,
        'Attendance': 36000  # Estimate from home average
    },
}

fill_from_dict(
    df,
    season='0910',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0910", 'WeekDay')
# Out:
#          HomeTeam     AwayTeam  Year  Month  Day
# 6540  Aston Villa       Wolves  2010      3   20
# 6541      Arsenal     West Ham  2010      3   20
# 6542   Portsmouth         Hull  2010      3   20
# 6543    Blackburn      Chelsea  2010      3   21
# 6544       Fulham     Man City  2010      3   21
# 6545   Man United    Liverpool  2010      3   21
# 6546     West Ham       Wolves  2010      3   23
# 6547  Aston Villa   Sunderland  2010      3   24
# 6548    Blackburn   Birmingham  2010      3   24
# 6549     Man City      Everton  2010      3   24
# 6550   Portsmouth      Chelsea  2010      3   24
# 6551       Wolves      Everton  2010      3   27
# 6552     West Ham        Stoke  2010      3   27
# 6553       Bolton   Man United  2010      3   27
# 6554         Hull       Fulham  2010      3   27
# 6555      Chelsea  Aston Villa  2010      3   27
# 6556   Birmingham      Arsenal  2010      3   27
# 6557    Tottenham   Portsmouth  2010      3   27
# ...

# %%
match_data = {
    # ==================== 20 March 2010 - Matchweek 31 ====================
    ('Aston Villa', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 31,
        'Attendance': 37562
    },  # Source: ESPN [2L5-L6], FBref [2L19-L20]
    ('Arsenal', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 31,
        'Attendance': 60077
    },  # Source: ESPN [3L5-L6], Sky Sports [3L11]
    ('Portsmouth', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31,
        'Attendance': 16513
    },  # Source: ESPN [4L5-L6], Sky Sports [4L11]

    # ==================== 21 March 2010 - Matchweek 31 ====================
    ('Blackburn', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 31,
        'Attendance': 25554
    },  # Source: Sky Sports [5L7], FBref [5L11-L12]
    ('Fulham', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 31,
        'Attendance': 25359
    },  # Source: ESPN [6L6-L7], FootyRoom [6L11]
    ('Man United', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 31,
        'Attendance': 75216
    },  # Source: ESPN [7L6-L7]

    # ==================== 23 March 2010 - Matchweek 21 ====================
    ('West Ham', 'Wolves'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 21,
        'Attendance': 33988
    },  # Source: ESPN [8L5-L6], Sky Sports [8L20]

    # ==================== 24 March 2010 - Matchweek 29 ====================
    ('Aston Villa', 'Sunderland'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 29,
        'Attendance': 37473
    },  # Source: ESPN [9L6-L7], FBref [9L20-L21]
    ('Blackburn', 'Birmingham'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 29,
        'Attendance': 23856
    },  # Source: Sky Sports [10L7], FBref [10L32-L33]
    ('Man City', 'Everton'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 29,
        'Attendance': 45708
    },  # Source: Sky Sports [11L7], ESPN [11L10-L11]
    ('Portsmouth', 'Chelsea'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 29,
        'Attendance': 18753
    },  # Source: Sky Sports [12L7], Premier League [12L18-L19]

    # ==================== 27 March 2010 - Matchweek 32 ====================
    ('Wolves', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': 28995
    },  # Source: ESPN [13L6-L7], FBref [13L16-L17]
    ('West Ham', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': 34564
    },  # Source: ESPN [14L5-L6], 11v11 [14L15]
    ('Bolton', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 32,
        'Attendance': 25370
    },  # Source: footymadalex [15L6-L7]
    ('Hull', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': 24361
    },  # Source: ESPN [16L5-L6], 11v11 [16L10-L11]
    ('Chelsea', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': 41825
    },  # Source: ESPN [17L5-L6], FBref [17L17]
    ('Birmingham', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': 27039
    },  # Source: FBref [18L16-L17], fussballdaten [18L6-L7]
    ('Tottenham', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': 35870
    },  # Source: Sky Sports [19L7], ESPN [19L9-L10]

    # ==================== 28 March 2010 - Matchweek 32 ====================
    ('Burnley', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '12:00', 'Round': 32,
        'Attendance': 21546
    },  # Source: ESPN [20L5-L6], 11v11 [20L19-L20]
    ('Liverpool', 'Sunderland'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 32,
        'Attendance': 43121
    },  # Source: ESPN [21L6-L7], LFChistory [21L13-L14]

    # ==================== 29 March 2010 - Matchweek 32 ====================
    ('Man City', 'Wigan'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 32,
        'Attendance': 43534
    },  # Source: ESPN [22L5-L6], Sky Sports [22L10-L11]

    # ==================== 3 April 2010 - Matchweek 33 ====================
    ('Sunderland', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33,
        'Attendance': 43184
    },  # Source: ESPN [23L5-L6], Sky Sports [23L14-L15]
    ('Stoke', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33,
        'Attendance': 27604
    },  # Source: Sky Sports [24L7], FBref [24L29-L30]
    ('Portsmouth', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33,
        'Attendance': 16207
    },  # Source: Sky Sports [25L6-L7], FBref [25L25-L26]
    ('Burnley', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 33,
        'Attendance': 21330
    },  # Source: Sky Sports [26L6-L7]
    ('Bolton', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33,
        'Attendance': 21111
    },  # Source: FBref [27L7-L8]
    ('Arsenal', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33,
        'Attendance': 60067
    },  # Source: Sky Sports [28L7], ESPN [28L10-L11]
    ('Man United', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 33,
        'Attendance': 75217
    },  # Source: ESPN [29L6-L7]

    # ==================== 4 April 2010 - Matchweek 33 ====================
    ('Birmingham', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 33,
        'Attendance': 27909
    },  # Source: Sky Sports [30L7], LFChistory [30L9-L10]
    ('Everton', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 33,
        'Attendance': 37451
    },  # Source: Sky Sports [31L7], ESPN [31L10-L11]
    ('Fulham', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 33,
        'Attendance': 22730
    },  # Source: Global Sports Archive [32L7], Sky Sports [32L15-L16]

    # ==================== 10 April 2010 - Matchweek 34 ====================
    ('Hull', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34,
        'Attendance': 24369
    },  # Source: ESPN [33L5-L6], weltfussball [33L16-L17]
    ('West Ham', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34,
        'Attendance': 34685
    },  # Source: ESPN [34L5-L6], 11v11 [34L15-L16]

    # ==================== 11 April 2010 - Matchweek 34 ====================
    ('Wolves', 'Stoke'): {
        'WeekDay': 'Sun', 'Time': '12:00', 'Round': 34,
        'Attendance': 28455
    },  # Source: ESPN [35L5-L6], Sky Sports [35L11]
    ('Liverpool', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 34,
        'Attendance': 42331
    },  # Source: LFChistory [36L4-L7], Sky Sports [36L11]
    ('Blackburn', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '14:30', 'Round': 34,
        'Attendance': 29912
    },  # Source: Sky Sports [37L7], Transfermarkt [37L19-L20]
    ('Man City', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 34,
        'Attendance': 45209
    },  # Source: ESPN [38L5-L6], Sky Sports [38L11-L12]

    # ==================== 13 April 2010 - Matchweek 34 ====================
    ('Chelsea', 'Bolton'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 34,
        'Attendance': 40539
    },  # Source: Sky Sports [39L6-L7], 11v11 [39L14-L15]

    # ==================== 14 April 2010 - Matchweek 34 ====================
    ('Aston Villa', 'Everton'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 34,
        'Attendance': 38729
    },  # Source: Sky Sports [40L7], FBref [40L20-L21]
    ('Tottenham', 'Arsenal'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 34,
        'Attendance': 36041
    },  # Source: Sky Sports [41L7], FBref [41L20-L21]
    ('Wigan', 'Portsmouth'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 34,
        'Attendance': 14323
    },  # Source: Sky Sports [42L6-L7]

    # ==================== 17 April 2010 - Matchweek 35 ====================
    ('Birmingham', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': 26669
    },  # Source: Sky Sports [43L6-L7], FBref [43L34-L35]
    ('Blackburn', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': 27022
    },  # Source: Sky Sports [44L6-L7]
    ('Fulham', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': 25597
    },  # Source: ESPN [45L5-L6], FBref [45L26-L27]
    ('Man City', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 35,
        'Attendance': 47019
    },  # Source: ESPN [46L6-L7]
    ('Stoke', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': 27250
    },  # Source: Sky Sports [47L6-L7], FBref [47L11-L12]
    ('Sunderland', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': 41341
    },  # Source: Premier League [48L6], 11v11 [48L18-L19]
    ('Tottenham', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 35,
        'Attendance': 35814
    },  # Source: ESPN [49L6], THFCDB [49L29-L30]

    # ==================== 18 April 2010 - Matchweek 35 ====================
    ('Portsmouth', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 35,
        'Attendance': 16523
    },  # Source: Sky Sports [50L7], FBref [50L17]
    ('Wigan', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 35,
        'Attendance': 22113
    },  # Source: Sky Sports [51L7], FBref [51L19]

    # ==================== 19 April 2010 - Matchweek 35 ====================
    ('Liverpool', 'West Ham'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 35,
        'Attendance': 37697
    },  # Source: Sky Sports [52L6-L7], ESPN [52L10-L11]

    # ==================== 21 April 2010 - Matchweek 28 ====================
    ('Hull', 'Aston Villa'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 28,
        'Attendance': 23842
    },  # Source: Sky Sports [53L6-L7], 11v11 [53L20-L21]

    # ==================== 24 April 2010 - Matchweek 36 ====================
    ('Arsenal', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 36,
        'Attendance': 60086
    },  # Source: ESPN [54L6-L7], Sky Sports [54L10-L11]
    ('Bolton', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': 20526
    },  # Source: Sky Sports [55L6-L7], 11v11 [55L21-L22]
    ('Hull', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': 25012
    },  # Source: Sky Sports [56L6-L7], 11v11 [56L24-L25]
    ('Man United', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 36,
        'Attendance': 75268
    },  # Source: ESPN [57L5-L6]
    ('West Ham', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': 33057
    },  # Source: Sky Sports [58L7], ESPN [58L10-L11]
    ('Wolves', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': 28967
    },  # Source: ESPN [59L5-L6]

    # ==================== 25 April 2010 - Matchweek 36 ====================
    ('Everton', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 36,
        'Attendance': 35578
    },  # Source: ESPN [60L5-L6], 11v11 [60L14-L15]
    ('Aston Villa', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '12:00', 'Round': 36,
        'Attendance': 42788
    },  # Source: ESPN [61L6-L7], FBref [61L23-L24]
    ('Chelsea', 'Stoke'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 36,
        'Attendance': 41013
    },  # Source: FBref [62L11-L12], Sky Sports [62L15-L16]
    ('Burnley', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 36,
        'Attendance': 21553
    },  # Source: Sky Sports [63L6-L7], LFChistory [63L14-L15]

    # ==================== 1 May 2010 - Matchweek 37 ====================
    ('Birmingham', 'Burnley'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 37,
        'Attendance': 24578
    },  # Source: Sky Sports [64L7], FBref [64L31-L32]
    ('Man City', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37,
        'Attendance': 47102
    },  # Source: ESPN [65L10-L11], Sky Sports [65L15-L16]
    ('Portsmouth', 'Wolves'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37,
        'Attendance': 19213
    },  # Source: ESPN [66L6-L7], FBref [66L17-L18]
    ('Stoke', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37,
        'Attendance': 27579
    },  # Source: Sky Sports [67L6-L7], FBref [67L25-L26]
    ('Tottenham', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37,
        'Attendance': 35852
    },  # Source: ESPN [68L5-L6], FBref [68L17-L18]

    # ==================== 2 May 2010 - Matchweek 37 ====================
    ('Fulham', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 37,
        'Attendance': 24201
    },  # Source: ESPN [69L6-L7], Sky Sports [69L19-L20]
    ('Liverpool', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 37,
        'Attendance': 44375
    },  # Source: Sky Sports [70L7], LFChistory [70L13-L15]
    ('Sunderland', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 37,
        'Attendance': 47641
    },  # Source: ESPN [71L6-L7]

    # ==================== 3 May 2010 - Matchweek 37 ====================
    ('Blackburn', 'Arsenal'): {
        'WeekDay': 'Mon', 'Time': '17:00', 'Round': 37,
        'Attendance': 26138
    },  # Source: Sky Sports [72L6-L7], 11v11 [72L19-L20]
    ('Wigan', 'Hull'): {
        'WeekDay': 'Mon', 'Time': '14:30', 'Round': 37,
        'Attendance': 20242
    },  # Source: ESPN [73L5-L6], Sky Sports [73L9-L10]

    # ==================== 5 May 2010 - Matchweek 29 ====================
    ('Man City', 'Tottenham'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 29,
        'Attendance': 47370
    },  # Source: ESPN [74L6-L7], Sky Sports [74L15-L16]
    ('Fulham', 'Stoke'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 29,
        'Attendance': 20831
    },  # Source: ESPN [75L6-L7], FBref [75L36-L37]

    # ==================== 9 May 2010 - Matchweek 38 ====================
    ('Wolves', 'Sunderland'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': 28971
    },  # Source: ESPN [76L5-L6], FBref [76L22-L23]
    ('West Ham', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': 34989
    },  # Source: ESPN [77L6-L7]
    ('Man United', 'Stoke'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': 75316
    },  # Source: Tribuna [78L7]
    ('Hull', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': 25030
    },  # Source: ESPN [79L5-L6], LFChistory [79L10-L11]
    ('Chelsea', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': 41383
    },  # Source: Premier League [80L6], ESPN [80L10-L11]
    ('Burnley', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': 21161
    },  # Source: Sky Sports [81L7-L8], 11v11 [81L16-L17]
    ('Bolton', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': 22863
    },  # Source: Sky Sports [82L6-L7]
    ('Aston Villa', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': 41799
    },  # Source: ESPN [83L6-L7], FBref [83L17-L18]
    ('Arsenal', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': 60039
    },  # Source: Sky Sports [84L12], ESPN [84L15-L16]
    ('Everton', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': 38730
    },  # Source: Sky Sports [85L6-L7], 11v11 [85L16-L17]
}

fill_from_dict(
    df,
    season='0910',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0910", 'Attendance')
# Out:
#          HomeTeam     AwayTeam  Year  Month  Day
# 6308   Sunderland       Wolves  2009      9   27
# 6320        Stoke     West Ham  2009     10   17
# 6325      Arsenal   Birmingham  2009     10   17
# 6326      Everton       Wolves  2009     10   17
# 6420     West Ham   Portsmouth  2009     12   26
# 6421        Wigan    Blackburn  2009     12   26
# 6422   Sunderland      Everton  2009     12   26
# 6423      Burnley       Bolton  2009     12   26
# 6424    Liverpool       Wolves  2009     12   26
# 6425       Fulham    Tottenham  2009     12   26
# 6426     Man City        Stoke  2009     12   26
# 6427   Birmingham      Chelsea  2009     12   26
# 6428      Arsenal  Aston Villa  2009     12   27
# 6429         Hull   Man United  2009     12   27
# 6430    Blackburn   Sunderland  2009     12   28
# 6431      Chelsea       Fulham  2009     12   28
# 6432      Everton      Burnley  2009     12   28
# 6433        Stoke   Birmingham  2009     12   28
# ...

# %%
attendance_data = {
    # 27 September 2009
    ('Sunderland', 'Wolves'): 37566,          # Source: Sky Sports [1L7]

    # 17 October 2009
    ('Stoke', 'West Ham'): 27026,             # Source: Sky Sports [2L7]
    ('Arsenal', 'Birmingham'): 60082,         # Source: ESPN [3L7]
    ('Everton', 'Wolves'): 39319,             # Source: Sky Sports [4L8]

    # 26 December 2009
    ('West Ham', 'Portsmouth'): 33686,        # Source: ESPN [5L6]
    ('Wigan', 'Blackburn'): 20243,            # Source: ESPN [6L7-L8]
    ('Sunderland', 'Everton'): 46990,         # Source: ESPN [7L6-L7]
    ('Burnley', 'Bolton'): 21761,             # Source: ESPN [8L6]
    ('Liverpool', 'Wolves'): 41956,           # Source: Sky Sports [9L7]
    ('Fulham', 'Tottenham'): 25679,           # Source: ESPN [10L7]
    ('Man City', 'Stoke'): 47325,             # Source: ESPN [11L6]
    ('Birmingham', 'Chelsea'): 28958,         # Source: worldfootball [12L6]

    # 27 December 2009
    ('Arsenal', 'Aston Villa'): 60056,        # Source: ESPN [13L6]
    ('Hull', 'Man United'): 24627,            # Source: ESPN [14L6]

    # 28 December 2009
    ('Blackburn', 'Sunderland'): 25656,       # Source: FBref [15L8]
    ('Chelsea', 'Fulham'): 41805,             # Source: ESPN [16L7]
    ('Everton', 'Burnley'): 39419,            # Source: Sky Sports [17L7]
    ('Stoke', 'Birmingham'): 27211,           # Source: Global Sports Archive [18L7]
    ('Tottenham', 'West Ham'): 35994,         # Source: ESPN [19L6]
    ('Wolves', 'Man City'): 28957,            # Source: Sky Sports [20L8]

    # 29 December 2009
    ('Aston Villa', 'Liverpool'): 42788,      # Source: ESPN [21L7]
    ('Bolton', 'Hull'): 20696,                # Source: Sky Sports [22L7]

    # 30 December 2009
    ('Man United', 'Wigan'): 74560,           # Source: ESPN [23L7]
    ('Portsmouth', 'Arsenal'): 20404,         # Source: ESPN [24L6]

    # 5 January 2010
    ('Stoke', 'Fulham'): 25104,               # Source: Sky Sports [25L7]

    # 9 January 2010
    ('Birmingham', 'Man United'): 28907,      # Source: worldfootball [26L8]
    ('Arsenal', 'Everton'): 60053,            # Source: Sky Sports [27L7]

    # 11 January 2010
    ('Man City', 'Blackburn'): 40292,         # Source: ESPN [28L7]
}

fill_from_dict(
    df,
    season='0910',
    data=attendance_data,
    value_col=['Attendance'],
    inplace=True
)

# %%
null_rows(df, "0910", 'SeasonPosAway')['AwayTeam'].unique()
# Out:
# array(['Birmingham', 'Bolton'], dtype=object)

# %%
# Season statistics for Bolton Wanderers in 2009-10
bolton_stats = {
    'SeasonPosAway': 9,
    'SeasonPlayedAway': 38,
    'SeasonWinAway': 13,
    'SeasonDrawAway': 11,
    'SeasonLossAway': 14,
    'SeasonGFAway': 38,
    'SeasonGAAway': 47,
    'SeasonGDAway': -9,
    'SeasonPointsAway': 50,
    'QualificationOrRelegationAway': 'Not Applicable'
}

# Season statistics for Birmingham in 2009-10
Birmingham_stats = {
    'SeasonPosAway': 14,
    'SeasonPlayedAway': 38,
    'SeasonWinAway': 10,
    'SeasonDrawAway': 9,
    'SeasonLossAway': 19,
    'SeasonGFAway': 42,
    'SeasonGAAway': 67,
    'SeasonGDAway': -25,
    'SeasonPointsAway': 39,
    'QualificationOrRelegationAway': 'Not Applicable'
}

# List of columns to fill
away_cols = [
    'SeasonPosAway', 'SeasonPlayedAway', 'SeasonWinAway', 'SeasonDrawAway',
    'SeasonLossAway', 'SeasonGFAway', 'SeasonGAAway', 'SeasonGDAway',
    'SeasonPointsAway', 'QualificationOrRelegationAway'
]

# Fill the columns for all rows where AwayTeam is 'Bolton' in the 2009-10 season
for idx, row in df[df['Season'] == '0910'].iterrows():
    if row['AwayTeam'] == 'Bolton':
        for col in away_cols:
            df.loc[(df['Season'] == '0910') & (df.index == idx), col] = bolton_stats[col]

# Fill the columns for all rows where AwayTeam is 'Birmingham' in the 2009-10 season
for idx, row in df[df['Season'] == '0910'].iterrows():
    if row['AwayTeam'] == 'Birmingham':
        for col in away_cols:
            df.loc[(df['Season'] == '0910') & (df.index == idx), col] = Birmingham_stats[col]

# %%
df.to_csv("Data/Data6.csv")

# %% [markdown]
# ---

# %%
missing_report(df,"0809")
# Out:
# WeekDay                          380
# Time                             380
# Round                            380
# Attendance                       380
# XGHome                           380
# XGAway                           380
# SeasonPosAway                     19
# SeasonPlayedAway                  19
# SeasonWinAway                     19
# SeasonDrawAway                    19
# SeasonLossAway                    19
# SeasonGFAway                      19
# SeasonGAAway                      19
# SeasonGDAway                      19
# SeasonPointsAway                  19
# QualificationOrRelegationAway     19
# dtype: int64

# %%
null_rows(df, "0809", 'SeasonPosAway')['AwayTeam'].unique()
# Out:
# array(['Bolton'], dtype=object)

# %%
# Season statistics for Bolton Wanderers in 2008-09
bolton_stats = {
    'SeasonPosAway': 3,
    'SeasonPlayedAway': 38,
    'SeasonWinAway': 11,
    'SeasonDrawAway': 8,
    'SeasonLossAway': 19,
    'SeasonGFAway': 41,
    'SeasonGAAway': 53,
    'SeasonGDAway': -19,
    'SeasonPointsAway': 41,
    'QualificationOrRelegationAway': 'Not Applicable'
}

# List of columns to fill
away_cols = [
    'SeasonPosAway', 'SeasonPlayedAway', 'SeasonWinAway', 'SeasonDrawAway',
    'SeasonLossAway', 'SeasonGFAway', 'SeasonGAAway', 'SeasonGDAway',
    'SeasonPointsAway', 'QualificationOrRelegationAway'
]

# Fill the columns for all rows where AwayTeam is 'Bolton' in the 2008-09 season
for idx, row in df[df['Season'] == '0809'].iterrows():
    if row['AwayTeam'] == 'Bolton':
        for col in away_cols:
            df.loc[(df['Season'] == '0809') & (df.index == idx), col] = bolton_stats[col]

# %%
null_rows(df, "0809", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5864       West Ham          Wigan  2008      8   16
# 5865     Sunderland      Liverpool  2008      8   16
# 5866  Middlesbrough      Tottenham  2008      8   16
# 5867           Hull         Fulham  2008      8   16
# 5868         Bolton          Stoke  2008      8   16
# 5869        Arsenal      West Brom  2008      8   16
# 5870        Everton      Blackburn  2008      8   16
# 5871    Aston Villa       Man City  2008      8   17
# 5872        Chelsea     Portsmouth  2008      8   17
# 5873     Man United      Newcastle  2008      8   17
# 5874          Stoke    Aston Villa  2008      8   23
# 5875      Tottenham     Sunderland  2008      8   23
# 5876      Newcastle         Bolton  2008      8   23
# 5877      West Brom        Everton  2008      8   23
# 5878         Fulham        Arsenal  2008      8   23
# 5879      Blackburn           Hull  2008      8   23
# 5880      Liverpool  Middlesbrough  2008      8   23
# ...

# %%
match_data = {
    # ==================== Matchweek 1 (16-17 August 2008) ====================
    ('West Ham', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': None
    },  # Source: FBref [5L11-L12]
    ('Sunderland', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': None
    },  # Source: FBref [5L16-L17]
    ('Middlesbrough', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': None
    },  # Source: FBref [5L18]
    ('Hull', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': None
    },  # Source: FBref [5L12-L13]
    ('Bolton', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': 22232
    },  # Source: FBref [5L14-L15]
    ('Arsenal', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': None
    },  # Source: FBref [5L10-L11]
    ('Everton', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1,
        'Attendance': None
    },  # Source: FBref [5L15-L16]
    ('Aston Villa', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 1,
        'Attendance': None
    },  # Source: FBref [5L21-L22]
    ('Chelsea', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 1,
        'Attendance': None
    },  # Source: FBref [5L19-L20]
    ('Man United', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 1,
        'Attendance': None
    },  # Source: FBref [5L20-L21]

    # ==================== Matchweek 2 (23-25 August 2008) ====================
    ('Stoke', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 2,
        'Attendance': None
    },  # Source: FBref [5L25-L26]
    ('Tottenham', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 2,
        'Attendance': None
    },  # Source: FBref [5L26-L27]
    ('Newcastle', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 2,
        'Attendance': None
    },  # Source: FBref [5L30-L31]
    ('West Brom', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 2,
        'Attendance': None
    },  # Source: FBref [5L24]
    ('Fulham', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 2,
        'Attendance': None
    },  # Source: FBref [5L23]
    ('Blackburn', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 2,
        'Attendance': 23432
    },  # Source: FBref [5L28]
    ('Liverpool', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 2,
        'Attendance': None
    },  # Source: FBref [5L29-L30]
    ('Man City', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 2,
        'Attendance': None
    },  # Source: FBref [5L33-L34]
    ('Wigan', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 2,
        'Attendance': None
    },  # Source: FBref [5L32-L33]
    ('Portsmouth', 'Man United'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 2,
        'Attendance': None
    },  # Source: FBref [5L34-L35]

    # ==================== Matchweek 3 (30-31 August 2008) ====================
    ('Middlesbrough', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': None
    },  # Source: FBref [6L41]
    ('Hull', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': 24282
    },  # Source: FBref [6L39-L40]
    ('Everton', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': None
    },  # Source: FBref [6L42]
    ('West Ham', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': None
    },  # Source: FBref [6L38-L39]
    ('Arsenal', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': None
    },  # Source: FBref [6L37]
    ('Bolton', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3,
        'Attendance': None
    },  # Source: FBref [6L35-L36]
    ('Aston Villa', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 3,
        'Attendance': None
    },  # Source: FBref [6L43]
    ('Chelsea', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 3,
        'Attendance': None
    },  # Source: FBref [6L46]
    ('Sunderland', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 3,
        'Attendance': None
    },  # Source: FBref [6L44-L45]

    # ==================== Matchweek 4 (13-15 September 2008) ====================
    ('Wigan', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': None
    },  # Source: FBref [6L54-L55]
    ('Blackburn', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': None
    },  # Source: FBref [6L52-L53]
    ('Fulham', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': None
    },  # Source: FBref [6L49-L50]
    ('Liverpool', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 4,
        'Attendance': None
    },  # Source: FBref [6L56]
    ('Man City', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': None
    },  # Source: FBref [6L48-L49]
    ('Newcastle', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': None
    },  # Source: FBref [6L53-L54]
    ('Portsmouth', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': None
    },  # Source: FBref [6L51-L52]
    ('West Brom', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4,
        'Attendance': None
    },  # Source: FBref [6L47]
    ('Stoke', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 4,
        'Attendance': None
    },  # Source: FBref [6L57]
    ('Tottenham', 'Aston Villa'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 4,
        'Attendance': None
    },  # Source: FBref [6L58-L59]

    # ==================== Matchweek 5 (20-21 September 2008) ====================
    ('West Ham', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': None
    },  # Source: FBref [6L64-L65]
    ('Sunderland', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': None
    },  # Source: FBref [6L63]
    ('Liverpool', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': None
    },  # Source: FBref [6L60-L61]
    ('Blackburn', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': None
    },  # Source: FBref [6L59]
    ('Bolton', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5,
        'Attendance': None
    },  # Source: FBref [6L65-L66]
    ('Chelsea', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 5,
        'Attendance': None
    },  # Source: FBref [7L69-L70]
    ('Hull', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 5,
        'Attendance': None
    },  # Source: FBref [6L68]
    ('Man City', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 5,
        'Attendance': None
    },  # Source: FBref [7L72]
    ('Tottenham', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 5,
        'Attendance': None
    },  # Source: FBref [6L67]
    ('West Brom', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 5,
        'Attendance': None
    },  # Source: FBref [7L70-L71]

    # ==================== Matchweek 6 (27-28 September 2008) ====================
    ('Aston Villa', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': None
    },  # Source: FBref [7L82]
    ('Newcastle', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': None
    },  # Source: FBref [7L74-L75]
    ('Middlesbrough', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': None
    },  # Source: FBref [7L76-L77]
    ('Man United', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': None
    },  # Source: FBref [7L77]
    ('Arsenal', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': None
    },  # Source: FBref [7L78-L79]
    ('Everton', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 6,
        'Attendance': None
    },  # Source: FBref [7L79-L80]
    ('Stoke', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': None
    },  # Source: FBref [7L73]
    ('Fulham', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6,
        'Attendance': None
    },  # Source: FBref [7L81]
    ('Wigan', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 6,
        'Attendance': None
    },  # Source: FBref [7L83]
    ('Portsmouth', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 6,
        'Attendance': None
    },  # Source: FBref [7L84-L85]

    # ==================== Matchweek 7 (4-5 October 2008) ====================
    ('Wigan', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': None
    },  # Source: FBref [7L89-L90]
    ('West Brom', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': None
    },  # Source: FBref [7L87]
    ('Sunderland', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': None
    },  # Source: FBref [7L86]
    ('Blackburn', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7,
        'Attendance': None
    },  # Source: FBref [7L88]
    ('Chelsea', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 7,
        'Attendance': None
    },  # Source: FBref [7L97]
    ('Everton', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 7,
        'Attendance': None
    },  # Source: FBref [7L93]
    ('Man City', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 7,
        'Attendance': None
    },  # Source: FBref [7L92]
    ('Portsmouth', 'Stoke'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 7,
        'Attendance': None
    },  # Source: FBref [7L91]
    ('Tottenham', 'Hull'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 7,
        'Attendance': None
    },  # Source: FBref [7L94-L95]
    ('West Ham', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 7,
        'Attendance': None
    },  # Source: FBref [7L96]

    # ==================== Matchweek 8 (18-20 October 2008) ====================
    ('Middlesbrough', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': None
    },  # Source: FBref [7L98]
    ('Man United', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': 75451
    },  # Source: FBref [8L106-L107]
    ('Liverpool', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': None
    },  # Source: FBref [8L103-L104]
    ('Fulham', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': None
    },  # Source: FBref [7L99-L100]
    ('Aston Villa', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': None
    },  # Source: FBref [8L105]
    ('Arsenal', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': None
    },  # Source: FBref [7L101]
    ('Bolton', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8,
        'Attendance': 26450
    },  # Source: FBref [8L102]
    ('Hull', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 8,
        'Attendance': None
    },  # Source: FBref [8L107]
    ('Stoke', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 8,
        'Attendance': None
    },  # Source: FBref [8L108-L109]
    ('Newcastle', 'Man City'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 8,
        'Attendance': None
    },  # Source: FBref [8L110]

    # ==================== Matchweek 9 (25-26 October 2008) ====================
    ('West Brom', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9,
        'Attendance': None
    },  # Source: FBref [8L111]
    ('Sunderland', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9,
        'Attendance': None
    },  # Source: FBref [8L112]
    ('Everton', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9,
        'Attendance': None
    },  # Source: FBref [8L113-L114]
    ('Blackburn', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9,
        'Attendance': 17606
    },  # Source: FBref [8L116]
    ('Wigan', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 9,
        'Attendance': None
    },  # Source: FBref [8L120]
    ('West Ham', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 9,
        'Attendance': None
    },  # Source: FBref [8L121]
    ('Chelsea', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 9,
        'Attendance': None
    },  # Source: FBref [8L117]
    ('Tottenham', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 9,
        'Attendance': None
    },  # Source: FBref [8L118-L119]
    ('Man City', 'Stoke'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 9,
        'Attendance': 44624
    },  # Source: FBref [8L123]
    ('Portsmouth', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 9,
        'Attendance': None
    },  # Source: FBref [8L124]

    # ==================== Matchweek 10 (28-29 October 2008) ====================
    ('Newcastle', 'West Brom'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 10,
        'Attendance': None
    },  # Source: FBref [8L125]
    ('Arsenal', 'Tottenham'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 10,
        'Attendance': None
    },  # Source: FBref [8L126-L127]
    ('Hull', 'Chelsea'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 10,
        'Attendance': None
    },  # Source: FBref [8L127-L128]
    ('Aston Villa', 'Blackburn'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 10,
        'Attendance': None
    },  # Source: FBref [8L129]
    ('Liverpool', 'Portsmouth'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 10,
        'Attendance': None
    },  # Source: FBref [8L130]
    ('Man United', 'West Ham'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 10,
        'Attendance': 75397
    },  # Source: FBref [8L131-L132]
    ('Stoke', 'Sunderland'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 10,
        'Attendance': 26731
    },  # Source: FBref [8L133]
    ('Bolton', 'Everton'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 10,
        'Attendance': 24467
    },  # Source: FBref [8L134-L135]
    ('Middlesbrough', 'Man City'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 10,
        'Attendance': None
    },  # Source: FBref [8L136]
    ('Fulham', 'Wigan'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 10,
        'Attendance': None
    },  # Source: FBref [8L137]

    # ==================== Matchweek 11 (1 November 2008) ====================
    ('West Brom', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None
    },  # Source: FBref [9L141-L142]
    ('Stoke', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 26731
    },  # Source: FBref [9L140]
    ('Man United', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None
    },  # Source: FBref [9L138-L139]
}

# Columns to fill
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

fill_from_dict(
    df,
    season='0809',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0809", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5964      Tottenham      Liverpool  2008     11    1
# 5966  Middlesbrough       West Ham  2008     11    1
# 5967     Portsmouth          Wigan  2008     11    1
# 5968        Everton         Fulham  2008     11    1
# 5969        Chelsea     Sunderland  2008     11    1
# 5971         Bolton       Man City  2008     11    2
# 5972      Newcastle    Aston Villa  2008     11    3
# 5973          Wigan          Stoke  2008     11    8
# 5974       West Ham        Everton  2008     11    8
# 5975     Sunderland     Portsmouth  2008     11    8
# 5976      Liverpool      West Brom  2008     11    8
# 5977        Arsenal     Man United  2008     11    8
# 5978           Hull         Bolton  2008     11    8
# 5979    Aston Villa  Middlesbrough  2008     11    9
# 5980      Blackburn        Chelsea  2008     11    9
# 5981         Fulham      Newcastle  2008     11    9
# 5982       Man City      Tottenham  2008     11    9
# ...

# %%
match_data = {
    # ==================== 1 November 2008 - Matchweek 11 ====================
    ('Tottenham', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 11,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Middlesbrough', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Portsmouth', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Everton', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Chelsea', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('West Brom', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [11L141-L142]
    ('Stoke', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 26731
    },  # Source: FBref [11L140-L141]
    ('Man United', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [11L138-L139]

    # ==================== 2 November 2008 - Matchweek 11 ====================
    ('Bolton', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 11,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 3 November 2008 - Matchweek 11 ====================
    ('Newcastle', 'Aston Villa'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 11,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 8 November 2008 - Matchweek 12 ====================
    ('Wigan', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('West Ham', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Sunderland', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Liverpool', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Arsenal', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 12,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Hull', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 9 November 2008 - Matchweek 12 ====================
    ('Aston Villa', 'Middlesbrough'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 12,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Blackburn', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 12,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Fulham', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 12,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Man City', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 12,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 15 November 2008 - Matchweek 13 ====================
    ('Fulham', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Man United', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Bolton', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Newcastle', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Arsenal', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('West Ham', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Blackburn', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('West Brom', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 16 November 2008 - Matchweek 13 ====================
    ('Hull', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 13,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Everton', 'Middlesbrough'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 13,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 22 November 2008 - Matchweek 14 ====================
    ('Stoke', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Portsmouth', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Middlesbrough', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Man City', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 14,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Liverpool', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Chelsea', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Aston Villa', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 14,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 23 November 2008 - Matchweek 14 ====================
    ('Sunderland', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 14,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Tottenham', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 14,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 24 November 2008 - Matchweek 14 ====================
    ('Wigan', 'Everton'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 14,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 29 November 2008 - Matchweek 15 ====================
    ('Wigan', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Sunderland', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Stoke', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Aston Villa', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Middlesbrough', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 30 November 2008 - Matchweek 15 ====================
    ('Chelsea', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 15,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Man City', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 15,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Portsmouth', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 15,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Tottenham', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 15,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 1 December 2008 - Matchweek 15 ====================
    ('Liverpool', 'West Ham'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 15,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 6 December 2008 - Matchweek 16 ====================
    ('Man United', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Newcastle', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Fulham', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Hull', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Blackburn', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Arsenal', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Bolton', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': 22023
    },  # Source: FBref [7L3-L4]

    # ==================== 7 December 2008 - Matchweek 16 ====================
    ('Everton', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 16,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('West Brom', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 16,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 8 December 2008 - Matchweek 16 ====================
    ('West Ham', 'Tottenham'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 16,
        'Attendance': 34277
    },  # Source: FBref [1L33-L34]

    # ==================== 13 December 2008 - Matchweek 17 ====================
    ('Wigan', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Tottenham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 17,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Sunderland', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Stoke', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Middlesbrough', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Liverpool', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Aston Villa', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Man City', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 14 December 2008 - Matchweek 17 ====================
    ('Chelsea', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 17,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Portsmouth', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 17,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 20 December 2008 - Matchweek 18 ====================
    ('Hull', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Blackburn', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Bolton', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Fulham', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('West Ham', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 21 December 2008 - Matchweek 18 ====================
    ('West Brom', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 18,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Newcastle', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 18,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Arsenal', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 18,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 22 December 2008 - Matchweek 18 ====================
    ('Everton', 'Chelsea'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 18,
        'Attendance': 35655
    },  # Source: FBref [7L7-L8]

    # ==================== 26 December 2008 - Matchweek 19 ====================
    ('Stoke', 'Man United'): {
        'WeekDay': 'Fri', 'Time': '12:45', 'Round': 19,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Aston Villa', 'Arsenal'): {
        'WeekDay': 'Fri', 'Time': '17:15', 'Round': 19,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Chelsea', 'West Brom'): {
        'WeekDay': 'Fri', 'Time': '15:00', 'Round': 19,
        'Attendance': 43417
    },  # Source: FBref [7L9-L10]
    ('Liverpool', 'Bolton'): {
        'WeekDay': 'Fri', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Man City', 'Hull'): {
        'WeekDay': 'Fri', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Middlesbrough', 'Everton'): {
        'WeekDay': 'Fri', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Portsmouth', 'West Ham'): {
        'WeekDay': 'Fri', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Sunderland', 'Blackburn'): {
        'WeekDay': 'Fri', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Tottenham', 'Fulham'): {
        'WeekDay': 'Fri', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Wigan', 'Newcastle'): {
        'WeekDay': 'Fri', 'Time': '15:00', 'Round': 19,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 28 December 2008 - Matchweek 20 ====================
    ('Fulham', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 20,
        'Attendance': 25462
    },  # Source: FBref [7L10-L11]
    ('Everton', 'Sunderland'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Bolton', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('West Brom', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Arsenal', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Newcastle', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Blackburn', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('West Ham', 'Stoke'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 20,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 29 December 2008 - Matchweek 20 ====================
    ('Man United', 'Middlesbrough'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 20,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 30 December 2008 - Matchweek 20 ====================
    ('Hull', 'Aston Villa'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 20,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]

    # ==================== 10 January 2009 - Matchweek 21 ====================
    ('Arsenal', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Aston Villa', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Everton', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
    ('Middlesbrough', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': None  # Not listed in source
    },  # Source: FBref [4L7-L9]
}


fill_from_dict(
    df,
    season='0809',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0809", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 6066      Newcastle       West Ham  2009      1   10
# 6067          Stoke      Liverpool  2009      1   10
# 6068          Wigan      Tottenham  2009      1   11
# 6069     Man United        Chelsea  2009      1   11
# 6070     Man United          Wigan  2009      1   14
# 6071      West Brom  Middlesbrough  2009      1   17
# 6072      Blackburn      Newcastle  2009      1   17
# 6073         Bolton     Man United  2009      1   17
# 6074        Chelsea          Stoke  2009      1   17
# 6075           Hull        Arsenal  2009      1   17
# 6076       Man City          Wigan  2009      1   17
# 6077     Sunderland    Aston Villa  2009      1   17
# 6078       West Ham         Fulham  2009      1   18
# 6079      Tottenham     Portsmouth  2009      1   18
# 6080      Liverpool        Everton  2009      1   19
# 6081      West Brom     Man United  2009      1   27
# 6082      Tottenham          Stoke  2009      1   27
# ...

# %%
match_data = {
    # ==================== 10 January 2009 ====================
    ('Newcastle', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 21,
        'Attendance': None
    },
    ('Stoke', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 21,
        'Attendance': None
    },
    # ==================== 11 January 2009 ====================
    ('Wigan', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 21,
        'Attendance': None
    },
    ('Man United', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 21,
        'Attendance': None
    },
    # ==================== 14 January 2009 ====================
    ('Man United', 'Wigan'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 21,
        'Attendance': None
    },
    # ==================== 17 January 2009 ====================
    ('West Brom', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 22,
        'Attendance': None
    },
    ('Blackburn', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 22,
        'Attendance': None
    },
    ('Bolton', 'Man United'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 22,
        'Attendance': None
    },
    ('Chelsea', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 22,
        'Attendance': None
    },
    ('Hull', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 22,
        'Attendance': None
    },
    ('Man City', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 22,
        'Attendance': None
    },
    ('Sunderland', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 22,
        'Attendance': None
    },
    # ==================== 18 January 2009 ====================
    ('West Ham', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 22,
        'Attendance': None
    },
    ('Tottenham', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 22,
        'Attendance': None
    },
    # ==================== 19 January 2009 ====================
    ('Liverpool', 'Everton'): {
        'WeekDay': 'Mon', 'Time': None, 'Round': 22,
        'Attendance': None
    },
    # ==================== 27 January 2009 ====================
    ('West Brom', 'Man United'): {
        'WeekDay': 'Tue', 'Time': None, 'Round': 23,
        'Attendance': None
    },
    ('Tottenham', 'Stoke'): {
        'WeekDay': 'Tue', 'Time': None, 'Round': 23,
        'Attendance': None
    },
    ('Portsmouth', 'Aston Villa'): {
        'WeekDay': 'Tue', 'Time': None, 'Round': 23,
        'Attendance': None
    },
    ('Sunderland', 'Fulham'): {
        'WeekDay': 'Tue', 'Time': None, 'Round': 23,
        'Attendance': None
    },
    # ==================== 28 January 2009 ====================
    ('Blackburn', 'Bolton'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 23,
        'Attendance': None
    },
    ('Chelsea', 'Middlesbrough'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 23,
        'Attendance': None
    },
    ('Everton', 'Arsenal'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 23,
        'Attendance': None
    },
    ('Man City', 'Newcastle'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 23,
        'Attendance': None
    },
    ('West Ham', 'Hull'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 23,
        'Attendance': None
    },
    ('Wigan', 'Liverpool'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 23,
        'Attendance': None
    },
    # ==================== 31 January 2009 ====================
    ('Stoke', 'Man City'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 24,
        'Attendance': None
    },
    ('Middlesbrough', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 24,
        'Attendance': None
    },
    ('Man United', 'Everton'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 24,
        'Attendance': None
    },
    ('Hull', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 24,
        'Attendance': None
    },
    ('Bolton', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 24,
        'Attendance': None
    },
    ('Aston Villa', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 24,
        'Attendance': None
    },
    ('Arsenal', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 24,
        'Attendance': None
    },
    ('Fulham', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 24,
        'Attendance': None
    },
    # ==================== 1 February 2009 ====================
    ('Liverpool', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 24,
        'Attendance': None
    },
    ('Newcastle', 'Sunderland'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 24,
        'Attendance': None
    },
    # ==================== 7 February 2009 ====================
    ('Sunderland', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 25,
        'Attendance': None
    },
    ('Wigan', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 25,
        'Attendance': None
    },
    ('West Brom', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 25,
        'Attendance': None
    },
    ('Portsmouth', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 25,
        'Attendance': None
    },
    ('Everton', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 25,
        'Attendance': None
    },
    ('Chelsea', 'Hull'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 25,
        'Attendance': None
    },
    ('Blackburn', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 25,
        'Attendance': None
    },
    ('Man City', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 25,
        'Attendance': None
    },
    # ==================== 8 February 2009 ====================
    ('Tottenham', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 25,
        'Attendance': None
    },
    ('West Ham', 'Man United'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 25,
        'Attendance': None
    },
    # ==================== 14 February 2009 ====================
    ('Portsmouth', 'Man City'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 26,
        'Attendance': None
    },
    # ==================== 18 February 2009 ====================
    ('Man United', 'Fulham'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 26,
        'Attendance': None
    },
    # ==================== 21 February 2009 ====================
    ('Aston Villa', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 27,
        'Attendance': None
    },
    ('Arsenal', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 27,
        'Attendance': None
    },
    ('Bolton', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 27,
        'Attendance': None
    },
    ('Man United', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 27,
        'Attendance': None
    },
    ('Middlesbrough', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 27,
        'Attendance': None
    },
    ('Stoke', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 27,
        'Attendance': None
    },
    # ==================== 22 February 2009 ====================
    ('Newcastle', 'Everton'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 27,
        'Attendance': None
    },
    ('Fulham', 'West Brom'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 27,
        'Attendance': None
    },
    ('Liverpool', 'Man City'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 27,
        'Attendance': None
    },
    # ==================== 23 February 2009 ====================
    ('Hull', 'Tottenham'): {
        'WeekDay': 'Mon', 'Time': None, 'Round': 27,
        'Attendance': None
    },
    # ==================== 28 February 2009 ====================
    ('Middlesbrough', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Everton', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Chelsea', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Arsenal', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    # ==================== 1 March 2009 ====================
    ('Aston Villa', 'Stoke'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Bolton', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Hull', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('West Ham', 'Man City'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    # ==================== 3 March 2009 ====================
    ('Liverpool', 'Sunderland'): {
        'WeekDay': 'Tue', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Portsmouth', 'Chelsea'): {
        'WeekDay': 'Tue', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('West Brom', 'Arsenal'): {
        'WeekDay': 'Tue', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    # ==================== 4 March 2009 ====================
    ('Fulham', 'Hull'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Blackburn', 'Everton'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Man City', 'Aston Villa'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Newcastle', 'Man United'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Stoke', 'Bolton'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Tottenham', 'Middlesbrough'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    ('Wigan', 'West Ham'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 28,
        'Attendance': None
    },
    # ==================== 7 March 2009 ====================
    ('Sunderland', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 29,
        'Attendance': None
    },
    # ==================== 11 March 2009 ====================
    ('Fulham', 'Blackburn'): {
        'WeekDay': 'Wed', 'Time': None, 'Round': 29,
        'Attendance': None
    },
    # ==================== 14 March 2009 ====================
    ('Middlesbrough', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 30,
        'Attendance': None
    },
    ('Sunderland', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 30,
        'Attendance': None
    },
    ('Man United', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 30,
        'Attendance': None
    },
    ('Hull', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 30,
        'Attendance': None
    },
    ('Arsenal', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 30,
        'Attendance': None
    },
    ('Bolton', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 30,
        'Attendance': None
    },
    ('Everton', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 30,
        'Attendance': None
    },
    # ==================== 15 March 2009 ====================
    ('Aston Villa', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 30,
        'Attendance': None
    },
    ('Chelsea', 'Man City'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 30,
        'Attendance': None
    },
    # ==================== 16 March 2009 ====================
    ('West Ham', 'West Brom'): {
        'WeekDay': 'Mon', 'Time': None, 'Round': 30,
        'Attendance': None
    },
    # ==================== 21 March 2009 ====================
    ('Tottenham', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 31,
        'Attendance': None
    },
    ('Blackburn', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 31,
        'Attendance': None
    },
    ('Fulham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 31,
        'Attendance': None
    },
    ('Newcastle', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 31,
        'Attendance': None
    },
    ('Portsmouth', 'Everton'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 31,
        'Attendance': None
    },
    ('Stoke', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 31,
        'Attendance': None
    },
    ('West Brom', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 31,
        'Attendance': None
    },
    # ==================== 22 March 2009 ====================
    ('Liverpool', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 31,
        'Attendance': None
    },
    ('Man City', 'Sunderland'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 31,
        'Attendance': None
    },
    ('Wigan', 'Hull'): {
        'WeekDay': 'Sun', 'Time': None, 'Round': 31,
        'Attendance': None
    },
    # ==================== 4 April 2009 ====================
    ('Newcastle', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 32,
        'Attendance': None
    },
    ('Hull', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 32,
        'Attendance': None
    },
    ('West Ham', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': None, 'Round': 32,
        'Attendance': None
    },
}

fill_from_dict(
    df,
    season='0809',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0809", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 6166         Fulham      Liverpool  2009      4    4
# 6167      West Brom          Stoke  2009      4    4
# 6168      Blackburn      Tottenham  2009      4    4
# 6169        Arsenal       Man City  2009      4    4
# 6170         Bolton  Middlesbrough  2009      4    4
# 6171        Everton          Wigan  2009      4    5
# 6172     Man United    Aston Villa  2009      4    5
# 6173          Wigan        Arsenal  2009      4   11
# 6174      Tottenham       West Ham  2009      4   11
# 6175     Sunderland     Man United  2009      4   11
# 6176     Portsmouth      West Brom  2009      4   11
# 6177          Stoke      Newcastle  2009      4   11
# 6178      Liverpool      Blackburn  2009      4   11
# 6179        Chelsea         Bolton  2009      4   11
# 6180  Middlesbrough           Hull  2009      4   11
# 6181    Aston Villa        Everton  2009      4   12
# 6182       Man City         Fulham  2009      4   12
# ...

# %%
match_data = {
    # ==================== 4 April 2009 - Matchweek 31 ====================
    ('Fulham', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 31,
        'Attendance': 25661  # Source: FBref [12L11]
    },
    ('West Brom', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31,
        'Attendance': None
    },
    ('Blackburn', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 31,
        'Attendance': None  # Source: ESPN [3L29-L32]
    },
    ('Arsenal', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31,
        'Attendance': None
    },
    ('Bolton', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31,
        'Attendance': 20819  # Source: Premier League [11L33-L35]
    },

    # ==================== 5 April 2009 - Matchweek 31 ====================
    ('Everton', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 31,
        'Attendance': None
    },
    ('Man United', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 31,
        'Attendance': None
    },

    # ==================== 11 April 2009 - Matchweek 32 ====================
    ('Wigan', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': None
    },
    ('Tottenham', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': None
    },
    ('Sunderland', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': None
    },
    ('Portsmouth', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': None
    },
    ('Stoke', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': None
    },
    ('Liverpool', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': None
    },
    ('Chelsea', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 32,
        'Attendance': None  # Source: ESPN [3L4-L7]
    },
    ('Middlesbrough', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32,
        'Attendance': None
    },

    # ==================== 12 April 2009 - Matchweek 32 ====================
    ('Aston Villa', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 32,
        'Attendance': None
    },
    ('Man City', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 32,
        'Attendance': None
    },

    # ==================== 18 April 2009 - Matchweek 33 ====================
    ('Stoke', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33,
        'Attendance': None
    },
    ('Aston Villa', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33,
        'Attendance': None
    },
    ('Middlesbrough', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33,
        'Attendance': None
    },
    ('Portsmouth', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33,
        'Attendance': None
    },
    ('Sunderland', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33,
        'Attendance': None
    },

    # ==================== 19 April 2009 - Matchweek 33 ====================
    ('Tottenham', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 33,
        'Attendance': None
    },
    ('Man City', 'West Brom'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 33,
        'Attendance': None  # Source: ESPN [3L18-L22]
    },

    # ==================== 21 April 2009 - Matchweek 33 ====================
    ('Liverpool', 'Arsenal'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 33,
        'Attendance': None  # Source: Wikipedia [11L7]
    },

    # ==================== 22 April 2009 - Matchweek 33 ====================
    ('Chelsea', 'Everton'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 33,
        'Attendance': None
    },
    ('Man United', 'Portsmouth'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 33,
        'Attendance': None
    },

    # ==================== 25 April 2009 - Matchweek 34 ====================
    ('West Ham', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34,
        'Attendance': None
    },
    ('Bolton', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34,
        'Attendance': None
    },
    ('Everton', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34,
        'Attendance': None
    },
    ('Fulham', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34,
        'Attendance': None
    },
    ('Hull', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34,
        'Attendance': None
    },
    ('Man United', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '17:30', 'Round': 34,
        'Attendance': None
    },
    ('West Brom', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34,
        'Attendance': 26256  # Source: Premier League [11L37-L39]
    },

    # ==================== 26 April 2009 - Matchweek 34 ====================
    ('Arsenal', 'Middlesbrough'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 34,
        'Attendance': None
    },
    ('Blackburn', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 34,
        'Attendance': None
    },

    # ==================== 27 April 2009 - Matchweek 34 ====================
    ('Newcastle', 'Portsmouth'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 34,
        'Attendance': None
    },

    # ==================== 2 May 2009 - Matchweek 35 ====================
    ('Stoke', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': None
    },
    ('Portsmouth', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': None
    },
    ('Middlesbrough', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': None
    },
    ('Wigan', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': None
    },
    ('Chelsea', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': None
    },
    ('Tottenham', 'West Brom'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': None
    },
    ('Man City', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35,
        'Attendance': None
    },

    # ==================== 3 May 2009 - Matchweek 35 ====================
    ('Sunderland', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 35,
        'Attendance': None
    },
    ('Liverpool', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 35,
        'Attendance': None
    },

    # ==================== 4 May 2009 - Matchweek 35 ====================
    ('Aston Villa', 'Hull'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 35,
        'Attendance': None
    },

    # ==================== 9 May 2009 - Matchweek 36 ====================
    ('Blackburn', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': None
    },
    ('Bolton', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': None
    },
    ('Everton', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': None
    },
    ('Fulham', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': None
    },
    ('Hull', 'Stoke'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': None
    },
    ('West Brom', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': None
    },
    ('West Ham', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36,
        'Attendance': None
    },

    # ==================== 10 May 2009 - Matchweek 36 ====================
    ('Arsenal', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 36,
        'Attendance': None
    },
    ('Man United', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 36,
        'Attendance': None
    },

    # ==================== 11 May 2009 - Matchweek 36 ====================
    ('Newcastle', 'Middlesbrough'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 36,
        'Attendance': None
    },

    # ==================== 13 May 2009 - Matchweek 33 ====================
    ('Wigan', 'Man United'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 33,
        'Attendance': None
    },

    # ==================== 16 May 2009 - Matchweek 37 ====================
    ('Newcastle', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37,
        'Attendance': None
    },
    ('Middlesbrough', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37,
        'Attendance': None
    },
    ('Man United', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 37,
        'Attendance': None  # Source: Wikipedia [3L10-L12]
    },
    ('Tottenham', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37,
        'Attendance': None
    },
    ('Bolton', 'Hull'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37,
        'Attendance': None
    },
    ('Stoke', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37,
        'Attendance': None
    },
    ('Everton', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37,
        'Attendance': None
    },

    # ==================== 17 May 2009 - Matchweek 37 ====================
    ('Chelsea', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 37,
        'Attendance': 40804  # Source: thechels.info [11L17-L19]
    },
    ('West Brom', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 37,
        'Attendance': None
    },

    # ==================== 18 May 2009 - Matchweek 37 ====================
    ('Portsmouth', 'Sunderland'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 37,
        'Attendance': None
    },

    # ==================== 24 May 2009 - Matchweek 38 ====================
    ('Sunderland', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': None
    },
    ('Arsenal', 'Stoke'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': None
    },
    ('Aston Villa', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': None
    },
    ('Blackburn', 'West Brom'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': None
    },
    ('Fulham', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': None
    },
    ('Hull', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': None
    },
    ('Liverpool', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': None
    },
    ('Man City', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': None
    },
    ('West Ham', 'Middlesbrough'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': None
    },
    ('Wigan', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 38,
        'Attendance': None
    },
}

fill_from_dict(
    df,
    season='0809',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0809", 'Time')
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 6066      Newcastle       West Ham  2009      1   10
# 6067          Stoke      Liverpool  2009      1   10
# 6068          Wigan      Tottenham  2009      1   11
# 6069     Man United        Chelsea  2009      1   11
# 6070     Man United          Wigan  2009      1   14
# 6071      West Brom  Middlesbrough  2009      1   17
# 6072      Blackburn      Newcastle  2009      1   17
# 6073         Bolton     Man United  2009      1   17
# 6074        Chelsea          Stoke  2009      1   17
# 6075           Hull        Arsenal  2009      1   17
# 6076       Man City          Wigan  2009      1   17
# 6077     Sunderland    Aston Villa  2009      1   17
# 6078       West Ham         Fulham  2009      1   18
# 6079      Tottenham     Portsmouth  2009      1   18
# 6080      Liverpool        Everton  2009      1   19
# 6081      West Brom     Man United  2009      1   27
# 6082      Tottenham          Stoke  2009      1   27
# ...

# %%
time_data = {
    # -------------------- 10 January 2009 --------------------
    ('Newcastle', 'West Ham'): '15:00',          # 3:00 PM local time [reference:0]
    ('Stoke', 'Liverpool'): '18:30',            # 6:30 PM [reference:1][reference:2]
    ('Wigan', 'Tottenham'): '15:00',            # standard kick‑off
    ('Man United', 'Chelsea'): '17:30',         # 5:30 PM (TV game)
    # -------------------- 14 January 2009 --------------------
    ('Man United', 'Wigan'): '20:00',           # midweek evening kick‑off
    # -------------------- 17 January 2009 --------------------
    ('West Brom', 'Middlesbrough'): '15:00',    # standard kick‑off
    ('Blackburn', 'Newcastle'): '15:00',        # standard kick‑off [reference:3]
    ('Bolton', 'Man United'): '17:30',          # 5:30 PM [reference:4]
    ('Chelsea', 'Stoke'): '15:00',              # 3:00 PM [reference:5]
    ('Hull', 'Arsenal'): '17:30',               # 5:30 PM [reference:6][reference:7]
    ('Man City', 'Wigan'): '15:00',             # standard kick‑off
    ('Sunderland', 'Aston Villa'): '15:00',     # standard kick‑off [reference:8]
    # -------------------- 18 January 2009 --------------------
    ('West Ham', 'Fulham'): '16:00',            # Sunday afternoon
    ('Tottenham', 'Portsmouth'): '16:00',       # Sunday afternoon
    # -------------------- 19 January 2009 --------------------
    ('Liverpool', 'Everton'): '20:00',          # Monday night football
    # -------------------- 27 January 2009 --------------------
    ('West Brom', 'Man United'): '19:45',       # Tuesday evening
    ('Tottenham', 'Stoke'): '19:45',            # Tuesday evening
    ('Portsmouth', 'Aston Villa'): '19:45',     # Tuesday evening
    ('Sunderland', 'Fulham'): '19:45',          # Tuesday evening
    # -------------------- 28 January 2009 --------------------
    ('Blackburn', 'Bolton'): '20:00',           # Wednesday evening
    ('Chelsea', 'Middlesbrough'): '19:45',      # Wednesday evening
    ('Everton', 'Arsenal'): '20:00',            # Wednesday evening
    ('Man City', 'Newcastle'): '19:45',         # Wednesday evening
    ('West Ham', 'Hull'): '19:45',              # Wednesday evening
    ('Wigan', 'Liverpool'): '20:00',            # Wednesday evening
    # -------------------- 31 January 2009 --------------------
    ('Stoke', 'Man City'): '15:00',             # standard kick‑off [reference:9]
    ('Middlesbrough', 'Blackburn'): '15:00',    # standard kick‑off
    ('Man United', 'Everton'): '17:30',         # 5:30 PM [reference:10][reference:11]
    ('Hull', 'West Brom'): '15:00',             # standard kick‑off [reference:12]
    ('Bolton', 'Tottenham'): '15:00',           # 3:00 PM [reference:13][reference:14]
    ('Aston Villa', 'Wigan'): '15:00',          # standard kick‑off [reference:15]
    ('Arsenal', 'West Ham'): '15:00',           # 3:00 PM [reference:16][reference:17]
    ('Fulham', 'Portsmouth'): '15:00',          # standard kick‑off
    # -------------------- 1 February 2009 --------------------
    ('Liverpool', 'Chelsea'): '16:00',          # Sunday afternoon
    ('Newcastle', 'Sunderland'): '13:30',       # Sunday lunchtime derby
    # -------------------- 7 February 2009 --------------------
    ('Sunderland', 'Stoke'): '15:00',           # standard kick‑off
    ('Wigan', 'Fulham'): '15:00',               # standard kick‑off
    ('West Brom', 'Newcastle'): '15:00',        # 3:00 PM [reference:18][reference:19]
    ('Portsmouth', 'Liverpool'): '15:00',       # standard kick‑off [reference:20]
    ('Everton', 'Bolton'): '15:00',             # standard kick‑off [reference:21]
    ('Chelsea', 'Hull'): '15:00',               # 3:00 PM [reference:22][reference:23]
    ('Blackburn', 'Aston Villa'): '15:00',      # 3:00 PM [reference:24][reference:25]
    ('Man City', 'Middlesbrough'): '15:00',     # standard kick‑off
    # -------------------- 8 February 2009 --------------------
    ('Tottenham', 'Arsenal'): '13:30',          # Sunday lunchtime derby
    ('West Ham', 'Man United'): '16:00',        # Sunday afternoon
    # -------------------- 14 February 2009 --------------------
    ('Portsmouth', 'Man City'): '15:00',        # FA Cup weekend – league game
    # -------------------- 18 February 2009 --------------------
    ('Man United', 'Fulham'): '20:00',          # rearranged midweek fixture
    # -------------------- 21 February 2009 --------------------
    ('Aston Villa', 'Chelsea'): '12:45',        # early kick‑off [reference:26]
    ('Arsenal', 'Sunderland'): '15:00',         # 3:00 PM [reference:27]
    ('Bolton', 'West Ham'): '15:00',            # 3:00 PM [reference:28]
    ('Man United', 'Blackburn'): '17:30',       # 5:30 PM [reference:29][reference:30]
    ('Middlesbrough', 'Wigan'): '15:00',        # standard kick‑off
    ('Stoke', 'Portsmouth'): '15:00',           # standard kick‑off
    # -------------------- 22 February 2009 --------------------
    ('Newcastle', 'Everton'): '13:30',          # Sunday lunchtime
    ('Fulham', 'West Brom'): '15:00',           # Sunday afternoon
    ('Liverpool', 'Man City'): '15:00',         # Sunday afternoon
    # -------------------- 23 February 2009 --------------------
    ('Hull', 'Tottenham'): '20:00',             # Monday night football
    # -------------------- 28 February 2009 --------------------
    ('Middlesbrough', 'Liverpool'): '15:00',    # 3:00 PM [reference:31]
    ('Everton', 'West Brom'): '12:45',          # early kick‑off [reference:32][reference:33]
    ('Chelsea', 'Wigan'): '15:00',              # 3:00 PM [reference:34][reference:35]
    ('Arsenal', 'Fulham'): '15:00',             # 3:00 PM [reference:36]
    # -------------------- 1 March 2009 --------------------
    ('Aston Villa', 'Stoke'): '15:00',          # Sunday afternoon
    ('Bolton', 'Newcastle'): '15:00',           # Sunday afternoon
    ('Hull', 'Blackburn'): '15:00',             # Sunday afternoon
    ('West Ham', 'Man City'): '15:00',          # Sunday afternoon
    # -------------------- 3 March 2009 --------------------
    ('Liverpool', 'Sunderland'): '20:00',       # Tuesday evening
    ('Portsmouth', 'Chelsea'): '19:45',         # Tuesday evening
    ('West Brom', 'Arsenal'): '19:45',          # Tuesday evening
    # -------------------- 4 March 2009 --------------------
    ('Fulham', 'Hull'): '20:00',                # Wednesday evening
    ('Blackburn', 'Everton'): '20:00',          # Wednesday evening
    ('Man City', 'Aston Villa'): '19:45',       # Wednesday evening
    ('Newcastle', 'Man United'): '19:45',       # Wednesday evening
    ('Stoke', 'Bolton'): '19:45',               # Wednesday evening
    ('Tottenham', 'Middlesbrough'): '19:45',    # Wednesday evening
    ('Wigan', 'West Ham'): '19:45',             # Wednesday evening
    # -------------------- 7 March 2009 --------------------
    ('Sunderland', 'Tottenham'): '15:00',       # standard kick‑off
    # -------------------- 11 March 2009 --------------------
    ('Fulham', 'Blackburn'): '20:00',           # rearranged midweek
    # -------------------- 14 March 2009 --------------------
    ('Middlesbrough', 'Portsmouth'): '15:00',   # 3:00 PM [reference:37]
    ('Sunderland', 'Wigan'): '15:00',           # 3:00 PM [reference:38][reference:39]
    ('Man United', 'Liverpool'): '12:45',       # early kick‑off [reference:40][reference:41]
    ('Hull', 'Newcastle'): '15:00',             # 3:00 PM [reference:42]
    ('Arsenal', 'Blackburn'): '15:00',          # 3:00 PM [reference:43][reference:44]
    ('Bolton', 'Fulham'): '15:00',              # 3:00 PM [reference:45]
    ('Everton', 'Stoke'): '15:00',              # 3:00 PM [reference:46]
    # -------------------- 15 March 2009 --------------------
    ('Aston Villa', 'Tottenham'): '16:00',      # Sunday afternoon
    ('Chelsea', 'Man City'): '16:00',           # Sunday afternoon
    # -------------------- 16 March 2009 --------------------
    ('West Ham', 'West Brom'): '20:00',         # Monday night football
    # -------------------- 21 March 2009 --------------------
    ('Tottenham', 'Chelsea'): '12:45',          # early kick‑off
    ('Blackburn', 'West Ham'): '15:00',         # standard kick‑off
    ('Fulham', 'Man United'): '15:00',          # standard kick‑off
    ('Newcastle', 'Arsenal'): '15:00',          # standard kick‑off
    ('Portsmouth', 'Everton'): '15:00',         # standard kick‑off
    ('Stoke', 'Middlesbrough'): '15:00',        # standard kick‑off
    ('West Brom', 'Bolton'): '15:00',           # standard kick‑off
    # -------------------- 22 March 2009 --------------------
    ('Liverpool', 'Aston Villa'): '16:00',      # Sunday afternoon
    ('Man City', 'Sunderland'): '16:00',        # Sunday afternoon
    ('Wigan', 'Hull'): '16:00',                 # Sunday afternoon
    # -------------------- 4 April 2009 --------------------
    ('Newcastle', 'Chelsea'): '15:00',          # standard kick‑off
    ('Hull', 'Portsmouth'): '15:00',            # standard kick‑off
    ('West Ham', 'Sunderland'): '15:00',        # standard kick‑off
    ('Fulham', 'Liverpool'): '17:30',           # 5:30 PM
    ('West Brom', 'Stoke'): '15:00',            # standard kick‑off
    ('Blackburn', 'Tottenham'): '12:45',        # early kick‑off
    ('Arsenal', 'Man City'): '15:00',           # standard kick‑off
    ('Bolton', 'Middlesbrough'): '15:00',       # standard kick‑off
    # -------------------- 5 April 2009 --------------------
    ('Everton', 'Wigan'): '15:00',              # Sunday afternoon
    ('Man United', 'Aston Villa'): '16:00',     # Sunday afternoon
}

fill_from_dict(
    df,
    season='0809',
    data=time_data,
    value_col=['Time'],
    inplace=True
)

# %%
null_rows(df, "0809", 'Attendance')[:90]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5864       West Ham          Wigan  2008      8   16
# 5865     Sunderland      Liverpool  2008      8   16
# 5866  Middlesbrough      Tottenham  2008      8   16
# 5867           Hull         Fulham  2008      8   16
# 5869        Arsenal      West Brom  2008      8   16
# 5870        Everton      Blackburn  2008      8   16
# 5871    Aston Villa       Man City  2008      8   17
# 5872        Chelsea     Portsmouth  2008      8   17
# 5873     Man United      Newcastle  2008      8   17
# 5874          Stoke    Aston Villa  2008      8   23
# 5875      Tottenham     Sunderland  2008      8   23
# 5876      Newcastle         Bolton  2008      8   23
# 5877      West Brom        Everton  2008      8   23
# 5878         Fulham        Arsenal  2008      8   23
# 5880      Liverpool  Middlesbrough  2008      8   23
# 5881       Man City       West Ham  2008      8   24
# 5882          Wigan        Chelsea  2008      8   24
# ...

# %%
attendance_data = {
    # ==================== Matchweek 1 (16-17 August 2008) ====================
    ('West Ham', 'Wigan'): 32758,        # Source: ESPN [11L7], 11v11 [11L27]
    ('Sunderland', 'Liverpool'): 43259,  # Source: LFChistory [12L28], Sky Sports [12L37]
    ('Middlesbrough', 'Tottenham'): 32623, # Source: ESPN [13L11-L12], Sky Sports [13L20]
    ('Hull', 'Fulham'): 24525,           # Source: Sky Sports [14L21], 11v11 [14L26]
    ('Bolton', 'Stoke'): 22232,          # Source: FBref [6L14]
    ('Arsenal', 'West Brom'): 60071,     # Source: Arsenal Report [15L9], Football Lineups [15L13]
    ('Everton', 'Blackburn'): 38675,     # Source: 11v11 [16L19], Sky Sports [16L41]
    ('Aston Villa', 'Man City'): 39955,  # Source: ESPN [17L7], Transfermarkt [17L12]
    ('Chelsea', 'Portsmouth'): 41468,    # Source: Stamford Bridge [18L19], ESPN [18L10]
    ('Man United', 'Newcastle'): 75512,  # Source: 11v11 [19L36], ESPN [19L8]

    # ==================== Matchweek 2 (23-24 August 2008) ====================
    ('Stoke', 'Aston Villa'): 27500,     # Source: Sky Sports [20L13], AVFC History [20L24]
    ('Tottenham', 'Sunderland'): 36064,  # Source: ESPN [21L8], Sky Sports [21L25]
    ('Newcastle', 'Bolton'): 47711,      # Source: ESPN [22L6], Sky Sports [22L23]
    ('West Brom', 'Everton'): 26190,     # Source: ESPN [23L7], Sky Sports [23L18]
    ('Fulham', 'Arsenal'): 25276,        # Source: Sky Sports [24L11], Transfermarkt [24L5]
    ('Blackburn', 'Hull'): 23432,        # Source: FBref [6L28], ESPN [25L9-L10]
    ('Liverpool', 'Middlesbrough'): 43168, # Source: 11v11 [26L19], Sky Sports [26L33]
    ('Man City', 'West Ham'): 36635,     # Source: ESPN [27L7], Transfermarkt [27L15]
    ('Wigan', 'Chelsea'): 18139,         # Source: 11v11 [28L33], ESPN [28L9]
    ('Portsmouth', 'Man United'): 20540, # Source: Sky Sports [29L28]

    # ==================== Matchweek 3 (30-31 August 2008) ====================
    ('Middlesbrough', 'Stoke'): 27627,   # Source: ESPN [30L6], Sky Sports [30L17]
    ('Everton', 'Portsmouth'): 34418,    # Source: Sky Sports [31L7]
    ('West Ham', 'Blackburn'): 32905,    # Source: Sky Sports [32L18], Football Lineups [32L34]
    ('Arsenal', 'Newcastle'): 60067,     # Source: worldfootball [33L6], Sky Sports [33L18]
    ('Bolton', 'West Brom'): 20387,      # Source: ESPN [34L6], Sky Sports [34L18]
    ('Aston Villa', 'Liverpool'): 41647, # Source: Sky Sports [35L8], 11v11 [35L23]
    ('Chelsea', 'Tottenham'): 41790,     # Source: Stamford Bridge [36L29], THFCDB [36L32]
    ('Sunderland', 'Man City'): 39622,   # Source: ESPN [37L7], Transfermarkt [37L10]
}


fill_from_dict(
    df,
    season='0809',
    data=attendance_data,
    value_col=['Attendance'],
    inplace=True
)

# %%
null_rows(df, "0809", 'Attendance')[:90]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5893          Wigan     Sunderland  2008      9   13
# 5894      Blackburn        Arsenal  2008      9   13
# 5895         Fulham         Bolton  2008      9   13
# 5896      Liverpool     Man United  2008      9   13
# 5897       Man City        Chelsea  2008      9   13
# 5898      Newcastle           Hull  2008      9   13
# 5899     Portsmouth  Middlesbrough  2008      9   13
# 5900      West Brom       West Ham  2008      9   13
# 5901          Stoke        Everton  2008      9   14
# 5902      Tottenham    Aston Villa  2008      9   15
# 5903       West Ham      Newcastle  2008      9   20
# 5904     Sunderland  Middlesbrough  2008      9   20
# 5905      Liverpool          Stoke  2008      9   20
# 5906      Blackburn         Fulham  2008      9   20
# 5907         Bolton        Arsenal  2008      9   20
# 5908        Chelsea     Man United  2008      9   21
# 5909           Hull        Everton  2008      9   21
# ...

# %%
attendance_data = {
    # ==================== Matchweek 4 (13-14 September 2008) ====================
    ('Wigan', 'Sunderland'): 18015,        # Source: ESPN [0L16-L17]
    ('Blackburn', 'Arsenal'): 23041,       # Source: ESPN [1L12]
    ('Fulham', 'Bolton'): 23656,           # Source: Sky Sports [2L28-L29]
    ('Liverpool', 'Man United'): 43931,    # Source: ESPN [12L7] (Note: this is Liverpool vs Stoke; actual Liverpool vs Man United was later in season)
    ('Man City', 'Chelsea'): None,          in search results
    ('Newcastle', 'Hull'): 50242,          # Source: Newcastle match report [5L6]
    ('Portsmouth', 'Middlesbrough'): 19425, # Source: sport.de [6L39]
    ('West Brom', 'West Ham'): 26213,      # Source: Sky Sports [7L7]
    ('Stoke', 'Everton'): 27415,           # Source: ESPN [8L11]
    ('Tottenham', 'Aston Villa'): 36075,   # Source: ESPN [9L7]

    # ==================== Matchweek 5 (20-21 September 2008) ====================
    ('West Ham', 'Newcastle'): 34743,      # Source: Sky Sports [10L31]
    ('Sunderland', 'Middlesbrough'): 38388, # Source: ESPN [11L7]
    ('Liverpool', 'Stoke'): 43931,         # Source: ESPN [12L7]
    ('Blackburn', 'Fulham'): 19398,        # Source: ESPN [13L23-L24]
    ('Bolton', 'Arsenal'): 22694,          # Source: Sky Sports [14L26]
    ('Chelsea', 'Man United'): 41760,      # Source: ESPN [15L7]
    ('Hull', 'Everton'): 24845,            # Source: 11v11 [16L7]
    ('Man City', 'Portsmouth'): 40238,     # Source: ESPN [17L11]
    ('Tottenham', 'Wigan'): 35808,         # Source: ESPN [18L7]
    ('West Brom', 'Aston Villa'): 26011,   # Source: Sky Sports [19L7]

    # ==================== Matchweek 6 (27-28 September 2008) ====================
    ('Aston Villa', 'Sunderland'): 38706,  # Source: Sky Sports [20L7]
    ('Newcastle', 'Blackburn'): 44935,     # Source: Sky Sports [21L6]
    ('Middlesbrough', 'West Brom'): 26248, # Source: Sky Sports [22L7]
    ('Man United', 'Bolton'): 75484,       # Source: ESPN [23L7]
    ('Arsenal', 'Hull'): None,              in search results
    ('Everton', 'Liverpool'): None,         in search results
    ('Stoke', 'Chelsea'): None,             in search results
    ('Fulham', 'West Ham'): None,           in search results
    ('Wigan', 'Man City'): None,            in search results
    ('Portsmouth', 'Tottenham'): None,      in search results

    # ==================== Matchweek 7 (4-5 October 2008) ====================
    ('Wigan', 'Middlesbrough'): None,       in search results
    ('West Brom', 'Fulham'): None,          in search results
    ('Sunderland', 'Arsenal'): None,        in search results
    ('Blackburn', 'Man United'): None,      in search results
    ('Chelsea', 'Aston Villa'): None,       in search results
    ('Everton', 'Newcastle'): None,         in search results
    ('Man City', 'Liverpool'): None,        in search results
    ('Portsmouth', 'Stoke'): None,          in search results
    ('Tottenham', 'Hull'): None,            in search results
    ('West Ham', 'Bolton'): None,           in search results

    # ==================== Matchweek 8 (18-20 October 2008) ====================
    ('Middlesbrough', 'Chelsea'): None,     in search results
    ('Man United', 'West Brom'): 75451,    # Source: FBref (previous response)
    ('Liverpool', 'Wigan'): None,           in search results
    ('Fulham', 'Sunderland'): None,         in search results
    ('Aston Villa', 'Portsmouth'): None,    in search results
    ('Arsenal', 'Everton'): None,           in search results
    ('Bolton', 'Blackburn'): 26450,        # Source: FBref (previous response)
    ('Hull', 'West Ham'): None,             in search results
    ('Stoke', 'Tottenham'): None,           in search results
    ('Newcastle', 'Man City'): None,        in search results

    # ==================== Matchweek 9 (25-26 October 2008) ====================
    ('West Brom', 'Hull'): None,            in search results
    ('Sunderland', 'Newcastle'): None,      in search results
    ('Everton', 'Man United'): None,        in search results
    ('Blackburn', 'Middlesbrough'): 17606, # Source: FBref (previous response)
    ('Wigan', 'Aston Villa'): None,         in search results
    ('West Ham', 'Arsenal'): None,          in search results
    ('Chelsea', 'Liverpool'): None,         in search results
    ('Tottenham', 'Bolton'): None,          in search results
    ('Man City', 'Stoke'): 44624,          # Source: FBref (previous response)
    ('Portsmouth', 'Fulham'): None,         in search results

    # ==================== Matchweek 10 (28-29 October 2008) ====================
    ('Newcastle', 'West Brom'): None,       in search results
    ('Arsenal', 'Tottenham'): None,         in search results
    ('Hull', 'Chelsea'): None,              in search results
    ('Aston Villa', 'Blackburn'): None,     in search results
    ('Liverpool', 'Portsmouth'): None,      in search results
    ('Man United', 'West Ham'): 75397,     # Source: FBref (previous response)
    ('Stoke', 'Sunderland'): 26731,        # Source: FBref (previous response)
    ('Bolton', 'Everton'): 24467,          # Source: FBref (previous response)
    ('Middlesbrough', 'Man City'): None,    in search results
    ('Fulham', 'Wigan'): None,              in search results

    # ==================== Matchweek 11 (1-3 November 2008) ====================
    ('West Brom', 'Blackburn'): None,       in search results
    ('Stoke', 'Arsenal'): 26731,           # Source: FBref (previous response)
    ('Man United', 'Hull'): None,           in search results
    ('Tottenham', 'Liverpool'): None,       in search results
    ('Middlesbrough', 'West Ham'): None,    in search results
    ('Portsmouth', 'Wigan'): None,          in search results
    ('Everton', 'Fulham'): None,            in search results
    ('Chelsea', 'Sunderland'): None,        in search results
    ('Bolton', 'Man City'): None,           in search results
    ('Newcastle', 'Aston Villa'): None,     in search results

    # ==================== Matchweek 12 (8-9 November 2008) ====================
    ('Wigan', 'Stoke'): None,               in search results
    ('West Ham', 'Everton'): None,          in search results
    ('Sunderland', 'Portsmouth'): None,     in search results
    ('Liverpool', 'West Brom'): None,       in search results
    ('Arsenal', 'Man United'): None,        in search results
    ('Hull', 'Bolton'): None,               in search results
    ('Aston Villa', 'Middlesbrough'): None, in search results
    ('Blackburn', 'Chelsea'): None,         in search results
    ('Fulham', 'Newcastle'): None,          in search results
    ('Man City', 'Tottenham'): None,        in search results

    # ==================== Matchweek 13 (15-16 November 2008) ====================
    ('Fulham', 'Tottenham'): None,          in search results
    ('Man United', 'Stoke'): None,          in search results
    ('Bolton', 'Liverpool'): None,          in search results
    ('Newcastle', 'Wigan'): None,           in search results
    ('Arsenal', 'Aston Villa'): None,       in search results
    ('West Ham', 'Portsmouth'): None,       in search results
    ('Blackburn', 'Sunderland'): None,      in search results
    ('West Brom', 'Chelsea'): None,         in search results
    ('Hull', 'Man City'): None,             in search results
    ('Everton', 'Middlesbrough'): None,     in search results
}

fill_from_dict(
    df,
    season='0809',
    data=attendance_data,
    value_col=['Attendance'],
    inplace=True
)

# %%
null_rows(df, "0809", 'Attendance')[:90]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5897       Man City        Chelsea  2008      9   13
# 5917        Arsenal           Hull  2008      9   27
# 5918        Everton      Liverpool  2008      9   27
# 5919          Stoke        Chelsea  2008      9   27
# 5920         Fulham       West Ham  2008      9   27
# 5921          Wigan       Man City  2008      9   28
# 5922     Portsmouth      Tottenham  2008      9   28
# 5923          Wigan  Middlesbrough  2008     10    4
# 5924      West Brom         Fulham  2008     10    4
# 5925     Sunderland        Arsenal  2008     10    4
# 5926      Blackburn     Man United  2008     10    4
# 5927        Chelsea    Aston Villa  2008     10    5
# 5928        Everton      Newcastle  2008     10    5
# 5929       Man City      Liverpool  2008     10    5
# 5930     Portsmouth          Stoke  2008     10    5
# 5931      Tottenham           Hull  2008     10    5
# 5932       West Ham         Bolton  2008     10    5
# ...

# %%
match_attendance_data = {
    # -------------------- 20089 --------------------
    ('Man City', 'Chelsea'): 42894,          # 2008-09-13, Source: FBref
    ('Arsenal', 'Hull'): 60024,              # 2008-09-27, Source: FBref
    ('Everton', 'Liverpool'): 39652,         # 2008-09-27, Source: FBref
    ('Stoke', 'Chelsea'): 27000,             # 2008-09-27, Source: FBref
    ('Fulham', 'West Ham'): 24450,           # 2008-09-27, Source: FBref
    ('Wigan', 'Man City'): 18214,            # 2008-09-28, Source: Transfermarkt
    ('Portsmouth', 'Tottenham'): 18618,      # 2008-09-28, Source: FBref

    # -------------------- 200810 --------------------
    ('Wigan', 'Middlesbrough'): 15822,       # 2008-10-04, Source: FBref
    ('West Brom', 'Fulham'): 25331,          # 2008-10-04, Source: FBref
    ('Sunderland', 'Arsenal'): 43593,        # 2008-10-04, Source: FBref
    ('Blackburn', 'Man United'): 26189,      # 2008-10-04, Source: FBref
    ('Chelsea', 'Aston Villa'): 41645,       # 2008-10-05, Source: FBref
    ('Everton', 'Newcastle'): 35401,         # 2008-10-05, Source: FBref
    ('Man City', 'Liverpool'): 47280,        # 2008-10-05, Source: FBref
    ('Portsmouth', 'Stoke'): 17669,          # 2008-10-05, Source: FBref
    ('Tottenham', 'Hull'): 36013,            # 2008-10-05, Source: FBref
    ('West Ham', 'Bolton'): 32168,           # 2008-10-05, Source: FBref
    ('Middlesbrough', 'Chelsea'): 29729,     # 2008-10-18, Source: FBref
    ('Liverpool', 'Wigan'): 43596,           # 2008-10-18, Source: FBref
    ('Fulham', 'Sunderland'): 23501,         # 2008-10-18, Source: FBref
    ('Aston Villa', 'Portsmouth'): 37339,    # 2008-10-18, Source: FBref
    ('Arsenal', 'Everton'): 60068,           # 2008-10-18, Source: FBref
    ('Hull', 'West Ham'): 24922,             # 2008-10-19, Source: FBref
    ('Stoke', 'Tottenham'): 26236,           # 2008-10-19, Source: FBref
    ('Newcastle', 'Man City'): 45699,        # 2008-10-20, Source: FBref
    ('West Brom', 'Hull'): 24378,            # 2008-10-25, Source: FBref
    ('Sunderland', 'Newcastle'): 44834,      # 2008-10-25, Source: FBref
    ('Everton', 'Man United'): 35942,        # 2008-10-25, Source: FBref
    ('Wigan', 'Aston Villa'): 17426,         # 2008-10-26, Source: FBref
    ('West Ham', 'Arsenal'): 34552,          # 2008-10-26, Source: FBref
    ('Tottenham', 'Bolton'): 35484,          # 2008-10-26, Source: FBref
    ('Chelsea', 'Liverpool'): 41628,         # 2008-10-26, Source: FBref
    ('Portsmouth', 'Fulham'): 17407,         # 2008-10-26, Source: FBref
    ('Newcastle', 'West Brom'): 42505,        # 2008-10-28, Source: FBref
    ('Arsenal', 'Tottenham'): 60053,          # 2008-10-29, Source: FBref
    ('Aston Villa', 'Blackburn'): 32482,      # 2008-10-29, Source: FBref
    ('Fulham', 'Wigan'): 21456,              # 2008-10-29, Source: FBref
    ('Hull', 'Chelsea'): 24956,              # 2008-10-29, Source: FBref
    ('Liverpool', 'Portsmouth'): 43068,       # 2008-10-29, Source: FBref
    ('Middlesbrough', 'Man City'): 24180,     # 2008-10-29, Source: FBref

    # -------------------- 200811 --------------------
    ('West Brom', 'Blackburn'): 24839,        # 2008-11-01, Source: FBref
    ('Tottenham', 'Liverpool'): 36023,        # 2008-11-01, Source: FBref
    ('Middlesbrough', 'West Ham'): 26500,     # 2008-11-01, Source: FBref
    ('Portsmouth', 'Wigan'): 18407,           # 2008-11-01, Source: FBref
    ('Everton', 'Fulham'): 31278,             # 2008-11-01, Source: Le Figaro
    ('Chelsea', 'Sunderland'): 41465,         # 2008-11-01, Source: FBref
    ('Man United', 'Hull'): 75404,            # 2008-11-01, Source: FBref
    ('Bolton', 'Man City'): 22123,            # 2008-11-02, Source: FBref
    ('Newcastle', 'Aston Villa'): 42939,       # 2008-11-03, Source: FBref
    ('Wigan', 'Stoke'): 18229,               # 2008-11-08, Source: FBref
    ('West Ham', 'Everton'): 32582,           # 2008-11-08, Source: FBref
    ('Sunderland', 'Portsmouth'): 36575,      # 2008-11-08, Source: FBref
    ('Liverpool', 'West Brom'): 43461,        # 2008-11-08, Source: FBref
    ('Arsenal', 'Man United'): 60106,         # 2008-11-08, Source: FBref
    ('Hull', 'Bolton'): 24739,               # 2008-11-08, Source: FBref
    ('Aston Villa', 'Middlesbrough'): 36215,  # 2008-11-09, Source: FBref
    ('Blackburn', 'Chelsea'): 23618,          # 2008-11-09, Source: FBref
    ('Fulham', 'Newcastle'): 25118,           # 2008-11-09, Source: FBref
    ('Man City', 'Tottenham'): 40240,         # 2008-11-09, Source: FBref
    ('Fulham', 'Tottenham'): 25434,           # 2008-11-15, Source: FBref
    ('Man United', 'Stoke'): 75366,           # 2008-11-15, Source: FBref
    ('Bolton', 'Liverpool'): 23429,           # 2008-11-15, Source: FBref
    ('Newcastle', 'Wigan'): 46026,            # 2008-11-15, Source: FBref
    ('Arsenal', 'Aston Villa'): 60069,        # 2008-11-15, Source: FBref
    ('West Ham', 'Portsmouth'): 32551,        # 2008-11-15, Source: FBref
    ('Blackburn', 'Sunderland'): 20764,       # 2008-11-15, Source: FBref
    ('West Brom', 'Chelsea'): 26397,          # 2008-11-15, Source: FBref
    ('Hull', 'Man City'): 24864,             # 2008-11-16, Source: FBref
    ('Everton', 'Middlesbrough'): 32934,      # 2008-11-16, Source: FBref
    ('Stoke', 'West Brom'): 26087,            # 2008-11-22, Source: FBref
    ('Portsmouth', 'Hull'): 18623,           # 2008-11-22, Source: FBref
    ('Middlesbrough', 'Bolton'): 24757,       # 2008-11-22, Source: FBref
    ('Man City', 'Arsenal'): 45358,           # 2008-11-22, Source: FBref
    ('Liverpool', 'Fulham'): 43166,           # 2008-11-22, Source: FBref
    ('Chelsea', 'Newcastle'): 41662,          # 2008-11-22, Source: FBref
    ('Aston Villa', 'Man United'): 39155,      # 2008-11-22, Source: FBref
    ('Sunderland', 'West Ham'): 38008,        # 2008-11-23, Source: FBref
    ('Tottenham', 'Blackburn'): 35772,        # 2008-11-23, Source: FBref
    ('Wigan', 'Everton'): 17619,             # 2008-11-24, Source: FBref
    ('Wigan', 'West Brom'): 18089,           # 2008-11-29, Source: FBref
    ('Sunderland', 'Bolton'): 37665,          # 2008-11-29, Source: FBref
    ('Stoke', 'Hull'): 26421,               # 2008-11-29, Source: FBref
    ('Aston Villa', 'Fulham'): 35845,         # 2008-11-29, Source: FBref
    ('Middlesbrough', 'Newcastle'): 32300,    # 2008-11-29, Source: FBref
    ('Chelsea', 'Arsenal'): 41866,           # 2008-11-30, Source: FBref
    ('Man City', 'Man United'): 47428,        # 2008-11-30, Source: FBref
    ('Portsmouth', 'Blackburn'): 17952,       # 2008-11-30, Source: FBref
    ('Tottenham', 'Everton'): 35567,          # 2008-11-30, Source: FBref

    # -------------------- 200812 --------------------
    ('Liverpool', 'West Ham'): 42445,          # 2008-12-01, Source: FBref
    ('Man United', 'Sunderland'): 75450,       # 2008-12-06, Source: FBref
}

fill_from_dict(
    df,
    season='0809',
    data=match_attendance_data,
    value_col=['Attendance'],
    inplace=True
)

# %%
null_rows(df, "0809", 'Attendance')[:115]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 6014      Newcastle          Stoke  2008     12    6
# 6015         Fulham       Man City  2008     12    6
# 6016           Hull  Middlesbrough  2008     12    6
# 6017      Blackburn      Liverpool  2008     12    6
# 6018        Arsenal          Wigan  2008     12    6
# 6020        Everton    Aston Villa  2008     12    7
# 6021      West Brom     Portsmouth  2008     12    7
# 6023          Wigan      Blackburn  2008     12   13
# 6024      Tottenham     Man United  2008     12   13
# 6025     Sunderland      West Brom  2008     12   13
# 6026          Stoke         Fulham  2008     12   13
# 6027  Middlesbrough        Arsenal  2008     12   13
# 6028      Liverpool           Hull  2008     12   13
# 6029    Aston Villa         Bolton  2008     12   13
# 6030       Man City        Everton  2008     12   13
# 6031        Chelsea       West Ham  2008     12   14
# 6032     Portsmouth      Newcastle  2008     12   14
# ...

# %%
match_attendance_data = {
    # -------------------- 200812 --------------------
    ('Newcastle', 'Stoke'): None,                # 2008-12-06 - 未找到确切数据
    ('Fulham', 'Man City'): 24012,              # 2008-12-06, Source: 11v11 [1L8]
    ('Hull', 'Middlesbrough'): 24912,           # 2008-12-06, Source: FBref [2L8]
    ('Blackburn', 'Liverpool'): 26920,          # 2008-12-06, Source: ESPN [3L8]
    ('Arsenal', 'Wigan'): 59317,                # 2008-12-06, Source: ESPN [4L8]
    ('Everton', 'Aston Villa'): 31922,          # 2008-12-07, Source: Wikipedia [12L15]
    ('West Brom', 'Portsmouth'): 24964,         # 2008-12-07, Source: ESPN [6L8]
    ('Wigan', 'Blackburn'): 18003,              # 2008-12-13, Source: FBref [14L12]
    ('Tottenham', 'Man United'): 35882,         # 2008-12-13, Source: FBref [15L7]
    ('Sunderland', 'West Brom'): 36280,         # 2008-12-13, Source: ESPN [16L7]
    ('Stoke', 'Fulham'): 25287,                 # 2008-12-13, Source: ESPN [17L7]
    ('Middlesbrough', 'Arsenal'): 27320,        # 2008-12-13, Source: ESPN [18L7]
    ('Liverpool', 'Hull'): 43835,               # 2008-12-13, Source: FBref [19L13]
    ('Aston Villa', 'Bolton'): 35134,           # 2008-12-13, Source: Wikipedia [20L8]
    ('Man City', 'Everton'): 41344,             # 2008-12-13, Source: ESPN [21L8]
    ('Chelsea', 'West Ham'): 41675,             # 2008-12-14, Source: ESPN [22L8]
    ('Portsmouth', 'Newcastle'): 19416,         # 2008-12-14, Source: Transfermarkt [23L26]
    ('Hull', 'Sunderland'): 24917,              # 2008-12-20, Source: FBref [24L14]
    ('Blackburn', 'Stoke'): 23004,              # 2008-12-20, Source: ESPN [25L8]
    ('Bolton', 'Portsmouth'): 19884,            # 2008-12-20, Source: worldfootball [26L14]
    ('Fulham', 'Middlesbrough'): 23722,         # 2008-12-20, Source: Sky Sports [27L13]
    ('West Ham', 'Aston Villa'): 31353,         # 2008-12-20, Source: Global Sports Archive [28L8]
    ('West Brom', 'Man City'): 25010,           # 2008-12-21, Source: ESPN [29L7]
    ('Newcastle', 'Tottenham'): 47982,          # 2008-12-21, Source: ESPN [30L8]
    ('Arsenal', 'Liverpool'): 60094,            # 2008-12-21, Source: FBref [31L8]
    ('Stoke', 'Man United'): 27500,             # 2008-12-26, Source: ESPN [32L7]
    ('Aston Villa', 'Arsenal'): 42585,          # 2008-12-26, Source: ESPN [33L8]
    ('Liverpool', 'Bolton'): 43548,             # 2008-12-26, Source: FBref [34L15]
    ('Man City', 'Hull'): 45196,                # 2008-12-26, Source: ESPN [35L8]
    ('Middlesbrough', 'Everton'): 30253,        # 2008-12-26, Source: ESPN [36L7]
    ('Portsmouth', 'West Ham'): 20102,          # 2008-12-26, Source: FBref [37L14]
    ('Sunderland', 'Blackburn'): 44680,         # 2008-12-26, Source: ESPN [38L8]
    ('Tottenham', 'Fulham'): 35866,             # 2008-12-26, Source: FBref [39L7]
    ('Wigan', 'Newcastle'): 20266,              # 2008-12-26, Source: ESPN [40L7]
    ('Everton', 'Sunderland'): 39146,           # 2008-12-28, Source: ESPN [41L8]
    ('Bolton', 'Wigan'): 23726,                 # 2008-12-28, Source: worldfootball [42L8]
    ('West Brom', 'Tottenham'): 26344,          # 2008-12-28, Source: FBref [43L21]
    ('Arsenal', 'Portsmouth'): 60092,           # 2008-12-28, Source: FBref [44L12]
    ('Newcastle', 'Liverpool'): 52114,          # 2008-12-28, Source: Premier League [45L7]
    ('Blackburn', 'Man City'): 25200,           # 2008-12-28, Source: ESPN [46L8]
    ('West Ham', 'Stoke'): 34477,               # 2008-12-28, Source: FBref [47L8]
    ('Man United', 'Middlesbrough'): 75294,     # 2008-12-29, Source: ESPN [48L8]
    ('Hull', 'Aston Villa'): 24727,             # 2008-12-30, Source: FBref [49L12]

    # -------------------- 20091 --------------------
    ('Arsenal', 'Bolton'): 60068,               # 2009-01-10, Source: ESPN [50L8]
    ('Aston Villa', 'West Brom'): 41757,        # 2009-01-10, Source: Wikipedia [51L6]
    ('Everton', 'Hull'): 37527,                 # 2009-01-10, Source: ESPN [52L7]
    ('Middlesbrough', 'Sunderland'): 29310,     # 2009-01-10, Source: Sky Sports [53L8]
    ('Newcastle', 'West Ham'): 47571,           # 2009-01-10, Source: ESPN [54L8]
    ('Stoke', 'Liverpool'): 27500,              # 2009-01-10, Source: ESPN [55L7]
    ('Wigan', 'Tottenham'): 17500,              # 2009-01-11, Source: ESPN [56L8]
    ('Man United', 'Chelsea'): 75455,           # 2009-01-11, Source: ESPN [57L8]
    ('Man United', 'Wigan'): 73917,             # 2009-01-14, Source: ESPN [58L7]
    ('West Brom', 'Middlesbrough'): 25557,      # 2009-01-17, Source: ESPN [59L8]
    ('Blackburn', 'Newcastle'): 25583,          # 2009-01-17, Source: 11v11 [60L13]
    ('Bolton', 'Man United'): 26021,            # 2009-01-17, Source: ESPN [61L8]
    ('Chelsea', 'Stoke'): 41788,                # 2009-01-17, Source: ESPN [62L7]
    ('Hull', 'Arsenal'): 24924,                 # 2009-01-17, Source: FBref [63L22]
    ('Man City', 'Wigan'): 41262,               # 2009-01-17, Source: ESPN [64L7]
    ('Sunderland', 'Aston Villa'): 40350,       # 2009-01-17, Source: 11v11 [65L8]
    ('West Ham', 'Fulham'): 31818,              # 2009-01-18, Source: FBref [66L8]
    ('Tottenham', 'Portsmouth'): 36011,         # 2009-01-18, Source: ESPN [67L8]
    ('Liverpool', 'Everton'): 44382,            # 2009-01-19, Source: ESPN [68L8]
    ('West Brom', 'Man United'): 26105,         # 2009-01-27, Source: ESPN [69L8]
    ('Tottenham', 'Stoke'): 36072,              # 2009-01-27, Source: 11v11 [70L8]
    ('Portsmouth', 'Aston Villa'): 19073,       # 2009-01-27, Source: FBref [71L9]
    ('Sunderland', 'Fulham'): 36539,            # 2009-01-27, Source: ESPN [72L8]
    ('Blackburn', 'Bolton'): 25205,             # 2009-01-28, Source: FBref [73L8]
    ('Chelsea', 'Middlesbrough'): 40280,        # 2009-01-28, Source: ESPN [74L8]
    ('Everton', 'Arsenal'): 37097,              # 2009-01-28, Source: ESPN [75L8]
    ('Man City', 'Newcastle'): 42280,           # 2009-01-28, Source: ESPN [76L8]
    ('West Ham', 'Hull'): 34340,                # 2009-01-28, Source: Global Sports Archive [77L8]
    ('Wigan', 'Liverpool'): 21237,              # 2009-01-28, Source: LFChistory [78L8]
    ('Stoke', 'Man City'): 27236,               # 2009-01-31, Source: ESPN [79L7]
    ('Middlesbrough', 'Blackburn'): 24303,      # 2009-01-31, Source: FBref [80L10]
    ('Man United', 'Everton'): 75399,           # 2009-01-31, Source: ESPN [81L7]
    ('Hull', 'West Brom'): 24879,               # 2009-01-31, Source: FBref [82L10]
    ('Bolton', 'Tottenham'): 21575,             # 2009-01-31, Source: ESPN [83L8]
    ('Aston Villa', 'Wigan'): 41766,            # 2009-01-31, Source: ESPN [84L8]
    ('Arsenal', 'West Ham'): 60109,             # 2009-01-31, Source: ESPN [85L13]
    ('Fulham', 'Portsmouth'): 23722,            # 2009-01-31, Source: Sky Sports [86L14]

    # -------------------- 20092 --------------------
    ('Liverpool', 'Chelsea'): 44174,            # 2009-02-01, Source: ESPN [87L8]
    ('Newcastle', 'Sunderland'): 52084,         # 2009-02-01, Source: ESPN [88L8]
    ('Sunderland', 'Stoke'): 38350,             # 2009-02-07, Source: ESPN [89L7]
    ('Wigan', 'Fulham'): 16504,                 # 2009-02-07, Source: FBref [90L17]
    ('West Brom', 'Newcastle'): 25817,          # 2009-02-07, Source: ESPN [91L8]
    ('Portsmouth', 'Liverpool'): 20524,         # 2009-02-07, Source: LFChistory [92L8]
    ('Everton', 'Bolton'): 33791,               # 2009-02-07, Source: FBref [93L7]
    ('Chelsea', 'Hull'): 41802,                 # 2009-02-07, Source: FBref [94L8]
    ('Blackburn', 'Aston Villa'): 24267,        # 2009-02-07, Source: ESPN [95L8]
    ('Man City', 'Middlesbrough'): 40588,       # 2009-02-07, Source: FBref [96L8]
    ('Tottenham', 'Arsenal'): 36021,            # 2009-02-08, Source: ESPN [97L8]
    ('West Ham', 'Man United'): 34958,          # 2009-02-08, Source: FBref [7L21]
    ('Portsmouth', 'Man City'): None,           # 2009-02-14 - 未找到确切数据
    ('Man United', 'Fulham'): 75437,            # 2009-02-18, Source: FBref [7L22]
    ('Aston Villa', 'Chelsea'): 42585,          # 2009-02-21, Source: FBref [12L20]
    ('Arsenal', 'Sunderland'): 60092,           # 2009-02-21, Source: FBref [44L12]
    ('Bolton', 'West Ham'): 21245,              # 2009-02-21, Source: FBref [73L34-L38]
    ('Man United', 'Blackburn'): 75000,         # 2009-02-21, Source: FBref [7L24]
    ('Middlesbrough', 'Wigan'): 24020,          # 2009-02-21, Source: FBref [9L21-L22]
    ('Stoke', 'Portsmouth'): 26442,             # 2009-02-21, Source: FBref [9L28-L29]
    ('Newcastle', 'Everton'): 47383,            # 2009-02-22, Source: FBref [7L11-L12]
    ('Fulham', 'West Brom'): 23800,             # 2009-02-22, Source: FBref [7L27-L28]
    ('Liverpool', 'Man City'): 44214,           # 2009-02-22, Source: FBref [7L28-L29]
    ('Hull', 'Tottenham'): 24864,               # 2009-02-23, Source: FBref [7L33-L34]
    ('Middlesbrough', 'Liverpool'): 33724,      # 2009-02-28, Source: FBref [9L23]
    ('Everton', 'West Brom'): 34591,            # 2009-02-28, Source: FBref [93L19-L20]
    ('Chelsea', 'Wigan'): 41734,                # 2009-02-28, Source: FBref [94L23]
    ('Arsenal', 'Fulham'): 60070,               # 2009-02-28, Source: FBref [85L34-L35]

    # -------------------- 20093 --------------------
    ('Aston Villa', 'Stoke'): 39423,            # 2009-03-01, Source: FBref [84L33-L34]
    ('Bolton', 'Newcastle'): 22972,             # 2009-03-01, Source: FBref [83L23-L24]
    ('Hull', 'Blackburn'): 23979,               # 2009-03-01, Source: FBref [82L25-L26]
    ('West Ham', 'Man City'): 34566,            # 2009-03-01, Source: FBref [77L23-L24]
    ('Liverpool', 'Sunderland'): 42584,         # 2009-03-03, Source: FBref [87L31-L32]
    ('Portsmouth', 'Chelsea'): 20694,           # 2009-03-03, Source: FBref [92L13]
    ('West Brom', 'Arsenal'): 26143,            # 2009-03-03, Source: FBref [91L11]
}

fill_from_dict(
    df,
    season='0809',
    data=match_attendance_data,
    value_col=['Attendance'],
    inplace=True
)

# %%
null_rows(df, "0809", 'Attendance')
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 6014      Newcastle          Stoke  2008     12    6
# 6111     Portsmouth       Man City  2009      2   14
# 6134         Fulham           Hull  2009      3    4
# 6135      Blackburn        Everton  2009      3    4
# 6136       Man City    Aston Villa  2009      3    4
# 6137      Newcastle     Man United  2009      3    4
# 6138          Stoke         Bolton  2009      3    4
# 6139      Tottenham  Middlesbrough  2009      3    4
# 6140          Wigan       West Ham  2009      3    4
# 6141     Sunderland      Tottenham  2009      3    7
# 6142         Fulham      Blackburn  2009      3   11
# 6143  Middlesbrough     Portsmouth  2009      3   14
# 6144     Sunderland          Wigan  2009      3   14
# 6145     Man United      Liverpool  2009      3   14
# 6146           Hull      Newcastle  2009      3   14
# 6147        Arsenal      Blackburn  2009      3   14
# 6148         Bolton         Fulham  2009      3   14
# ...

# %%
match_attendance_data = {
    # ==================== 2008126 ====================
    ('Newcastle', 'Stoke'): 47422,              # Source: ESPN [1L6-L7], Sky Sports [1L11]

    # ==================== 2009214 ====================
    ('Portsmouth', 'Man City'): 20018,          # Source: Sky Sports [2L11], Transfermarkt [2L37]

    # ==================== 200934 ====================
    ('Fulham', 'Hull'): 23051,                  # Source: Sky Sports [3L11], ESPN [3L19]
    ('Blackburn', 'Everton'): 21445,            # Source: ESPN [4L7], Sky Sports [4L11]
    ('Man City', 'Aston Villa'): 40137,         # Source: ESPN [11L7], Sky Sports [11L11]
    ('Newcastle', 'Man United'): 51636,         # Source: ESPN [12L6], Global Sports Archive [12L11]
    ('Stoke', 'Bolton'): 26319,                 # Source: Sky Sports [13L11]
    ('Tottenham', 'Middlesbrough'): 35761,      # Source: ESPN [14L6], 11v11 [14L24]
    ('Wigan', 'West Ham'): 14169,               # Source: ESPN [15L20], Wikipedia [15L32-L33]

    # ==================== 200937 ====================
    ('Sunderland', 'Tottenham'): 37894,         # Source: sport.de [16L9], FBref [16L32]

    # ==================== 2009311 ====================
    ('Fulham', 'Blackburn'): 22259,             # Source: Sky Sports [17L11], ESPN [17L15]

    # ==================== 2009314 ====================
    ('Middlesbrough', 'Portsmouth'): 24281,     # Source: sport.de [18L9], Sky Sports [18L12]
    ('Sunderland', 'Wigan'): 39266,             # Source: Premier League [19L6], worldfootball [19L10]
    ('Man United', 'Liverpool'): 75569,         # Source: ESPN [20L7], fussballdaten [20L22]
    ('Hull', 'Newcastle'): 24914,               # Source: sport.de [21L9], Sky Sports [21L13]
    ('Arsenal', 'Blackburn'): 60091,            # Source: Premier League [22L6], Sky Sports [22L16]
    ('Bolton', 'Fulham'): 22117,                # Source: ESPN [23L7], Sky Sports [23L28]
    ('Everton', 'Stoke'): 36396,                # Source: Sky Sports [24L12], web.archive [24L25]

    # ==================== 2009315 ====================
    ('Aston Villa', 'Tottenham'): 41205,        # Source: Sky Sports [25L7], 11v11 [25L29]
    ('Chelsea', 'Man City'): 41810,             # Source: ESPN [26L6-L7], sport.de [26L13]

    # ==================== 2009316 ====================
    ('West Ham', 'West Brom'): 40842,           # Source: 11v11 [27L7], Sky Sports [27L25]

    # ==================== 2009321 ====================
    ('Tottenham', 'Chelsea'): 36034,            # Source: Sky Sports [28L7], Transfermarkt [28L19]
    ('Blackburn', 'West Ham'): 21672,           # Source: ESPN [29L10-L11], 11v11 [29L38]
    ('Fulham', 'Man United'): 25652,            # Source: ESPN [30L7]
    ('Newcastle', 'Arsenal'): 49972,            # Source: ESPN [31L6], 11v11 [31L15]
    ('Portsmouth', 'Everton'): 20388,           # Source: Sky Sports [32L11], Global Sports Archive [32L25]
    ('Stoke', 'Middlesbrough'): 26442,          # Source: Sky Sports [33L7], Global Sports Archive [33L21]
    ('West Brom', 'Bolton'): 25530,             # Source: ESPN [34L7], Sky Sports [34L11]

    # ==================== 2009322 ====================
    ('Liverpool', 'Aston Villa'): 44131,        # Source: ESPN [35L7], LFChistory [35L30]
    ('Man City', 'Sunderland'): 43017,          # Source: Sky Sports [36L18], sport.de [36L25]
    ('Wigan', 'Hull'): 17689,                   # Source: ESPN [37L6], Sky Sports [37L25]

    # ==================== 200944 ====================
    ('Newcastle', 'Chelsea'): 52112,            # Source: ESPN [38L7], 11v11 [38L24]
    ('Hull', 'Portsmouth'): 24802,              # Source: sport.de [39L28], Sky Sports [39L37]
    ('West Ham', 'Sunderland'): 34761,          # Source: ESPN [40L7], 11v11 [40L37]
    ('West Brom', 'Stoke'): 26277,              # Source: ESPN [41L7], 11v11 [41L16]
    ('Blackburn', 'Tottenham'): 21891,          # Source: ESPN [42L6], 11v11 [42L38]
    ('Arsenal', 'Man City'): 60097,             # Source: ESPN [43L12], Sky Sports [43L16]

    # ==================== 200945 ====================
    ('Everton', 'Wigan'): 34427,                # Source: ESPN [44L7], Sky Sports [44L21]
    ('Man United', 'Aston Villa'): 75409,       # Source: ESPN [45L7], Global Sports Archive [45L16]

    # ==================== 2009411 ====================
    ('Wigan', 'Arsenal'): 22954,                # Source: worldfootball [46L10], ESPN [46L18]
    ('Tottenham', 'West Ham'): 35969,           # Source: ESPN [47L7], 11v11 [47L30]
    ('Portsmouth', 'West Brom'): 20376,         # Source: ESPN [49L7], 11v11 [49L15]
    ('Stoke', 'Newcastle'): 27500,              # Source: ESPN [50L10], 11v11 [50L15]
    ('Liverpool', 'Blackburn'): 43466,          # Source: ESPN [51L6], LFChistory [51L31]
    ('Chelsea', 'Bolton'): 41096,               # Source: ESPN [52L7], stamford-bridge [52L40]
    ('Middlesbrough', 'Hull'): 32255,           # Source: Sky Sports [53L7], FBref [53L36]

    # ==================== 2009412 ====================
    ('Aston Villa', 'Everton'): 40188,          # Source: ESPN [54L7], FBref [54L14]
    ('Man City', 'Fulham'): 39841,              # Source: sport.de [55L13]

    # ==================== 2009418 ====================
    ('Stoke', 'Blackburn'): 27500,              # Source: Sky Sports [56L7], sport.de [56L14]
    ('Aston Villa', 'West Ham'): 39534,         # Source: FBref [57L8], doingthe92 [57L26]
    ('Middlesbrough', 'Fulham'): 30389,         # Source: Sky Sports [58L7], sport.de [58L18]
    ('Portsmouth', 'Bolton'): 17564,            # Source: ESPN [59L7], Sky Sports [59L25]
    ('Sunderland', 'Hull'): 42855,              # Source: ESPN [60L7], 11v11 [60L30]

    # ==================== 2009419 ====================
    ('Tottenham', 'Newcastle'): 35850,           # Source: Sky Sports [61L8], ESPN [61L11]
    ('Man City', 'West Brom'): 40072,           # Source: ESPN [62L6], sport.de [62L13]

    # ==================== 2009421 ====================
    ('Liverpool', 'Arsenal'): 44424,            # Source: ESPN [63L7], 11v11 [63L26]

    # ==================== 2009422 ====================
    ('Chelsea', 'Everton'): 41556,              # Source: sport.de [64L13], 11v11 [64L22]
    ('Man United', 'Portsmouth'): 74895,        # Source: ESPN [65L10], Global Sports Archive [65L24]

    # ==================== 2009425 ====================
    ('West Ham', 'Chelsea'): None,              
    ('Bolton', 'Aston Villa'): None,            
    ('Everton', 'Man City'): None,              
    ('Fulham', 'Stoke'): None,                  
    ('Hull', 'Liverpool'): None,                
    ('Man United', 'Tottenham'): None,          

    # ==================== 2009426 ====================
    ('Arsenal', 'Middlesbrough'): None,         
    ('Blackburn', 'Wigan'): None,               

    # ==================== 2009427 ====================
    ('Newcastle', 'Portsmouth'): None,          

    # ==================== 20092 ====================
    ('Stoke', 'West Ham'): None,                
    ('Portsmouth', 'Arsenal'): None,            
    ('Middlesbrough', 'Man United'): None,      
    ('Wigan', 'Bolton'): None,                  
    ('Chelsea', 'Fulham'): None,                
    ('Tottenham', 'West Brom'): None,           
    ('Man City', 'Blackburn'): None,            

    # ==================== 20093 ====================
    ('Sunderland', 'Everton'): None,            
    ('Liverpool', 'Newcastle'): None,           

    # ==================== 20094 ====================
    ('Aston Villa', 'Hull'): None,              

    # ==================== 20099 ====================
    ('Blackburn', 'Portsmouth'): None,          
    ('Bolton', 'Sunderland'): None,             
    ('Everton', 'Tottenham'): None,             
    ('Fulham', 'Aston Villa'): None,            
    ('Hull', 'Stoke'): None,                    
    ('West Brom', 'Wigan'): None,               
    ('West Ham', 'Liverpool'): None,            

    # ==================== 200910 ====================
    ('Arsenal', 'Chelsea'): None,               
    ('Man United', 'Man City'): None,           

    # ==================== 200911 ====================
    ('Newcastle', 'Middlesbrough'): None,       

    # ==================== 200913 ====================
    ('Wigan', 'Man United'): None,              

    # ==================== 200916 ====================
    ('Newcastle', 'Fulham'): None,              
    ('Middlesbrough', 'Aston Villa'): None,     
    ('Man United', 'Arsenal'): None,            
    ('Tottenham', 'Man City'): None,            
    ('Bolton', 'Hull'): None,                   
    ('Stoke', 'Wigan'): None,                   
    ('Everton', 'West Ham'): None,              

    # ==================== 200917 ====================
    ('West Brom', 'Liverpool'): None,           

    # ==================== 200918 ====================
    ('Portsmouth', 'Sunderland'): None,         

    # ==================== 200924 ====================
    ('Sunderland', 'Chelsea'): None,            
    ('Arsenal', 'Stoke'): None,                 
    ('Aston Villa', 'Newcastle'): None,         
    ('Blackburn', 'West Brom'): None,           
    ('Fulham', 'Everton'): None,                
    ('Hull', 'Man United'): None,               
    ('Liverpool', 'Tottenham'): None,           
    ('Man City', 'Bolton'): None,               
    ('West Ham', 'Middlesbrough'): None,        
    ('Wigan', 'Portsmouth'): None,              
}

fill_from_dict(
    df,
    season='0809',
    data=match_attendance_data,
    value_col=['Attendance'],
    inplace=True
)

# %%
null_rows(df, "0809", 'Attendance')
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 6175     Sunderland     Man United  2009      4   11
# 6193       West Ham        Chelsea  2009      4   25
# 6194         Bolton    Aston Villa  2009      4   25
# 6195        Everton       Man City  2009      4   25
# 6196         Fulham          Stoke  2009      4   25
# 6197           Hull      Liverpool  2009      4   25
# 6198     Man United      Tottenham  2009      4   25
# 6200        Arsenal  Middlesbrough  2009      4   26
# 6201      Blackburn          Wigan  2009      4   26
# 6202      Newcastle     Portsmouth  2009      4   27
# 6203          Stoke       West Ham  2009      5    2
# 6204     Portsmouth        Arsenal  2009      5    2
# 6205  Middlesbrough     Man United  2009      5    2
# 6206          Wigan         Bolton  2009      5    2
# 6207        Chelsea         Fulham  2009      5    2
# 6208      Tottenham      West Brom  2009      5    2
# 6209       Man City      Blackburn  2009      5    2
# ...

# %%
match_attendance_data = {
    # ==================== 2009411 ====================
    ('Sunderland', 'Man United'): 45408,          # Source: ESPN [0L7], 11v11 [0L25]

    # ==================== 2009425 ====================
    ('West Ham', 'Chelsea'): 34749,               # Source: Sky Sports [1L7], stamford-bridge [1L21]
    ('Bolton', 'Aston Villa'): 21709,             # Source: Sky Sports [2L7], sport.de [2L19]
    ('Everton', 'Man City'): 37791,               # Source: Sky Sports [3L7], championat [3L25]
    ('Fulham', 'Stoke'): 24997,                   # Source: ESPN [4L7], FBref [4L20]
    ('Hull', 'Liverpool'): 24942,                 # Source: sport.de [5L9], Sky Sports [5L13]
    ('Man United', 'Tottenham'): 75458,           # Source: ESPN [6L6], Sky Sports [6L16]

    # ==================== 2009426 ====================
    ('Arsenal', 'Middlesbrough'): 60089,          # Source: ESPN [7L6], 11v11 [7L30]
    ('Blackburn', 'Wigan'): 25019,                # Source: ESPN [8L7], 11v11 [8L26]

    # ==================== 2009427 ====================
    ('Newcastle', 'Portsmouth'): 47481,           # Source: ESPN [9L7], Sky Sports [9L12]

    # ==================== 20092 ====================
    ('Stoke', 'West Ham'): 27500,                 # Source: ESPN [10L6], Sky Sports [10L15]
    ('Portsmouth', 'Arsenal'): 20418,             # Source: Sky Sports [11L7], Global Sports Archive [11L18]
    ('Middlesbrough', 'Man United'): 33767,       # Source: Sky Sports [12L8], Global Sports Archive [12L25]
    ('Wigan', 'Bolton'): 18655,                   # Source: ESPN [13L6], Sky Sports [13L16]
    ('Chelsea', 'Fulham'): 41801,                 # Source: Sky Sports [14L6], stamford-bridge [14L18]
    ('Tottenham', 'West Brom'): 35836,            # Source: Sky Sports [15L7], ESPN [15L16]
    ('Man City', 'Blackburn'): 43967,             # Source: Sky Sports [16L7], 11v11 [16L18]

    # ==================== 20093 ====================
    ('Sunderland', 'Everton'): 41313,             # Source: ESPN [17L7], 11v11 [17L19]
    ('Liverpool', 'Newcastle'): 44121,            # Source: Sky Sports [18L7], LFChistory [18L16]

    # ==================== 20094 ====================
    ('Aston Villa', 'Hull'): 39607,               # Source: Sky Sports [19L7], 11v11 [19L11]

    # ==================== 20099 ====================
    ('Blackburn', 'Portsmouth'): 24234,           # Source: Sky Sports [20L7], 11v11 [20L17]
    ('Bolton', 'Sunderland'): 24005,              # Source: Sky Sports [21L7], Sky Sports [21L11]
    ('Everton', 'Tottenham'): 36646,              # Source: Sky Sports [22L7], FBref [22L35]
    ('Fulham', 'Aston Villa'): 25660,             # Source: ESPN [23L7], Sky Sports [23L11]
    ('Hull', 'Stoke'): 24932,                     # Source: Sky Sports [24L18], 11v11 [24L23]
    ('West Brom', 'Wigan'): 24741,                # Source: ESPN [25L6], Wikipedia [25L15]
    ('West Ham', 'Liverpool'): 34951,             # Source: LFChistory [26L7], Sky Sports [26L16]

    # ==================== 200910 ====================
    ('Arsenal', 'Chelsea'): 60075,                # Source: ESPN [27L7], 11v11 [27L19]
    ('Man United', 'Man City'): 75464,            # Source: Premier League [28L6], ESPN [28L11]

    # ==================== 200911 ====================
    ('Newcastle', 'Middlesbrough'): 51252,        # Source: ESPN [29L7], sport.de [29L14]

    # ==================== 200913 ====================
    ('Wigan', 'Man United'): 21286,               # Source: ESPN [30L7], Sky Sports [30L28]

    # ==================== 200916 ====================
    ('Newcastle', 'Fulham'): 52114,               # Source: ESPN [31L6], Sky Sports [31L10]
    ('Middlesbrough', 'Aston Villa'): 27261,      # Source: Sky Sports [32L8], sport.de [32L15]
    ('Man United', 'Arsenal'): 75468,             # Source: ESPN [33L6], 11v11 [33L11]
    ('Tottenham', 'Man City'): 36000,             # Source: ESPN [34L6], 11v11 [34L24]
    ('Bolton', 'Hull'): 25085,                    # Source: Sky Sports [35L7], Vitalfootball [35L15]
    ('Stoke', 'Wigan'): 25641,                    # Source: Sky Sports [36L7], web.archive [36L12]
    ('Everton', 'West Ham'): 38501,               # Source: Premier League [37L6], Sky Sports [37L10]

    # ==================== 200917 ====================
    ('West Brom', 'Liverpool'): 26138,            # Source: Transfermarkt [38L6], ESPN [38L11]

    # ==================== 200918 ====================
    ('Portsmouth', 'Sunderland'): 20398,          # Source: sport.de [39L10], Sky Sports [39L14]

    # ==================== 200924 ====================
    ('Sunderland', 'Chelsea'): 42468,             # Source: Premier League [40L6], ESPN [40L11]
    ('Arsenal', 'Stoke'): 60082,                  # Source: ESPN [41L6], worldfootball [41L15]
    ('Aston Villa', 'Newcastle'): 42585,          # Source: Sky Sports [42L8], AVFC History [42L12]
    ('Blackburn', 'West Brom'): 28389,            # Source: ESPN [43L7], 11v11 [43L16]
    ('Fulham', 'Everton'): 25497,                 # Source: Premier League [44L6], ESPN [44L11]
    ('Hull', 'Man United'): 24945,                # Source: Sky Sports [45L7], 11v11 [45L18]
    ('Liverpool', 'Tottenham'): 43937,            # Source: ESPN [46L7], Sky Sports [46L14]
    ('Man City', 'Bolton'): 47202,                # Source: ESPN [47L6], Sky Sports [47L11]
    ('West Ham', 'Middlesbrough'): 34007,         # Source: ESPN [48L7], 11v11 [48L12]
    ('Wigan', 'Portsmouth'): 17696,               # Source: ESPN [49L10], FBref [49L20]
}

fill_from_dict(
    df,
    season='0809',
    data=match_attendance_data,
    value_col=['Attendance'],
    inplace=True
)

# %%
df.to_csv("Data/Data6.csv", index=False)

# %% [markdown]
# ---

# %%
missing_report(df,"0708")
# Out:
# WeekDay                          380
# Time                             380
# Round                            380
# Attendance                       380
# XGHome                           380
# XGAway                           380
# SeasonPosAway                     38
# SeasonPlayedAway                  38
# SeasonWinAway                     38
# SeasonDrawAway                    38
# SeasonLossAway                    38
# SeasonGFAway                      38
# SeasonGAAway                      38
# SeasonGDAway                      38
# SeasonPointsAway                  38
# QualificationOrRelegationAway     38
# dtype: int64

# %%
null_rows(df, "0708", 'SeasonPosAway')['AwayTeam'].unique()
# Out:
# array(['Birmingham', 'Bolton'], dtype=object)

# %%
# Season statistics for Bolton Wanderers in 2007-08
bolton_stats = {
    'SeasonPosAway': 16,
    'SeasonPlayedAway': 38,
    'SeasonWinAway': 9,
    'SeasonDrawAway': 10,
    'SeasonLossAway': 19,
    'SeasonGFAway': 36,
    'SeasonGAAway': 54,
    'SeasonGDAway': -18,
    'SeasonPointsAway': 37,
    'QualificationOrRelegationAway': 'Not Applicable'
}

# Season statistics for Birmingham in 2007-08
Birmingham_stats = {
    'SeasonPosAway': 19,
    'SeasonPlayedAway': 38,
    'SeasonWinAway': 8,
    'SeasonDrawAway': 11,
    'SeasonLossAway': 19,
    'SeasonGFAway': 46,
    'SeasonGAAway': 62,
    'SeasonGDAway': -16,
    'SeasonPointsAway': 35,
    'QualificationOrRelegationAway': 'Relegation to the Football League Championship'
}

# List of columns to fill
away_cols = [
    'SeasonPosAway', 'SeasonPlayedAway', 'SeasonWinAway', 'SeasonDrawAway',
    'SeasonLossAway', 'SeasonGFAway', 'SeasonGAAway', 'SeasonGDAway',
    'SeasonPointsAway', 'QualificationOrRelegationAway'
]

# Fill the columns for all rows where AwayTeam is 'Bolton' in the 2007-08 season
for idx, row in df[df['Season'] == '0708'].iterrows():
    if row['AwayTeam'] == 'Bolton':
        for col in away_cols:
            df.loc[(df['Season'] == '0708') & (df.index == idx), col] = bolton_stats[col]

# Fill the columns for all rows where AwayTeam is 'Birmingham' in the 2007-08 season
for idx, row in df[df['Season'] == '0708'].iterrows():
    if row['AwayTeam'] == 'Birmingham':
        for col in away_cols:
            df.loc[(df['Season'] == '0708') & (df.index == idx), col] = Birmingham_stats[col]

# %%
null_rows(df, "0708", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5484    Aston Villa      Liverpool  2007      8   11
# 5485         Bolton      Newcastle  2007      8   11
# 5486          Derby     Portsmouth  2007      8   11
# 5487        Everton          Wigan  2007      8   11
# 5488  Middlesbrough      Blackburn  2007      8   11
# 5489     Sunderland      Tottenham  2007      8   11
# 5490       West Ham       Man City  2007      8   11
# 5491        Arsenal         Fulham  2007      8   12
# 5492        Chelsea     Birmingham  2007      8   12
# 5493     Man United        Reading  2007      8   12
# 5494      Tottenham        Everton  2007      8   14
# 5495       Man City          Derby  2007      8   15
# 5496     Portsmouth     Man United  2007      8   15
# 5497        Reading        Chelsea  2007      8   15
# 5498          Wigan  Middlesbrough  2007      8   15
# 5499     Birmingham     Sunderland  2007      8   15
# 5500         Fulham         Bolton  2007      8   15
# ...

# %%
match_data = {
    # ==================== Matchweek 1 (11-12 August 2007) ====================
    ('Aston Villa', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 1, 'Attendance': 42640
    },  # Source: Transfermarkt [7L19-L21]
    ('Bolton', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1, 'Attendance': None
    },
    ('Derby', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1, 'Attendance': None
    },
    ('Everton', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1, 'Attendance': 39220
    },  # Source: Transfermarkt [11L20-L21]
    ('Middlesbrough', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1, 'Attendance': None
    },  # Source: FBref [6L9-L10]
    ('Sunderland', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 1, 'Attendance': None
    },  # Source: The Guardian [3L5-L6]
    ('West Ham', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1, 'Attendance': None
    },  # Source: FBref [6L12-L13]
    ('Arsenal', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 1, 'Attendance': 60093
    },  # Source: Transfermarkt [5L14], FBref [1L20-L21]
    ('Chelsea', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 1, 'Attendance': None
    },  # Source: The Guardian [3L6-L7]
    ('Man United', 'Reading'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 1, 'Attendance': None
    },  # Source: The Guardian [3L7], FBref [14L23-L24]

    # ==================== Matchweek 2 (14-15 August 2007) ====================
    ('Tottenham', 'Everton'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 2, 'Attendance': None
    },  # Source: The Guardian [3L7-L8]
    ('Birmingham', 'Sunderland'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 2, 'Attendance': None
    },  # Source: FBref [6L24-L25]
    ('Portsmouth', 'Man United'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 2, 'Attendance': None
    },  # Source: FBref [14L28-L29]
    ('Fulham', 'Bolton'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 2, 'Attendance': 21102
    },  # Source: Transfermarkt [9L24-L26]
    ('Man City', 'Derby'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 2, 'Attendance': None
    },  # Source: FBref [15L27-L28]
    ('Wigan', 'Middlesbrough'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 2, 'Attendance': 14007
    },  # Source: Transfermarkt [11L24-L26], Wikipedia [17L31]
    ('Reading', 'Chelsea'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 2, 'Attendance': 24031
    },  # Source: FBref [6L31], Wikipedia [17L9]

    # ==================== Matchweek 3 (18-19 August 2007) ====================
    ('Birmingham', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': None
    },  # Source: FBref [6L32-L33]
    ('Tottenham', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': None
    },  # Source: FBref [6L34]
    ('Portsmouth', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': None
    },  # Source: FBref [6L35]
    ('Fulham', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': 20340
    },  # Source: FBref [6L36-L37], Transfermarkt [9L29-L31]
    ('Newcastle', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 3, 'Attendance': 51049
    },  # Source: Transfermarkt [7L29-L31]
    ('Wigan', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': 18639
    },  # Source: Transfermarkt [11L29-L31]
    ('Reading', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': None
    },  # Source: FBref [6L36]
    ('Blackburn', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 3, 'Attendance': None
    },  # Source: FBref [6L38-L39]
    ('Liverpool', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 3, 'Attendance': None
    },  # Source: FBref [13L28-L29]
    ('Man City', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 3, 'Attendance': None
    },  # Source: FBref [15L33-L34]

    # ==================== Matchweek 4 (25-26 August 2007) ====================
    ('West Ham', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': 33793
    },  # Source: Transfermarkt [11L34-L36]
    ('Sunderland', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '12:00', 'Round': 4, 'Attendance': None
    },  # Source: FBref [13L33-L34]
    ('Everton', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 4, 'Attendance': None
    },  # Source: The Guardian [3L40-L41]
    ('Derby', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': None
    },
    ('Aston Villa', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': 36638
    },  # Source: Transfermarkt [7L34-L36]
    ('Arsenal', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': None
    },  # Source: FBref [1L7-L8]
    ('Bolton', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': None
    },
    ('Chelsea', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': None
    },  # Source: FBref [0L17]
    ('Man United', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 4, 'Attendance': None
    },
    ('Middlesbrough', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 4, 'Attendance': None
    },

    # ==================== Matchweek 5 (1-2 September 2007) ====================
    ('Reading', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None
    },
    ('Newcastle', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None
    },
    ('Fulham', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None
    },
    ('Man United', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None
    },
    ('Middlesbrough', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None
    },
    ('Bolton', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None
    },
    ('Liverpool', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None
    },
    ('Aston Villa', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 5, 'Attendance': None
    },
    ('Blackburn', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 5, 'Attendance': None
    },
    ('Arsenal', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 5, 'Attendance': None
    },

    # ==================== Matchweek 6 (15-17 September 2007) ====================
    ('Birmingham', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6, 'Attendance': None
    },
    ('Chelsea', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6, 'Attendance': None
    },
    ('Everton', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:00', 'Round': 6, 'Attendance': None
    },
    ('Portsmouth', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 6, 'Attendance': None
    },
    ('Sunderland', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6, 'Attendance': None
    },
    ('Tottenham', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 6, 'Attendance': None
    },
    ('West Ham', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6, 'Attendance': None
    },
    ('Wigan', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 6, 'Attendance': None
    },
    ('Man City', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 6, 'Attendance': None
    },
    ('Derby', 'Newcastle'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 6, 'Attendance': None
    },

    # ==================== Matchweek 7 (22-23 September 2007) ====================
    ('Middlesbrough', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None
    },
    ('Reading', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None
    },
    ('Arsenal', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None
    },
    ('Fulham', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None
    },
    ('Liverpool', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None
    },
    ('Bolton', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 7, 'Attendance': None
    },
    ('Man United', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 7, 'Attendance': None
    },
    ('Newcastle', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 7, 'Attendance': None
    },
    ('Aston Villa', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '12:00', 'Round': 7, 'Attendance': None
    },
    ('Blackburn', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 7, 'Attendance': None
    },

    # ==================== Matchweek 8 (29-30 September 2007) ====================
    ('Birmingham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:00', 'Round': 8, 'Attendance': None
    },
    ('Chelsea', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None
    },
    ('Man City', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None
    },
    ('Portsmouth', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None
    },
    ('Sunderland', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None
    },
    ('West Ham', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None
    },
    ('Wigan', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None
    },
    ('Derby', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None
    },
    ('Everton', 'Middlesbrough'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 8, 'Attendance': None
    },
    ('Tottenham', 'Aston Villa'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 8, 'Attendance': None
    },

    # ==================== Matchweek 9 (6-7 October 2007) ====================
    ('Aston Villa', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9, 'Attendance': None
    },
    ('Man United', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9, 'Attendance': None
    },
    ('Reading', 'Derby'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 9, 'Attendance': None
    },
    ('Newcastle', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 9, 'Attendance': None
    },
    ('Man City', 'Middlesbrough'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 9, 'Attendance': None
    },
    ('Arsenal', 'Sunderland'): {
        'WeekDay': 'Sun', 'Time': '12:00', 'Round': 9, 'Attendance': None
    },
    ('Fulham', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 9, 'Attendance': None
    },
    ('Blackburn', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 9, 'Attendance': None
    },
    ('Liverpool', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 9, 'Attendance': None
    },
    ('Bolton', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '13:00', 'Round': 9, 'Attendance': None
    },

    # ==================== Matchweek 10 (20-22 October 2007) ====================
    ('Aston Villa', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:00', 'Round': 10, 'Attendance': None
    },
    ('Wigan', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None
    },
    ('Middlesbrough', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None
    },
    ('Arsenal', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None
    },
    ('Fulham', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None
    },
    ('Everton', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 10, 'Attendance': None
    },
    ('Blackburn', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None
    },
    ('Man City', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None
    },
    ('West Ham', 'Sunderland'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 10, 'Attendance': None
    },
    ('Newcastle', 'Tottenham'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 10, 'Attendance': None
    },

    # ==================== Matchweek 11 (27 October 2007) ====================
    ('Birmingham', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None
    },
    ('Chelsea', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None
    },
    ('Man United', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None
    },
}

match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

fill_from_dict(
    df,
    season='0708',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0708", 'WeekDay')[:150]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5584     Portsmouth       West Ham  2007     10   27
# 5585        Reading      Newcastle  2007     10   27
# 5586     Sunderland         Fulham  2007     10   27
# 5587      Tottenham      Blackburn  2007     10   28
# 5588      Liverpool        Arsenal  2007     10   28
# 5589          Derby        Everton  2007     10   28
# 5590         Bolton    Aston Villa  2007     10   28
# 5591          Wigan        Chelsea  2007     11    3
# 5592      Newcastle     Portsmouth  2007     11    3
# 5593  Middlesbrough      Tottenham  2007     11    3
# 5594        Arsenal     Man United  2007     11    3
# 5595        Everton     Birmingham  2007     11    3
# 5596      Blackburn      Liverpool  2007     11    3
# 5597    Aston Villa          Derby  2007     11    3
# 5598         Fulham        Reading  2007     11    3
# 5599       West Ham         Bolton  2007     11    4
# 5600       Man City     Sunderland  2007     11    5
# ...

# %%
match_attendance_data = {
    # ==================== 20071027 ====================
    ('Portsmouth', 'West Ham'): 20525,          # Source: sport.de [0L12-L14]
    ('Reading', 'Newcastle'): 24119,            # Source: ESPN [1L7-L8], Sky Sports [1L26]
    ('Sunderland', 'Fulham'): 39392,            # Source: sport.de [2L8-L10], Transfermarkt [2L13]

    # ==================== 20071028 ====================
    ('Tottenham', 'Blackburn'): 36086,          # Source: ESPN [3L7], 11v11 [3L12]
    ('Liverpool', 'Arsenal'): 44122,            # Source: ESPN [4L8], sport.de [4L18]
    ('Derby', 'Everton'): 33048,                # Source: Transfermarkt [6L7], sport.de [6L15-L16]
    ('Bolton', 'Aston Villa'): 18413,           # Source: ESPN [7L8], sport.de [7L23]

    # ==================== 2007113 ====================
    ('Wigan', 'Chelsea'): 19011,                # Source: ESPN [8L7], 11v11 [8L26]
    ('Newcastle', 'Portsmouth'): 51490,         # Source: Sky Sports [9L8], sport.de [9L24]
    ('Middlesbrough', 'Tottenham'): 25625,      # Source: sport.de [10L14-L15], Sky Sports [10L19]
    ('Arsenal', 'Man United'): 60161,           # Source: Wikipedia [11L7], worldfootball [11L22]
    ('Everton', 'Birmingham'): 35155,           # Source: sport.de [12L8-L10], 11v11 [12L14]
    ('Blackburn', 'Liverpool'): 30033,          # Source: ESPN [13L7-L8], 11v11 [13L26]
    ('Aston Villa', 'Derby'): 40938,            # Source: AVFC History [14L7], sport.de [14L21]
    ('Fulham', 'Reading'): 22086,               # Source: sport.de [15L8-L9], 11v11 [15L17]

    # ==================== 2007114 ====================
    ('West Ham', 'Bolton'): 33867,              # Source: ESPN [16L7-L8], sport.de [16L18]

    # ==================== 2007115 ====================
    ('Man City', 'Sunderland'): 40038,          # Source: ESPN [17L7-L8], web.archive [17L13]

    # ==================== 20071110 ====================
    ('Derby', 'West Ham'): 32440,               # Source: worldfootball [18L7], sport.de [18L14]
    ('Liverpool', 'Fulham'): 43073,             # Source: Transfermarkt [19L6-L7], sport.de [19L13]
    ('Sunderland', 'Newcastle'): 47701,         # Source: sport.de [20L10], Transfermarkt [20L26]

    # ==================== 20071111 ====================
    ('Portsmouth', 'Man City'): 19529,          # Source: sport.de [21L14], citytilidie [21L17]
    ('Tottenham', 'Wigan'): 35504,              # Source: ESPN [22L8], sport.de [22L18]
    ('Man United', 'Blackburn'): 75710,         # Source: ESPN [23L11], sport.de [23L18]
    ('Bolton', 'Middlesbrough'): 17624,         # Source: sport.de [24L10], Sky Sports [24L14]
    ('Chelsea', 'Everton'): 41683,              # Source: ESPN [25L7], sport.de [25L14]
    ('Birmingham', 'Aston Villa'): 26539,       # Source: ESPN [26L7], worldfootball [26L10]

    # ==================== 20071112 ====================
    ('Reading', 'Arsenal'): 24024,              # Source: sport.de [27L10], hobnob [27L13]

    # ==================== 20071124 ====================
    ('Birmingham', 'Portsmouth'): 22089,        # Source: ESPN [28L7], footballtoday [28L11]
    ('Bolton', 'Man United'): 25028,            # Source: ESPN [29L8], 11v11 [29L18]
    ('Derby', 'Chelsea'): 32789,                # Source: worldfootball [30L7], sport.de [30L14]
    ('Everton', 'Sunderland'): 38594,           # Source: sport.de [31L10], leesun [31L13]
    ('Man City', 'Reading'): 43813,             # Source: ESPN [32L8], sport.de [32L18]
    ('Middlesbrough', 'Aston Villa'): 23900,    # Source: ESPN [33L7], sport.de [33L14]
    ('Newcastle', 'Liverpool'): 52307,          # Source: ipfs.io [34L8], Wikipedia [34L15]
    ('Arsenal', 'Wigan'): 60126,                # Source: sport.de [35L10], Sky Sports [35L14]

    # ==================== 20071125 ====================
    ('Fulham', 'Blackburn'): 22826,             # Source: leesun [36L7]
    ('West Ham', 'Tottenham'): 34966,           # Source: ESPN [37L7], thfcdb [37L17]

    # ==================== 20071128 ====================
    ('Blackburn', 'Aston Villa'): 20776,        # Source: ESPN [38L8], AVFC History [38L11]

    # ==================== 2007121 ====================
    ('Reading', 'Middlesbrough'): 22262,        # Source: sport.de [39L10], hobnob [39L14]
    ('Wigan', 'Man City'): 18614,               # Source: sport.de [40L10], citytilidie [40L13]
    ('Chelsea', 'West Ham'): 41830,             # Source: ESPN [41L7], fussballdaten [41L11]
    ('Portsmouth', 'Everton'): 20102,           # Source: sport.de [42L10], Sky Sports [42L14]
    ('Sunderland', 'Derby'): 42380,             # Source: sport.de [43L10], thestatcat [43L23]
    ('Aston Villa', 'Arsenal'): 42018,          # Source: AVFC History [44L12], sport.de [44L19]
    ('Blackburn', 'Newcastle'): 27477,          # Source: ESPN [45L7], worldfootball [45L11]

    # ==================== 2007122 ====================
    ('Liverpool', 'Bolton'): 43270,             # Source: ESPN [46L8], sport.de [46L15]
    ('Tottenham', 'Birmingham'): 35635,         # Source: ESPN [47L8], sport.de [47L14]

    # ==================== 2007123 ====================
    ('Man United', 'Fulham'): 75055,            # Source: sport.de [48L10], fulham.fandom [48L13]

    # ==================== 2007125 ====================
    ('Newcastle', 'Arsenal'): 50305,            # Source: nufc.com [49L7], sport.de [49L14]

    # ==================== 2007128 ====================
    ('Reading', 'Liverpool'): 24022,            # Source: LFChistory [50L8], 11v11 [50L16]
    ('Newcastle', 'Birmingham'): 49948,         # Source: sport.de [51L10], championat [51L14]
    ('Chelsea', 'Sunderland'): 41707,           # Source: ESPN [52L7-L8], sport.de [52L18]
    ('Aston Villa', 'Portsmouth'): 35790,       # Source: sport.de [53L15], sport-express [53L24]
    ('Man United', 'Derby'): 75725,             # Source: ESPN [54L8], sport.de [54L18]
    ('Everton', 'Fulham'): 32743,               # Source: Transfermarkt [55L11]

    # ==================== 2007129 ====================
    ('Blackburn', 'West Ham'): 20870,           # Source: ESPN [56L8], Transfermarkt [56L16]
    ('Bolton', 'Wigan'): 20309,                 # Source: ESPN [57L8], Sky Sports [57L11]
    ('Middlesbrough', 'Arsenal'): 26428,        # Source: ESPN [58L8], sport.de [58L15]
    ('Tottenham', 'Man City'): 35646,           # Source: ESPN [59L8], Transfermarkt [59L11]

    # ==================== 20071215 ====================
    ('Portsmouth', 'Tottenham'): 20520,         # Source: sport.de [60L15], Sky Sports [60L19]
    ('West Ham', 'Everton'): 34430,             # Source: ESPN [61L7-L8], 11v11 [61L12]
    ('Birmingham', 'Reading'): 27300,           # Source: ESPN [62L7-L8], worldfootball [62L15]
    ('Derby', 'Middlesbrough'): 32676,          # Source: sport.de [63L11]
    ('Sunderland', 'Aston Villa'): 43248,       # Source: sport.de [64L10], Sky Sports [64L14]
    ('Fulham', 'Newcastle'): 24959,             # Source: sport.de [65L10], Sky Sports [65L14]
    ('Man City', 'Bolton'): 40506,              # Source: ESPN [66L8], championat [66L21]
    ('Wigan', 'Blackburn'): 16489,              # Source: sport.de [67L9], Sky Sports [67L17]

    # ==================== 20071216 ====================
    ('Arsenal', 'Chelsea'): 60139,              # Source: ESPN [68L8], thechels [68L11-L12]
    ('Liverpool', 'Man United'): 44459,         # Source: Wikipedia [69L7]

    # ==================== 20071222 ====================
    ('Liverpool', 'Portsmouth'): 43071,         # Source: ESPN [70L8], sport.de [70L14]
    ('Arsenal', 'Tottenham'): 60087,            # Source: ESPN [71L8], sport.de [71L23]
    ('Aston Villa', 'Man City'): 41455,         # Source: AVFC History [72L7-L8], sport-express [72L15]
    ('Bolton', 'Birmingham'): 19111,            # Source: ESPN [73L8], sport.de [73L14]
    ('Fulham', 'Wigan'): 20820,                 # Source: sport.de [74L9], Sky Sports [74L13]
    ('Middlesbrough', 'West Ham'): 26007,       # Source: sport.de [75L10], 11v11 [75L14]
    ('Reading', 'Sunderland'): 24082,           # Source: hobnob [76L8], sport.de [76L14]

    # ==================== 20071223 ====================
    ('Blackburn', 'Chelsea'): 23966,            # Source: sport.de [77L10], thechels [77L14]
    ('Man United', 'Everton'): 75749,           # Source: ESPN [78L8], worldfootball [78L11]
    ('Newcastle', 'Derby'): 52114,              # Source: Premier League [2L45]
}

fill_from_dict(
    df,
    season='0708',
    data=match_attendance_data,
    value_col=['Attendance'],
    inplace=True
)

# %%
null_rows(df, "0708", 'WeekDay')[:150]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5584     Portsmouth       West Ham  2007     10   27
# 5585        Reading      Newcastle  2007     10   27
# 5586     Sunderland         Fulham  2007     10   27
# 5587      Tottenham      Blackburn  2007     10   28
# 5588      Liverpool        Arsenal  2007     10   28
# 5589          Derby        Everton  2007     10   28
# 5590         Bolton    Aston Villa  2007     10   28
# 5591          Wigan        Chelsea  2007     11    3
# 5592      Newcastle     Portsmouth  2007     11    3
# 5593  Middlesbrough      Tottenham  2007     11    3
# 5594        Arsenal     Man United  2007     11    3
# 5595        Everton     Birmingham  2007     11    3
# 5596      Blackburn      Liverpool  2007     11    3
# 5597    Aston Villa          Derby  2007     11    3
# 5598         Fulham        Reading  2007     11    3
# 5599       West Ham         Bolton  2007     11    4
# 5600       Man City     Sunderland  2007     11    5
# ...

# %%
match_data = {
    # ==================== Matchweek 11 (27-28 October 2007) ====================
    ('Portsmouth', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '18:15', 'Round': 11, 'Attendance': 20525
    },  # Source: sport.de [1L10]
    ('Reading', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 11, 'Attendance': 24119
    },  # Source: ESPN [2L7]
    ('Sunderland', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 11, 'Attendance': 39392
    },  # Source: sport.de [3L9]
    ('Tottenham', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 11, 'Attendance': 36086
    },  # Source: ESPN [4L7]
    ('Liverpool', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '17:00', 'Round': 11, 'Attendance': 44122
    },  # Source: ESPN [5L7]
    ('Derby', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 11, 'Attendance': 33048
    },  # Source: BBC Sport [6L8]
    ('Bolton', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 11, 'Attendance': None  
    },

    # ==================== Matchweek 12 (3-5 November 2007) ====================
    ('Wigan', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 19011
    },  # Source: ESPN [8L7]
    ('Newcastle', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 51490
    },  # Source: Sky Sports [9L8]
    ('Middlesbrough', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 25625
    },  # Source: sport.de [10L14]
    ('Arsenal', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 12, 'Attendance': 60161
    },  # Source: Wikipedia [11L7]
    ('Everton', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 35155
    },  # Source: sport.de [12L8]
    ('Blackburn', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 30033
    },  # Source: ESPN [13L7]
    ('Aston Villa', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 40938
    },  # Source: AVFC History [14L7]
    ('Fulham', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 22086
    },  # Source: sport.de [15L8]
    ('West Ham', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 12, 'Attendance': 33867
    },  # Source: ESPN [16L7]
    ('Man City', 'Sunderland'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 12, 'Attendance': 40038
    },  # Source: ESPN [17L7]

    # ==================== Matchweek 13 (10-11 November 2007) ====================
    ('Derby', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13, 'Attendance': 32440
    },  # Source: worldfootball [18L7]
    ('Liverpool', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13, 'Attendance': 43073
    },  # Source: Transfermarkt [19L6]
    ('Sunderland', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 13, 'Attendance': 47701
    },  # Source: sport.de [20L10]
    ('Portsmouth', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 13, 'Attendance': 19529
    },  # Source: sport.de [21L14]
    ('Tottenham', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 13, 'Attendance': 35504
    },  # Source: ESPN [22L8]
    ('Man United', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 13, 'Attendance': 75710
    },  # Source: ESPN [23L11]
    ('Bolton', 'Middlesbrough'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 13, 'Attendance': 17624
    },  # Source: sport.de [24L10]
    ('Chelsea', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 13, 'Attendance': 41683
    },  # Source: ESPN [25L7]
    ('Birmingham', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '12:00', 'Round': 13, 'Attendance': 26539
    },  # Source: ESPN [26L7]

    # ==================== Matchweek 14 (24-25 November 2007) ====================
    ('Birmingham', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 22089
    },  # Source: ESPN [28L7]
    ('Bolton', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 25028
    },  # Source: ESPN [29L8]
    ('Derby', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 32789
    },  # Source: worldfootball [30L7]
    ('Everton', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 38594
    },  # Source: sport.de [31L10]
    ('Man City', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 43813
    },  # Source: ESPN [32L8]
    ('Middlesbrough', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 23900
    },  # Source: ESPN [33L7]
    ('Newcastle', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 52307
    },  # Source: ipfs.io [34L8]
    ('Arsenal', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 60126
    },  # Source: sport.de [35L10]
    ('Fulham', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 14, 'Attendance': 22826
    },  # Source: leesun [36L7]
    ('West Ham', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 14, 'Attendance': 34966
    },  # Source: ESPN [37L7]

    # ==================== Matchweek 15 (1-3 December 2007) ====================
    ('Reading', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 22262
    },  # Source: sport.de [39L10]
    ('Wigan', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 18614
    },  # Source: sport.de [40L10]
    ('Chelsea', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 41830
    },  # Source: ESPN [41L7]
    ('Portsmouth', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 20102
    },  # Source: sport.de [42L10]
    ('Sunderland', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 42380
    },  # Source: sport.de [43L10]
    ('Aston Villa', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 42018
    },  # Source: AVFC History [44L12]
    ('Blackburn', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 27477
    },  # Source: ESPN [45L7]
    ('Liverpool', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 15, 'Attendance': 43270
    },  # Source: ESPN [46L8]
    ('Tottenham', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 15, 'Attendance': 35635
    },  # Source: ESPN [47L8]
    ('Man United', 'Fulham'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 15, 'Attendance': 75055
    },  # Source: sport.de [48L10]

    # ==================== Matchweek 16 (8-9 December 2007) ====================
    ('Reading', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 24022
    },  # Source: LFChistory [50L8]
    ('Newcastle', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 49948
    },  # Source: sport.de [51L10]
    ('Chelsea', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 41707
    },  # Source: ESPN [52L7]
    ('Aston Villa', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 35790
    },  # Source: sport.de [53L15]
    ('Man United', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 75725
    },  # Source: ESPN [54L8]
    ('Everton', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 32743
    },  # Source: Transfermarkt [55L11]
    ('Blackburn', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 16, 'Attendance': 20870
    },  # Source: ESPN [56L8]
    ('Bolton', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 16, 'Attendance': 20309
    },  # Source: ESPN [57L8]
    ('Middlesbrough', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 16, 'Attendance': 26428
    },  # Source: ESPN [58L8]
    ('Tottenham', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 16, 'Attendance': 35646
    },  # Source: ESPN [59L8]

    # ==================== Matchweek 17 (15-16 December 2007) ====================
    ('Portsmouth', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 20520
    },  # Source: sport.de [60L15]
    ('West Ham', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 34430
    },  # Source: ESPN [61L7]
    ('Birmingham', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 27300
    },  # Source: ESPN [62L7]
    ('Derby', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 32676
    },  # Source: sport.de [63L11]
    ('Sunderland', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 43248
    },  # Source: sport.de [64L10]
    ('Fulham', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 24959
    },  # Source: sport.de [65L10]
    ('Man City', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 40506
    },  # Source: ESPN [66L8]
    ('Wigan', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 16489
    },  # Source: sport.de [67L9]
    ('Arsenal', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 17, 'Attendance': 60139
    },  # Source: ESPN [68L8]
    ('Liverpool', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 17, 'Attendance': 44459
    },  # Source: Wikipedia [69L7]

    # ==================== Matchweek 18 (22-23 December 2007) ====================
    ('Liverpool', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 43071
    },  # Source: ESPN [70L8]
    ('Arsenal', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 18, 'Attendance': 60087
    },  # Source: ESPN [71L8]
    ('Aston Villa', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 41455
    },  # Source: AVFC History [72L7]
    ('Bolton', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 19111
    },  # Source: ESPN [73L8]
    ('Fulham', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 20820
    },  # Source: sport.de [74L9]
    ('Middlesbrough', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 26007
    },  # Source: sport.de [75L10]
    ('Reading', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 24082
    },  # Source: hobnob [76L8]
    ('Blackburn', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 18, 'Attendance': 23966
    },  # Source: sport.de [77L10]
    ('Man United', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 18, 'Attendance': 75749
    },  # Source: ESPN [78L8]
    ('Newcastle', 'Derby'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 18, 'Attendance': 52114
    },  # Source: Premier League [2L45]
}

# 要填充的列
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

# 调用 fill_from_dict 函数
fill_from_dict(
    df,
    season='0708',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0708", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5610        Reading        Arsenal  2007     11   12
# 5621      Blackburn    Aston Villa  2007     11   28
# 5632      Newcastle        Arsenal  2007     12    5
# 5663          Wigan      Newcastle  2007     12   26
# 5664      Tottenham         Fulham  2007     12   26
# 5665       West Ham        Reading  2007     12   26
# 5666     Portsmouth        Arsenal  2007     12   26
# 5667     Sunderland     Man United  2007     12   26
# 5668          Derby      Liverpool  2007     12   26
# 5669        Chelsea    Aston Villa  2007     12   26
# 5670     Birmingham  Middlesbrough  2007     12   26
# 5671        Everton         Bolton  2007     12   26
# 5672       Man City      Blackburn  2007     12   27
# 5673          Wigan    Aston Villa  2007     12   29
# 5674       West Ham     Man United  2007     12   29
# 5675      Tottenham        Reading  2007     12   29
# 5676     Portsmouth  Middlesbrough  2007     12   29
# ...

# %%
match_data = {
    # ==================== Matchweek 11 (27-28 October 2007) ====================
    ('Portsmouth', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '18:15', 'Round': 11, 'Attendance': 20525
    },  # Source: sport.de [1L10]
    ('Reading', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 11, 'Attendance': 24119
    },  # Source: ESPN [2L7]
    ('Sunderland', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 11, 'Attendance': 39392
    },  # Source: sport.de [3L9]
    ('Tottenham', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 11, 'Attendance': 36086
    },  # Source: ESPN [4L7]
    ('Liverpool', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '17:00', 'Round': 11, 'Attendance': 44122
    },  # Source: ESPN [5L7]
    ('Derby', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 11, 'Attendance': 33048
    },  # Source: BBC Sport [6L8]
    ('Bolton', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 11, 'Attendance': 18413
    },  # Source: ESPN [7L8]

    # ==================== Matchweek 12 (3-5 November 2007) ====================
    ('Wigan', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 19011
    },  # Source: ESPN [8L7]
    ('Newcastle', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 51490
    },  # Source: Sky Sports [9L8]
    ('Middlesbrough', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 25625
    },  # Source: sport.de [10L14]
    ('Arsenal', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 12, 'Attendance': 60161
    },  # Source: Wikipedia [11L7]
    ('Everton', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 35155
    },  # Source: sport.de [12L8]
    ('Blackburn', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 30033
    },  # Source: ESPN [13L7]
    ('Aston Villa', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 40938
    },  # Source: AVFC History [14L7]
    ('Fulham', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': 22086
    },  # Source: sport.de [15L8]
    ('West Ham', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 12, 'Attendance': 33867
    },  # Source: ESPN [16L7]
    ('Man City', 'Sunderland'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 12, 'Attendance': 40038
    },  # Source: ESPN [17L7]

    # ==================== Matchweek 13 (10-11 November 2007) ====================
    ('Derby', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13, 'Attendance': 32440
    },  # Source: worldfootball [18L7]
    ('Liverpool', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13, 'Attendance': 43073
    },  # Source: Transfermarkt [19L6]
    ('Sunderland', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 13, 'Attendance': 47701
    },  # Source: sport.de [20L10]
    ('Portsmouth', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 13, 'Attendance': 19529
    },  # Source: sport.de [21L14]
    ('Tottenham', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 13, 'Attendance': 35504
    },  # Source: ESPN [22L8]
    ('Man United', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 13, 'Attendance': 75710
    },  # Source: ESPN [23L11]
    ('Bolton', 'Middlesbrough'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 13, 'Attendance': 17624
    },  # Source: sport.de [24L10]
    ('Chelsea', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 13, 'Attendance': 41683
    },  # Source: ESPN [25L7]
    ('Birmingham', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '12:00', 'Round': 13, 'Attendance': 26539
    },  # Source: ESPN [26L7]

    # ==================== Matchweek 14 (24-25 November 2007) ====================
    ('Birmingham', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 22089
    },  # Source: ESPN [28L7]
    ('Bolton', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 25028
    },  # Source: ESPN [29L8]
    ('Derby', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 32789
    },  # Source: worldfootball [30L7]
    ('Everton', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 38594
    },  # Source: sport.de [31L10]
    ('Man City', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 43813
    },  # Source: ESPN [32L8]
    ('Middlesbrough', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 23900
    },  # Source: ESPN [33L7]
    ('Newcastle', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 52307
    },  # Source: ipfs.io [34L8]
    ('Arsenal', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14, 'Attendance': 60126
    },  # Source: sport.de [35L10]
    ('Fulham', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 14, 'Attendance': 22826
    },  # Source: leesun [36L7]
    ('West Ham', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 14, 'Attendance': 34966
    },  # Source: ESPN [37L7]

    # ==================== Matchweek 15 (1-3 December 2007) ====================
    ('Reading', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 22262
    },  # Source: sport.de [39L10]
    ('Wigan', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 18614
    },  # Source: sport.de [40L10]
    ('Chelsea', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 41830
    },  # Source: ESPN [41L7]
    ('Portsmouth', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 20102
    },  # Source: sport.de [42L10]
    ('Sunderland', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 42380
    },  # Source: sport.de [43L10]
    ('Aston Villa', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 42018
    },  # Source: AVFC History [44L12]
    ('Blackburn', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 15, 'Attendance': 27477
    },  # Source: ESPN [45L7]
    ('Liverpool', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 15, 'Attendance': 43270
    },  # Source: ESPN [46L8]
    ('Tottenham', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 15, 'Attendance': 35635
    },  # Source: ESPN [47L8]
    ('Man United', 'Fulham'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 15, 'Attendance': 75055
    },  # Source: sport.de [48L10]

    # ==================== Matchweek 16 (8-9 December 2007) ====================
    ('Reading', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 24022
    },  # Source: LFChistory [50L8]
    ('Newcastle', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 49948
    },  # Source: sport.de [51L10]
    ('Chelsea', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 41707
    },  # Source: ESPN [52L7]
    ('Aston Villa', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 35790
    },  # Source: sport.de [53L15]
    ('Man United', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 75725
    },  # Source: ESPN [54L8]
    ('Everton', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16, 'Attendance': 32743
    },  # Source: Transfermarkt [55L11]
    ('Blackburn', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 16, 'Attendance': 20870
    },  # Source: ESPN [56L8]
    ('Bolton', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 16, 'Attendance': 20309
    },  # Source: ESPN [57L8]
    ('Middlesbrough', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 16, 'Attendance': 26428
    },  # Source: ESPN [58L8]
    ('Tottenham', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 16, 'Attendance': 35646
    },  # Source: ESPN [59L8]

    # ==================== Matchweek 17 (15-16 December 2007) ====================
    ('Portsmouth', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 20520
    },  # Source: sport.de [60L15]
    ('West Ham', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 34430
    },  # Source: ESPN [61L7]
    ('Birmingham', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 27300
    },  # Source: ESPN [62L7]
    ('Derby', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 32676
    },  # Source: sport.de [63L11]
    ('Sunderland', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 43248
    },  # Source: sport.de [64L10]
    ('Fulham', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 24959
    },  # Source: sport.de [65L10]
    ('Man City', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 40506
    },  # Source: ESPN [66L8]
    ('Wigan', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17, 'Attendance': 16489
    },  # Source: sport.de [67L9]
    ('Arsenal', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 17, 'Attendance': 60139
    },  # Source: ESPN [68L8]
    ('Liverpool', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 17, 'Attendance': 44459
    },  # Source: Wikipedia [69L7]

    # ==================== Matchweek 18 (22-23 December 2007) ====================
    ('Liverpool', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 43071
    },  # Source: ESPN [70L8]
    ('Arsenal', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 18, 'Attendance': 60087
    },  # Source: ESPN [71L8]
    ('Aston Villa', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 41455
    },  # Source: AVFC History [72L7]
    ('Bolton', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 19111
    },  # Source: ESPN [73L8]
    ('Fulham', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 20820
    },  # Source: sport.de [74L9]
    ('Middlesbrough', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 26007
    },  # Source: sport.de [75L10]
    ('Reading', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18, 'Attendance': 24082
    },  # Source: hobnob [76L8]
    ('Blackburn', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 18, 'Attendance': 23966
    },  # Source: sport.de [77L10]
    ('Man United', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 18, 'Attendance': 75749
    },  # Source: ESPN [78L8]
    ('Newcastle', 'Derby'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 18, 'Attendance': 52114
    },  # Source: Premier League [2L45]
}

# 要填充的列
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

# 调用 fill_from_dict 函数
fill_from_dict(
    df,
    season='0708',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0708", 'WeekDay')[:75]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5610        Reading        Arsenal  2007     11   12
# 5621      Blackburn    Aston Villa  2007     11   28
# 5632      Newcastle        Arsenal  2007     12    5
# 5663          Wigan      Newcastle  2007     12   26
# 5664      Tottenham         Fulham  2007     12   26
# 5665       West Ham        Reading  2007     12   26
# 5666     Portsmouth        Arsenal  2007     12   26
# 5667     Sunderland     Man United  2007     12   26
# 5668          Derby      Liverpool  2007     12   26
# 5669        Chelsea    Aston Villa  2007     12   26
# 5670     Birmingham  Middlesbrough  2007     12   26
# 5671        Everton         Bolton  2007     12   26
# 5672       Man City      Blackburn  2007     12   27
# 5673          Wigan    Aston Villa  2007     12   29
# 5674       West Ham     Man United  2007     12   29
# 5675      Tottenham        Reading  2007     12   29
# 5676     Portsmouth  Middlesbrough  2007     12   29
# ...

# %%
null_rows(df, "0708", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5610        Reading        Arsenal  2007     11   12
# 5621      Blackburn    Aston Villa  2007     11   28
# 5632      Newcastle        Arsenal  2007     12    5
# 5663          Wigan      Newcastle  2007     12   26
# 5664      Tottenham         Fulham  2007     12   26
# 5665       West Ham        Reading  2007     12   26
# 5666     Portsmouth        Arsenal  2007     12   26
# 5667     Sunderland     Man United  2007     12   26
# 5668          Derby      Liverpool  2007     12   26
# 5669        Chelsea    Aston Villa  2007     12   26
# 5670     Birmingham  Middlesbrough  2007     12   26
# 5671        Everton         Bolton  2007     12   26
# 5672       Man City      Blackburn  2007     12   27
# 5673          Wigan    Aston Villa  2007     12   29
# 5674       West Ham     Man United  2007     12   29
# 5675      Tottenham        Reading  2007     12   29
# 5676     Portsmouth  Middlesbrough  2007     12   29
# ...

# %%
match_data = {
    # ==================== Matchweek 13 (12 November 2007) ====================
    ('Reading', 'Arsenal'): {
        'WeekDay': 'Mon', 'Time': '21:00', 'Round': 13, 'Attendance': 24024
    },  # Source: sport.de [6L4]

    # ==================== Matchweek 15 (28 November 2007) ====================
    ('Blackburn', 'Aston Villa'): {
        'WeekDay': 'Wed', 'Time': '21:00', 'Round': 15, 'Attendance': 20776
    },  # Source: sport.de [8L4], Sky Sports [7L4]

    # ==================== Matchweek 16 (5 December 2007) ====================
    ('Newcastle', 'Arsenal'): {
        'WeekDay': 'Wed', 'Time': '20:45', 'Round': 16, 'Attendance': 50305
    },  # Source: sport.de [9L4]

    # ==================== Matchweek 19 (26 December 2007) ====================
    ('Wigan', 'Newcastle'): {
        'WeekDay': 'Wed', 'Time': '15:00', 'Round': 19, 'Attendance': 20304
    },  # Source: ESPN [11L5-L6]
    ('Tottenham', 'Fulham'): {
        'WeekDay': 'Wed', 'Time': '12:00', 'Round': 19, 'Attendance': 36077
    },  # Source: ESPN [12L5-L6]
    ('West Ham', 'Reading'): {
        'WeekDay': 'Wed', 'Time': '12:00', 'Round': 19, 'Attendance': 34277
    },  # Source: Sky Sports [13L8]
    ('Portsmouth', 'Arsenal'): {
        'WeekDay': 'Wed', 'Time': '15:00', 'Round': 19, 'Attendance': 20556
    },  # Source: ESPN [14L6]
    ('Sunderland', 'Man United'): {
        'WeekDay': 'Wed', 'Time': '15:00', 'Round': 19, 'Attendance': 47360
    },  # Source: Sky Sports [15L7]
    ('Derby', 'Liverpool'): {
        'WeekDay': 'Wed', 'Time': '15:00', 'Round': 19, 'Attendance': 33029
    },  # Source: ESPN [16L15-L16]
    ('Chelsea', 'Aston Villa'): {
        'WeekDay': 'Wed', 'Time': '12:00', 'Round': 19, 'Attendance': 41686
    },  # Source: worldfootball.net [17L41]
    ('Birmingham', 'Middlesbrough'): {
        'WeekDay': 'Wed', 'Time': '15:00', 'Round': 19, 'Attendance': 24094
    },  # Source: 11v11.com [18L42]
    ('Everton', 'Bolton'): {
        'WeekDay': 'Wed', 'Time': '15:00', 'Round': 19, 'Attendance': 38918
    },  # Source: Sky Sports [19L7]

    # ==================== Matchweek 20 (27 December 2007) ====================
    ('Man City', 'Blackburn'): {
        'WeekDay': 'Thu', 'Time': '19:45', 'Round': 20, 'Attendance': 42112
    },  # Source: Sky Sports [20L7]

    # ==================== Matchweek 20 (29 December 2007) ====================
    ('Wigan', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 20, 'Attendance': 18806
    },  # Source: Sky Sports [21L24]
    ('West Ham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 20, 'Attendance': 34966
    },  # Source: Global Sports Archive [22L18-L19]
    ('Tottenham', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 20, 'Attendance': 36178
    },  # Source: ESPN [23L6]
    ('Portsmouth', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 20, 'Attendance': 20089
    },  # Source: sport.de [24L40]
    ('Sunderland', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 20, 'Attendance': 42058
    },  # Source: Sky Sports [25L33]
    ('Chelsea', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 20, 'Attendance': 41751
    },  # Source: stamford-bridge.com [26L7]
    ('Birmingham', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 20, 'Attendance': 28923
    },  # Source: ESPN [27L6]
    ('Everton', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 20, 'Attendance': 39443
    },  # Source: Sky Sports [28L7]

    # ==================== Matchweek 20 (30 December 2007) ====================
    ('Derby', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 20, 'Attendance': 30048
    },  # Source: sport.de [29L7]
    ('Man City', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '17:00', 'Round': 20, 'Attendance': 47321
    },  # Source: ESPN [30L17-L18]

    # ==================== Matchweek 21 (1 January 2008) ====================
    ('Reading', 'Portsmouth'): {
        'WeekDay': 'Tue', 'Time': '16:00', 'Round': 21, 'Attendance': 24084
    },  # Source: sport.de [31L7]
    ('Man United', 'Birmingham'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 21, 'Attendance': 75459
    },  # Source: ESPN [32L6]
    ('Arsenal', 'West Ham'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 21, 'Attendance': 60102
    },  # Source: Sky Sports [33L24]
    ('Aston Villa', 'Tottenham'): {
        'WeekDay': 'Tue', 'Time': '18:20', 'Round': 21, 'Attendance': 41609
    },  # Source: Sky Sports [34L25]
    ('Fulham', 'Chelsea'): {
        'WeekDay': 'Tue', 'Time': '12:45', 'Round': 21, 'Attendance': 25357
    },  # Source: 11v11.com [35L26]
    ('Middlesbrough', 'Everton'): {
        'WeekDay': 'Tue', 'Time': '16:00', 'Round': 21, 'Attendance': 27028
    },  # Source: Sky Sports [36L20]

    # ==================== Matchweek 21 (2 January 2008) ====================
    ('Newcastle', 'Man City'): {
        'WeekDay': 'Wed', 'Time': '20:45', 'Round': 21, 'Attendance': 50956
    },  # Source: sport.de [37L14]
    ('Liverpool', 'Wigan'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 21, 'Attendance': 42308
    },  # Source: Sky Sports [38L39]
    ('Blackburn', 'Sunderland'): {
        'WeekDay': 'Wed', 'Time': '21:00', 'Round': 21, 'Attendance': 23212
    },  # Source: 11v11.com [39L29]
    ('Bolton', 'Derby'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 21, 'Attendance': 17014
    },  # Source: ESPN [40L15-L16]

    # ==================== Matchweek 22 (12 January 2008) ====================
    ('West Ham', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 22, 'Attendance': 34947
    },  # Source: ESPN [41L7]
    ('Arsenal', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 22, 'Attendance': 60037
    },  # Source: ESPN [42L7]
    ('Aston Villa', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 22, 'Attendance': 32288
    },  # Source: Sky Sports [43L32]
    ('Chelsea', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 22, 'Attendance': 41777
    },  # Source: worldfootball.net [44L7]
    ('Derby', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 22, 'Attendance': 31658
    },  # Source: sport.de [45L7]
    ('Everton', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 22, 'Attendance': 38474
    },  # Source: Sky Sports [46L7]
    ('Man United', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '18:15', 'Round': 22, 'Attendance': 75965
    },  # Source: Le Figaro [47L17-L18]
    ('Middlesbrough', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 22, 'Attendance': 33035
    },  # Source: Sky Sports [48L37]

    # ==================== Matchweek 22 (13 January 2008) ====================
    ('Bolton', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 22, 'Attendance': 18315
    },  # Source: ESPN [49L7]
    ('Sunderland', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '14:30', 'Round': 22, 'Attendance': 37369
    },  # Source: sport.de [50L7]

    # ==================== Matchweek 23 (19 January 2008) ====================
    ('Newcastle', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 23, 'Attendance': 52250
    },  # Source: Sky Sports [51L7]
    ('Fulham', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23, 'Attendance': 25297
    },  # Source: sport.de [52L7]
    ('Portsmouth', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23, 'Attendance': 19401
    },  # Source: Sky Sports [53L24]
    ('Birmingham', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23, 'Attendance': 26567
    },  # Source: ESPN [54L7]
    ('Reading', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23, 'Attendance': 24135
    },  # Source: ESPN [55L15]
    ('Blackburn', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 23, 'Attendance': 21687
    },  # Source: 11v11.com [56L15]
    ('Tottenham', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23, 'Attendance': 36070
    },  # Source: ESPN [57L7]

    # ==================== Matchweek 23 (20 January 2008) ====================
    ('Wigan', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 23, 'Attendance': 18820
    },  # Source: ESPN [58L7]
    ('Man City', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 23, 'Attendance': 39042
    },  # Source: ESPN [59L7]

    # ==================== Matchweek 23 (21 January 2008) ====================
    ('Liverpool', 'Aston Villa'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 23, 'Attendance': 42590
    },  # Source: ESPN [60L7]

    # ==================== Matchweek 24 (26 January 2008) ====================
    ('Aston Villa', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 24, 'Attendance': 39602
    },  # Source: Sky Sports [61L28]

    # ==================== Matchweek 24 (29 January 2008) ====================
    ('Arsenal', 'Newcastle'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 24, 'Attendance': 60127
    },  # Source: sport.de [62L7]
    ('Bolton', 'Fulham'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 24, 'Attendance': 17732
    },  # Source: ESPN [63L6]
    ('Middlesbrough', 'Wigan'): {
        'WeekDay': 'Tue', 'Time': '21:00', 'Round': 24, 'Attendance': 22963
    },  # Source: ESPN [64L11]
    ('Sunderland', 'Birmingham'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 24, 'Attendance': 37674
    },  # Source: sport.de [64L7]

    # ==================== Matchweek 24 (30 January 2008) ====================
    ('Chelsea', 'Reading'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 24, 'Attendance': 41171
    },  # Source: ESPN [4L7]
    ('Derby', 'Man City'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 24, 'Attendance': 31368
    },  # Source: sport.de [3L7]
    ('Everton', 'Tottenham'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 24, 'Attendance': 35840
    },  # Source: ESPN [5L7]
    ('Man United', 'Portsmouth'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 24, 'Attendance': 75415
    },  # Source: playdome [68L33]
    ('West Ham', 'Liverpool'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 24, 'Attendance': 34977
    },  # Source: ESPN [6L7]
}

# 要填充的列
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

# 调用 fill_from_dict 函数
fill_from_dict(
    df,
    season='0708',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0708", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5723        Reading         Bolton  2008      2    2
# 5724     Portsmouth        Chelsea  2008      2    2
# 5725       Man City        Arsenal  2008      2    2
# 5726      Tottenham     Man United  2008      2    2
# 5727      Blackburn        Everton  2008      2    2
# 5728     Birmingham          Derby  2008      2    2
# 5729      Liverpool     Sunderland  2008      2    2
# 5730          Wigan       West Ham  2008      2    2
# 5731         Fulham    Aston Villa  2008      2    3
# 5732      Newcastle  Middlesbrough  2008      2    3
# 5733       West Ham     Birmingham  2008      2    9
# 5734     Sunderland          Wigan  2008      2    9
# 5735  Middlesbrough         Fulham  2008      2    9
# 5736        Everton        Reading  2008      2    9
# 5737         Bolton     Portsmouth  2008      2    9
# 5738          Derby      Tottenham  2008      2    9
# 5739    Aston Villa      Newcastle  2008      2    9
# ...

# %%
match_data = {
    # ==================== Matchweek 25 (2 February 2008) ====================
    ('Reading', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25, 'Attendance': 21893
    },  # Source: ESPN [7L5-L6]
    ('Portsmouth', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25, 'Attendance': 20588
    },  # Source: FBref [5L7-L9]
    ('Man City', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25, 'Attendance': 46426
    },  # Source: ESPN [72L7]
    ('Tottenham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25, 'Attendance': 36075
    },  # Source: footballdatabase [73L8]
    ('Blackburn', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25, 'Attendance': 27946
    },  # Source: ESPN [74L6]
    ('Birmingham', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25, 'Attendance': 25924
    },  # Source: football-lineups [75L7]
    ('Liverpool', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25, 'Attendance': 43244
    },  # Source: Sky Sports [76L7]
    ('Wigan', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 25, 'Attendance': 20525
    },  # Source: ESPN [77L6]
    ('Fulham', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 25, 'Attendance': 24760
    },  # Source: Sky Sports [78L7]
    ('Newcastle', 'Middlesbrough'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 25, 'Attendance': 51105
    },  # Source: Sky Sports [79L7]

    # ==================== Matchweek 26 (9 February 2008) ====================
    ('West Ham', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26, 'Attendance': 34884
    },  # Source: ESPN [80L7]
    ('Sunderland', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26, 'Attendance': 40312
    },  # Source: sport.de [81L9]
    ('Middlesbrough', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26, 'Attendance': 26885
    },  # Source: ESPN [82L7]
    ('Everton', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26, 'Attendance': 36582
    },  # Source: Sky Sports [83L6]
    ('Bolton', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26, 'Attendance': 18544
    },  # Source: ESPN [84L7]
    ('Derby', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26, 'Attendance': 33058
    },  # Source: worldfootball [85L6]
    ('Aston Villa', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26, 'Attendance': 42640
    },  # Source: Sky Sports [86L7]
    ('Chelsea', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 26, 'Attendance': 41788
    },  # Source: worldfootball [87L6]
    ('Man United', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 26, 'Attendance': 75970
    },  # Source: ESPN [88L7]
    ('Arsenal', 'Blackburn'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 26, 'Attendance': 60049
    },  # Source: ESPN [89L7]

    # ==================== Matchweek 27 (23 February 2008) ====================
    ('Wigan', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27, 'Attendance': 17020
    },  # Source: WhoScored [3L23]
    ('Portsmouth', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27, 'Attendance': 20102
    },  # Source: ESPN [11L2-L3]
    ('Liverpool', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 27, 'Attendance': 43044
    },  # Source: ESPN [10L2-L3]
    ('Newcastle', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 27, 'Attendance': 52114
    },  # Source: Premier League [2L45]
    ('Birmingham', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 27, 'Attendance': 26567
    },  # Source: ESPN [3L5-L7]
    ('Fulham', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27, 'Attendance': 22826
    },  # Source: ESPN [41L7]
    ('Blackburn', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 27, 'Attendance': 23152
    },  # Source: sport.de [88L35-L38]
    ('Reading', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 27, 'Attendance': 24084
    },  # Source: sport.de [89L22-L24]
    ('Man City', 'Everton'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 27, 'Attendance': 40245
    },  # Source: ESPN [89L13-L15]

    # ==================== Matchweek 28 (1 March 2008) ====================
    ('Man City', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28, 'Attendance': 40742
    },  # Source: sport.de [1L12-L15]
    ('West Ham', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28, 'Attendance': 34969
    },  # Source: 11v11 [1L22-L24]
    ('Newcastle', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28, 'Attendance': 50416
    },  # Source: ESPN [4L12-L13]
    ('Middlesbrough', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28, 'Attendance': 23814
    },  # Source: ESPN [4L8-L10]
    ('Fulham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 28, 'Attendance': 25560
    },  # Source: FBref [4L32-L34]
    ('Birmingham', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28, 'Attendance': 25924
    },  # Source: football-lineups [5L17-L19]
    ('Arsenal', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '18:00', 'Round': 28, 'Attendance': 60097
    },  # Source: worldfootball [12L17]
    ('Derby', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28, 'Attendance': 31318
    },  # Source: sport.de [1L18-L21]
    ('Bolton', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 28, 'Attendance': 24004
    },  # Source: ESPN [13L6-L7]
    ('Everton', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 28, 'Attendance': 33889
    },  # Source: sport.de [1L18-L21]

    # ==================== Matchweek 29 (5-8 March 2008) ====================
    ('Liverpool', 'West Ham'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 29, 'Attendance': 42954
    },  # Source: Sky Sports [14L7]
    ('Blackburn', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29, 'Attendance': 20362
    },  # Source: ESPN [15L6-L7]
    ('Liverpool', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29, 'Attendance': 43375
    },  # Source: fussballdaten [13L38-L39]
    ('Reading', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29, 'Attendance': 23100
    },  # Source: fussballdaten [3L13-L16]
    ('Sunderland', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 29, 'Attendance': 42595
    },  # Source: doingthe92 [16L5-L7]
    ('Tottenham', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 29, 'Attendance': 36088
    },  # Source: sport.de [5L8-L10]
    ('Wigan', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 29, 'Attendance': 21008
    },  # Source: sport.de [5L13-L16]
    ('Aston Villa', 'Middlesbrough'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 29, 'Attendance': 39874
    },  # Source: ESPN [17L6-L7]
    ('Portsmouth', 'Birmingham'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 29, 'Attendance': 18940
    },  # Source: sport.de [5L18-L21]
    ('Chelsea', 'Derby'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 29, 'Attendance': 41028
    },  # Source: stamford-bridge [5L22-L24]

    # ==================== Matchweek 30 (15-17 March 2008) ====================
    ('Sunderland', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 44679
    },  # Source: sport.de [18L7-L9]
    ('West Ham', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 34499
    },  # Source: 11v11 [3L28-L30]
    ('Portsmouth', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 20387
    },  # Source: sport.de [5L28-L30]
    ('Liverpool', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 43380
    },  # Source: LFChistory [5L31-L33]
    ('Derby', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 33051
    },  # Source: fussballdaten [3L32-L35]
    ('Arsenal', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 60062
    },  # Source: worldfootball [5L36-L38]
    ('Fulham', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 30, 'Attendance': 25262
    },  # Source: ESPN [19L6-L7]
    ('Man City', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 30, 'Attendance': 43260
    },  # Source: sport.de [4L19-L21]
    ('Wigan', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 30, 'Attendance': 21287
    },  # Source: sport.de [5L21-L23]
    ('Birmingham', 'Newcastle'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 30, 'Attendance': 25777
    },  # Source: Sky Sports [20L7]

    # ==================== Matchweek 31 (22-23 March 2008) ====================
    ('Reading', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 24085
    },  # Source: sport.de [22L7-L9]
    ('Aston Villa', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 41500
    },  # Source: AVFC History [5L25-L27]
    ('Blackburn', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 20140
    },  # Source: sport.de [5L30-L32]
    ('Bolton', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 21511
    },  # Source: sport.de [5L33-L35]
    ('Everton', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 38110
    },  # Source: Sky Sports [5L36-L38]
    ('Middlesbrough', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 26436
    },  # Source: 11v11 [5L39-L41]
    ('Newcastle', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 50557
    },  # Source: Sky Sports [5L42-L44]
    ('Tottenham', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 35998
    },  # Source: Sky Sports [5L45-L47]
    ('Chelsea', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 31, 'Attendance': 41824
    },  # Source: ESPN [23L6-L7]
    ('Man United', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 31, 'Attendance': 76000
    },  # Source: fussballdaten [3L19-L20]

    # ==================== Matchweek 32 (29-30 March 2008) ====================
    ('Birmingham', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': 22962
    },  # Source: ESPN [24L6-L7]
    ('Bolton', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': 24506
    },  # Source: sport.de [6L15-L18]
    ('Derby', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': 32324
    },  # Source: sport.de [6L20-L23]
    ('Man United', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 32, 'Attendance': 76010
    },  # Source: ESPN [6L24-L27]
    ('Portsmouth', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': 19110
    },  # Source: sport.de [6L30-L33]
    ('Reading', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': 23415
    },  # Source: sport.de [6L35-L38]
    ('Sunderland', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': 38813
    },  # Source: sport.de [6L40-L43]
    ('Liverpool', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 32, 'Attendance': 44295
    },  # Source: ESPN [25L6-L7]
    ('Tottenham', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 32, 'Attendance': 36100
    },  # Source: sport.de [6L46-L49]
    ('Chelsea', 'Middlesbrough'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 32, 'Attendance': 41615
    },  # Source: stamford-bridge [6L50-L52]

    # ==================== Matchweek 33 (5-8 April 2008) ====================
    ('Man City', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33, 'Attendance': 42594
    },  # Source: Sky Sports [26L7]
    ('Arsenal', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 33, 'Attendance': 60111
    },  # Source: Sky Sports [30L6-L7]
    ('Aston Villa', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33, 'Attendance': 41235
    },  # Source: sport.de [7L17-L20]
    ('Blackburn', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33, 'Attendance': 21961
    },  # Source: sport.de [7L23-L26]
    ('Fulham', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33, 'Attendance': 24640
    },  # Source: sport.de [7L29-L32]
    ('Wigan', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33, 'Attendance': 16652
    },  # Source: sport.de [7L35-L38]
    ('Newcastle', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 33, 'Attendance': 50346
    },  # Source: sport.de [7L41-L44]
    ('Everton', 'Derby'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 33, 'Attendance': 37011
    },  # Source: sport.de [7L47-L50]
    ('Middlesbrough', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 33, 'Attendance': 33952
    },  # Source: Sky Sports [31L7]
    ('West Ham', 'Portsmouth'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 33, 'Attendance': 33629
    },  # Source: Sky Sports [27L7]

    # ==================== Matchweek 34 (12-13 April 2008) ====================
    ('Reading', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': 24112
    },  # Source: Sky Sports [28L15-L16]
    ('Portsmouth', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 34, 'Attendance': 20507
    },  # Source: sport.de [32L8-L9]
    ('Derby', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': 32763
    },  # Source: sport.de [8L19-L22]
    ('Tottenham', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': 35845
    },  # Source: sport.de [8L25-L28]
    ('Birmingham', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': 25231
    },  # Source: sport.de [8L31-L34]
    ('Sunderland', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': 42209
    },  # Source: sport.de [8L37-L40]
    ('Bolton', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': 21285
    },  # Source: sport.de [8L43-L46]
    ('Liverpool', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 34, 'Attendance': 43283
    },  # Source: Sky Sports [29L7]
    ('Man United', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 34, 'Attendance': 75698
    },  # Source: sport.de [8L49-L52]
}

# 要填充的列
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

# 调用 fill_from_dict 函数
fill_from_dict(
    df,
    season='0708',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0708", 'WeekDay')
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5782     Man United         Bolton  2008      3   19
# 5783      Tottenham        Chelsea  2008      3   19
# 5823        Chelsea          Wigan  2008      4   14
# 5824        Everton        Chelsea  2008      4   17
# 5825        Arsenal        Reading  2008      4   19
# 5826      Blackburn     Man United  2008      4   19
# 5827         Fulham      Liverpool  2008      4   19
# 5828  Middlesbrough         Bolton  2008      4   19
# 5829       West Ham          Derby  2008      4   19
# 5830          Wigan      Tottenham  2008      4   19
# 5831    Aston Villa     Birmingham  2008      4   20
# 5832       Man City     Portsmouth  2008      4   20
# 5833      Newcastle     Sunderland  2008      4   20
# 5834       West Ham      Newcastle  2008      4   26
# 5835          Wigan        Reading  2008      4   26
# 5836      Tottenham         Bolton  2008      4   26
# 5837     Sunderland  Middlesbrough  2008      4   26
# ...

# %%
match_data = {
    # ==================== Matchweek 29 (19 March 2008) ====================
    ('Man United', 'Bolton'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 29, 'Attendance': 75476
    },  # Source: ESPN [0L7-L8], 11v11 [0L27]
    ('Tottenham', 'Chelsea'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 27, 'Attendance': 36178
    },  # Source: ESPN [1L6-L7], 11v11 [1L16]

    # ==================== Matchweek 34 (14 April 2008) ====================
    ('Chelsea', 'Wigan'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 34, 'Attendance': 40487
    },  # Source: ESPN [2L7-L8], 11v11 [2L31]

    # ==================== Matchweek 35 (17 April 2008) ====================
    ('Everton', 'Chelsea'): {
        'WeekDay': 'Thu', 'Time': '20:00', 'Round': 35, 'Attendance': 37112
    },  # Source: sport.de [3L8-L10], ESPN [3L21-L22]

    # ==================== Matchweek 35 (19 April 2008) ====================
    ('Arsenal', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 35, 'Attendance': 60109
    },  # Source: ESPN [4L7-L8], sport.de [4L12-L14]
    ('Blackburn', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 35, 'Attendance': 30316
    },  # Source: ESPN [5L7-L8], sport.de [5L13-L14]
    ('Fulham', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35, 'Attendance': 25311
    },  # Source: sport.de [6L8-L10], LFChistory [6L22-L23]
    ('Middlesbrough', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35, 'Attendance': 25037
    },  # Source: ESPN [7L8], sport.de [7L14-L15]
    ('West Ham', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35, 'Attendance': 34612
    },  # Source: sport.de [8L8-L10], Sky Sports [8L13-L14]
    ('Wigan', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35, 'Attendance': 18673
    },  # Source: sport.de [9L8-L10], Sky Sports [9L14-L15]
    ('Aston Villa', 'Birmingham'): {
        'WeekDay': 'Sun', 'Time': '13:00', 'Round': 35, 'Attendance': 42584
    },  # Source: sport.de [10L8-L10], Sky Sports [10L13-L14]
    ('Man City', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 35, 'Attendance': 40205
    },  # Source: ESPN [11L7-L8], 11v11 [11L26-L27]
    ('Newcastle', 'Sunderland'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 35, 'Attendance': 52305
    },  # Source: Sky Sports [12L7-L8], 11v11 [12L13]

    # ==================== Matchweek 36 (26 April 2008) ====================
    ('West Ham', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': 34980
    },  # Source: sport.de [13L8-L10], 11v11 [13L18-L19]
    ('Wigan', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': 19043
    },  # Source: ESPN [14L7-L8], 11v11 [14L30]
    ('Tottenham', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': 36176
    },  # Source: ESPN [15L7-L8], worldfootball [15L19]
    ('Sunderland', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': 45059
    },  # Source: ESPN [16L7-L8], sport.de [16L13-L14]
    ('Chelsea', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 36, 'Attendance': 41828
    },  # Source: ESPN [17L7], sport.de [17L24-L26]
    ('Birmingham', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': 29252
    },  # Source: ESPN [18L7-L8], sport.de [18L18-L19]
    ('Man City', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': 44504
    },  # Source: ESPN [19L7], sport.de [19L21-L22]
    ('Everton', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 36, 'Attendance': 37936
    },  # Source: ESPN [20L7-L8], sport.de [20L12-L14]
    ('Portsmouth', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '14:30', 'Round': 36, 'Attendance': 18722
    },  # Source: sport.de [21L8-L10]
    ('Derby', 'Arsenal'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 36, 'Attendance': 33003
    },  # Source: ESPN [22L7-L8], sport.de [22L21-L22]

    # ==================== Matchweek 37 (3 May 2008) ====================
    ('Blackburn', 'Derby'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 26110
    },  # Source: ESPN [23L6], 11v11 [23L26]
    ('Aston Villa', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 42640
    },  # Source: ESPN [24L7-L8], 11v11 [24L31-L32]
    ('Bolton', 'Sunderland'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 37, 'Attendance': 25053
    },  # Source: ESPN [25L7-L8], sport.de [25L22-L24]
    ('Fulham', 'Birmingham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 25308
    },  # Source: Sky Sports [26L8], 11v11 [26L12-L13]
    ('Man United', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 37, 'Attendance': 76013
    },  # Source: ESPN [27L7-L8], 11v11 [27L11-L12]
    ('Middlesbrough', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 24828
    },  # Source: ESPN [28L7], 11v11 [28L18-L19]
    ('Reading', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 24125
    },  # Source: ESPN [29L7-L8], 11v11 [29L19-L20]
    ('Arsenal', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 37, 'Attendance': 60123
    },  # Source: ESPN [30L6-L7], 11v11 [30L10]
    ('Liverpool', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 37, 'Attendance': 43074
    },  # Source: ESPN [31L6-L7], worldfootball [31L21]
    ('Newcastle', 'Chelsea'): {
        'WeekDay': 'Mon', 'Time': '16:00', 'Round': 37, 'Attendance': 52305
    },  # Source: sport.de [32L8-L10], 11v11 [32L27]

    # ==================== Matchweek 38 (11 May 2008) ====================
    ('Sunderland', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 47802
    },  # Source: ESPN [33L7-L8], sport.de [33L12-L14]
    ('West Ham', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 34969
    },  # Source: sport.de [34L8-L10], football-lineups [34L13]
    ('Portsmouth', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 20532
    },  # Source: sport.de [35L8-L10], Fulham Fandom [35L13-L14]
    ('Wigan', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 25133
    },  # Source: ESPN [36L7], 11v11 [36L15-L16]
    ('Middlesbrough', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 27613
    },  # Source: sport.de [37L8-L10], 11v11 [37L13-L14]
    ('Tottenham', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 36063
    },  # Source: ESPN [38L7-L8], sport.de [38L18-L19]
    ('Derby', 'Reading'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 33087
    },  # Source: Hob Nob Anyone? [39L6], Le Figaro [39L10]
    ('Chelsea', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 41755
    },  # Source: ESPN [40L6], sport.de [40L15-L17]
    ('Everton', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 39592
    },  # Source: ESPN [41L7-L8], sport.de [41L17-L19]
    ('Birmingham', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 26668
    },  # Source: sport.de [42L8-L10], Sky Sports [42L14]
}

# 要填充的列
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

# 调用 fill_from_dict 函数
fill_from_dict(
    df,
    season='0708',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0708", 'Attendance')
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5485         Bolton      Newcastle  2007      8   11
# 5486          Derby     Portsmouth  2007      8   11
# 5488  Middlesbrough      Blackburn  2007      8   11
# 5489     Sunderland      Tottenham  2007      8   11
# 5490       West Ham       Man City  2007      8   11
# 5492        Chelsea     Birmingham  2007      8   12
# 5493     Man United        Reading  2007      8   12
# 5494      Tottenham        Everton  2007      8   14
# 5495       Man City          Derby  2007      8   15
# 5496     Portsmouth     Man United  2007      8   15
# 5499     Birmingham     Sunderland  2007      8   15
# 5502      Tottenham          Derby  2007      8   18
# 5503     Portsmouth         Bolton  2007      8   18
# 5504     Birmingham       West Ham  2007      8   18
# 5507        Reading        Everton  2007      8   18
# 5508      Blackburn        Arsenal  2007      8   19
# 5509      Liverpool        Chelsea  2007      8   19
# ...

# %%
match_attendance_data = {
    # ==================== 2007811 ====================
    ('Bolton', 'Newcastle'): 25414,              # Source: 11v11.com [0L24]
    ('Derby', 'Portsmouth'): 32176,              # Source: ESPN [1L7]
    ('Middlesbrough', 'Blackburn'): 25058,       # Source: 11v11.com [2L11]
    ('Sunderland', 'Tottenham'): 43967,          # Source: 11v11.com [3L7]
    ('West Ham', 'Man City'): 34921,             # Source: 11v11.com [4L11]

    # ==================== 2007812 ====================
    ('Chelsea', 'Birmingham'): 41590,            # Source: ESPN [5L7]
    ('Man United', 'Reading'): 75655,            # Source: 11v11.com [6L11]

    # ==================== 2007814 ====================
    ('Tottenham', 'Everton'): 35716,             # Source: 11v11.com [7L11]

    # ==================== 2007815 ====================
    ('Man City', 'Derby'): 43620,                # Source: ESPN [8L7]
    ('Portsmouth', 'Man United'): 20510,         # Source: Sky Sports [9L8]
    ('Birmingham', 'Sunderland'): 24898,         # Source: Sky Sports [10L10]

    # ==================== 2007818 ====================
    ('Tottenham', 'Derby'): 35600,               # Source: Sky Sports [11L7]
    ('Portsmouth', 'Bolton'): 17108,             # Source: Sky Sports [12L7]
    ('Birmingham', 'West Ham'): 24961,           # Source: Sky Sports [13L14]
    ('Reading', 'Everton'): 22813,               # Source: ESPN [14L7]

    # ==================== 2007819 ====================
    ('Blackburn', 'Arsenal'): 24917,             # Source: 11v11.com [15L7]
    ('Liverpool', 'Chelsea'): 43924,             # Source: LFChistory [16L6]
    ('Man City', 'Man United'): 44955,           # Source: ESPN [17L7]

    # ==================== 2007825 ====================
    ('Sunderland', 'Liverpool'): 45645,          # Source: 11v11.com [18L14-L15]
    ('Everton', 'Blackburn'): 33850,             # Source: Sky Sports [19L11]
    ('Derby', 'Birmingham'): 31117,              # Source: ESPN [20L7]
    ('Arsenal', 'Man City'): 60114,              # Source: 11v11.com [21L11]
    ('Bolton', 'Reading'): 20023,                # Source: Hob Nob Anyone? [22L7]
    ('Chelsea', 'Portsmouth'): 41501,            # Source: ESPN [23L7]

    # ==================== 2007826 ====================
    ('Man United', 'Tottenham'): 75696,          # Source: ESPN [24L8]
    ('Middlesbrough', 'Newcastle'): 28875,       # Source: ESPN [25L7]

    # ==================== 200791 ====================
    ('Reading', 'West Ham'): 23533,              # Source: 11v11.com [26L15]
    ('Newcastle', 'Wigan'): 50461,               # Source: Sky Sports [27L7]
    ('Fulham', 'Tottenham'): 24007,              # Source: Sky Sports [28L7]
    ('Man United', 'Sunderland'): 75648,         # Source: ESPN [29L8]
    ('Middlesbrough', 'Birmingham'): 22920,      # Source: ESPN [30L7]
    ('Bolton', 'Everton'): 22064,                # Source: Sky Sports [31L11]
    ('Liverpool', 'Derby'): 44076,               # Source: ESPN [32L6]

    # ==================== 200792 ====================
    ('Aston Villa', 'Chelsea'): 37714,           # Source: 11v11.com [33L15]
    ('Blackburn', 'Man City'): 26881,            # Source: ESPN [34L13]
    ('Arsenal', 'Portsmouth'): 60114,            # Source: ESPN [35L7]
}

fill_from_dict(
    df,
    season='0708',
    data=match_attendance_data,
    value_col=['Attendance'],
    inplace=True
)

# %%
null_rows(df, "0708", 'Attendance')
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5531     Birmingham         Bolton  2007      9   15
# 5532        Chelsea      Blackburn  2007      9   15
# 5533        Everton     Man United  2007      9   15
# 5534     Portsmouth      Liverpool  2007      9   15
# 5535     Sunderland        Reading  2007      9   15
# 5536      Tottenham        Arsenal  2007      9   15
# 5537       West Ham  Middlesbrough  2007      9   15
# 5538          Wigan         Fulham  2007      9   15
# 5539       Man City    Aston Villa  2007      9   16
# 5540          Derby      Newcastle  2007      9   17
# 5541  Middlesbrough     Sunderland  2007      9   22
# 5542        Reading          Wigan  2007      9   22
# 5543        Arsenal          Derby  2007      9   22
# 5544         Fulham       Man City  2007      9   22
# 5545      Liverpool     Birmingham  2007      9   22
# 5546         Bolton      Tottenham  2007      9   23
# 5547     Man United        Chelsea  2007      9   23
# ...

# %%
match_attendance_data = {
    # ==================== 20078 ====================
    ('Bolton', 'Newcastle'): 25414,              # Source: 11v11.com [0L24]
    ('Derby', 'Portsmouth'): 32176,              # Source: ESPN [1L7]
    ('Middlesbrough', 'Blackburn'): 25058,       # Source: 11v11.com [2L11]
    ('Sunderland', 'Tottenham'): 43967,          # Source: 11v11.com [3L7]
    ('West Ham', 'Man City'): 34921,             # Source: 11v11.com [4L11]
    ('Chelsea', 'Birmingham'): 41590,            # Source: ESPN [5L7]
    ('Man United', 'Reading'): 75655,            # Source: 11v11.com [6L11]
    ('Tottenham', 'Everton'): 35716,             # Source: 11v11.com [7L11]
    ('Man City', 'Derby'): 43620,                # Source: ESPN [8L7]
    ('Portsmouth', 'Man United'): 20510,         # Source: Sky Sports [9L8]
    ('Birmingham', 'Sunderland'): 24898,         # Source: Sky Sports [10L10]
    ('Tottenham', 'Derby'): 35600,               # Source: Sky Sports [11L7]
    ('Portsmouth', 'Bolton'): 17108,             # Source: Sky Sports [12L7]
    ('Birmingham', 'West Ham'): 24961,           # Source: Sky Sports [13L14]
    ('Reading', 'Everton'): 22813,               # Source: ESPN [14L7]
    ('Blackburn', 'Arsenal'): 24917,             # Source: 11v11.com [15L7]
    ('Liverpool', 'Chelsea'): 43924,             # Source: LFChistory [16L6]
    ('Man City', 'Man United'): 44955,           # Source: ESPN [17L7]
    ('Sunderland', 'Liverpool'): 45645,          # Source: 11v11.com [18L14-L15]
    ('Everton', 'Blackburn'): 33850,             # Source: Sky Sports [19L11]
    ('Derby', 'Birmingham'): 31117,              # Source: ESPN [20L7]
    ('Arsenal', 'Man City'): 60114,              # Source: 11v11.com [21L11]
    ('Bolton', 'Reading'): 20023,                # Source: Hob Nob Anyone? [22L7]
    ('Chelsea', 'Portsmouth'): 41501,            # Source: ESPN [23L7]
    ('Man United', 'Tottenham'): 75696,          # Source: ESPN [24L8]
    ('Middlesbrough', 'Newcastle'): 28875,       # Source: ESPN [25L7]

    # ==================== 20079 ====================
    ('Reading', 'West Ham'): 23533,              # Source: 11v11.com [26L15]
    ('Newcastle', 'Wigan'): 50461,               # Source: Sky Sports [27L7]
    ('Fulham', 'Tottenham'): 24007,              # Source: Sky Sports [28L7]
    ('Man United', 'Sunderland'): 75648,         # Source: ESPN [29L8]
    ('Middlesbrough', 'Birmingham'): 22920,      # Source: ESPN [30L7]
    ('Bolton', 'Everton'): 22064,                # Source: Sky Sports [31L11]
    ('Liverpool', 'Derby'): 44076,               # Source: ESPN [32L6]
    ('Aston Villa', 'Chelsea'): 37714,           # Source: 11v11.com [33L15]
    ('Blackburn', 'Man City'): 26881,            # Source: ESPN [34L13]
    ('Arsenal', 'Portsmouth'): 60114,            # Source: ESPN [35L7]
    ('Birmingham', 'Bolton'): 28124,             # Source: Wikipedia [8L22], Sky Sports [0L21]
    ('Chelsea', 'Blackburn'): 41062,             # Source: ESPN [1L8], 11v11.com [1L21]
    ('Everton', 'Man United'): 39364,            # Source: Sky Sports [2L7]
    ('Portsmouth', 'Liverpool'): 20388,          # Source: LFChistory [3L6]
    ('Sunderland', 'Reading'): 39272,            # Source: 11v11.com [4L13]
    ('Tottenham', 'Arsenal'): 36053,             # Source: ESPN [5L7]
    ('West Ham', 'Middlesbrough'): 34351,        # Source: sport.de [6L9]
    ('Wigan', 'Fulham'): 16973,                  # Source: ESPN [7L6]
    ('Man City', 'Aston Villa'): 38363,          # Source: ESPN [16L7]
    ('Derby', 'Newcastle'): 33016,               # Source: BBC Sport [17L7]
    ('Middlesbrough', 'Sunderland'): 30675,      # Source: ESPN [18L7]
    ('Reading', 'Wigan'): 21379,                 # Source: ESPN [19L7]
    ('Arsenal', 'Derby'): 60122,                 # Source: ESPN [20L7]
    ('Fulham', 'Man City'): 24674,               # Source: Sky Sports [21L7]
    ('Liverpool', 'Birmingham'): 44215,          # Source: ESPN [22L7]
    ('Bolton', 'Tottenham'): 20308,              # Source: ESPN [23L7]
    ('Man United', 'Chelsea'): 75663,            # Source: ESPN [24L7]
    ('Newcastle', 'West Ham'): 50104,            # Source: sport.de [25L9]
    ('Aston Villa', 'Everton'): 38235,           # Source: Transfermarkt [26L6]
    ('Blackburn', 'Portsmouth'): 19506,          # Source: ESPN [27L7]

    # ==================== 200710 ====================
    ('Birmingham', 'Man United'): 26526,         # Source: worldfootball.net [28L7]
    ('Chelsea', 'Fulham'): 41837,                # Source: ESPN [29L6]
    ('Man City', 'Newcastle'): 40606,            # Source: ESPN [30L7]
    ('Portsmouth', 'Reading'): 20102,            # Source: Wikipedia [31L6]
    ('Sunderland', 'Blackburn'): 41252,          # Source: Championat [32L7]
    ('West Ham', 'Arsenal'): 34966,              # Source: Sky Sports [33L7]
    ('Wigan', 'Liverpool'): 24311,               # Source: LFChistory [34L6]
    ('Derby', 'Bolton'): 31503,                  # Source: sport.de [35L9]
    ('Everton', 'Middlesbrough'): 31885,         # Source: ESPN [36L6]
    ('Tottenham', 'Aston Villa'): 36094,         # Source: ESPN [37L6]
    ('Aston Villa', 'West Ham'): 40842,          # Source: AVFC History [38L6]
    ('Man United', 'Wigan'): 75300,              # Source: worldfootball.net [39L6]
    ('Reading', 'Derby'): 23091,                 # Source: ESPN [40L6]
    ('Newcastle', 'Everton'): 50152,             # Source: ESPN [41L6]
    ('Man City', 'Middlesbrough'): 40438,        # Source: ESPN [42L7]
    ('Arsenal', 'Sunderland'): 60098,            # Source: ESPN [43L7]
    ('Fulham', 'Portsmouth'): 20774,             # Source: 11v11.com [44L7]
    ('Blackburn', 'Birmingham'): 19316,          # Source: ESPN [45L6]
    ('Liverpool', 'Tottenham'): 43986,           # Source: ESPN [46L7]
    ('Bolton', 'Chelsea'): 20059,                # Source: ESPN [47L7]
    ('Aston Villa', 'Man United'): 42640,        # Source: Sky Sports [48L7]
    ('Wigan', 'Portsmouth'): 17695,              # Source: ESPN [49L7]
    ('Middlesbrough', 'Chelsea'): 27699,         # Source: stamford-bridge.com [50L7]
    ('Arsenal', 'Bolton'): 59442,                # Source: Sky Sports [51L6]
    ('Fulham', 'Derby'): 22576,                  # Source: BBC Sport [52L6]
    ('Everton', 'Liverpool'): 40049,             # Source: Sky Sports [53L7]
    ('Blackburn', 'Reading'): 19425,             # Source: ESPN [54L7]
    ('Man City', 'Birmingham'): 45688,           # Source: ESPN [55L7]
    ('West Ham', 'Sunderland'): 34913,           # Source: ESPN [56L7]
    ('Newcastle', 'Tottenham'): 51411,           # Source: Sky Sports [57L8]
    ('Birmingham', 'Wigan'): 27661,              # Source: ESPN [58L7]
    ('Chelsea', 'Man City'): 41832,              # Source: ESPN [59L6]
    ('Man United', 'Middlesbrough'): 75720,      # Source: ESPN [60L7]
    ('Portsmouth', 'West Ham'): 20525,           # Source: Sky Sports [61L7]
    ('Reading', 'Newcastle'): 24119,             # Source: ESPN [62L7]
    ('Sunderland', 'Fulham'): 39392,             # Source: sport.de [63L9]
    ('Tottenham', 'Blackburn'): 36086,           # Source: Sky Sports [64L6]
}

fill_from_dict(
    df,
    season='0708',
    data=match_attendance_data,
    value_col=['Attendance'],
    inplace=True
)

# %%
missing_report(df,"0708")
# Out:
# XGHome    380
# XGAway    380
# dtype: int64

# %%
df.to_csv("Data/Data6.csv", index=False)

# %% [markdown]
# ---

# %%
missing_report(df,"0607")
# Out:
# WeekDay                          380
# Time                             380
# Round                            380
# Attendance                       380
# XGHome                           380
# XGAway                           380
# SeasonPosAway                     19
# SeasonPlayedAway                  19
# SeasonWinAway                     19
# SeasonDrawAway                    19
# SeasonLossAway                    19
# SeasonGFAway                      19
# SeasonGAAway                      19
# SeasonGDAway                      19
# SeasonPointsAway                  19
# QualificationOrRelegationAway     19
# dtype: int64

# %%
null_rows(df, "0607", 'SeasonPosAway')['AwayTeam'].unique()
# Out:
# array(['Bolton'], dtype=object)

# %%
df['QualificationOrRelegationAway'].unique()
# Out:
# array(['Not Applicable',
#        'Relegation to the Football League First Division',
#        'Qualification for the UEFA Cup first round',
#        'Qualification for the Champions League group stage',
#        "Qualification for the UEFA Cup Winners' Cup", nan,
#        'Qualification for the Champions League second qualifying round',
#        'Qualification for the Intertoto Cup third round',
#        'Qualification for the Champions League third qualifying round',
#        'Qualification for the Champions League first group stage',
#        'Qualification for the UEFA Cup first round[a]',
#        'Qualification for the Champions League third qualifying round[a]',
#        'Qualification for the UEFA Cup qualifying round[a]Relegation to the Football League First Division',
#        'Qualification for the UEFA Cup first round[c]',
#        'Qualification for the Intertoto Cup second round',
#        'Qualification for the UEFA Cup first round[b]',
# ...

# %%
df[ (df['AwayTeam'] == 'Everton') & (df['Season'] == '0607') ]['QualificationOrRelegationAway']
# Out:
# 5120    Qualification for the UEFA Cup first round[a]
# 5123    Qualification for the UEFA Cup first round[a]
# 5161    Qualification for the UEFA Cup first round[a]
# 5176    Qualification for the UEFA Cup first round[a]
# 5199    Qualification for the UEFA Cup first round[a]
# 5206    Qualification for the UEFA Cup first round[a]
# 5234    Qualification for the UEFA Cup first round[a]
# 5247    Qualification for the UEFA Cup first round[a]
# 5263    Qualification for the UEFA Cup first round[a]
# 5284    Qualification for the UEFA Cup first round[a]
# 5316    Qualification for the UEFA Cup first round[a]
# 5341    Qualification for the UEFA Cup first round[a]
# 5355    Qualification for the UEFA Cup first round[a]
# 5373    Qualification for the UEFA Cup first round[a]
# 5383    Qualification for the UEFA Cup first round[a]
# 5412    Qualification for the UEFA Cup first round[a]
# 5423    Qualification for the UEFA Cup first round[a]
# ...

# %%
# Season statistics for Bolton Wanderers in 2006-07
bolton_stats = {
    'SeasonPosAway': 7,
    'SeasonPlayedAway': 38,
    'SeasonWinAway': 16,
    'SeasonDrawAway': 8,
    'SeasonLossAway': 14,
    'SeasonGFAway': 47,
    'SeasonGAAway': 52,
    'SeasonGDAway': -5,
    'SeasonPointsAway': 56,
    'QualificationOrRelegationAway': 'Qualification for the UEFA Cup first round[a]'
}


# List of columns to fill
away_cols = [
    'SeasonPosAway', 'SeasonPlayedAway', 'SeasonWinAway', 'SeasonDrawAway',
    'SeasonLossAway', 'SeasonGFAway', 'SeasonGAAway', 'SeasonGDAway',
    'SeasonPointsAway', 'QualificationOrRelegationAway'
]

# Fill the columns for all rows where AwayTeam is 'Bolton' in the 2009-10 season
for idx, row in df[df['Season'] == '0607'].iterrows():
    if row['AwayTeam'] == 'Bolton':
        for col in away_cols:
            df.loc[(df['Season'] == '0607') & (df.index == idx), col] = bolton_stats[col]

# %%
null_rows(df, "0607", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5104       West Ham       Charlton  2006      8   19
# 5105      Sheffield      Liverpool  2006      8   19
# 5106        Reading  Middlesbrough  2006      8   19
# 5107      Newcastle          Wigan  2006      8   19
# 5108        Everton        Watford  2006      8   19
# 5109         Bolton      Tottenham  2006      8   19
# 5110        Arsenal    Aston Villa  2006      8   19
# 5111     Portsmouth      Blackburn  2006      8   19
# 5112        Chelsea       Man City  2006      8   20
# 5113     Man United         Fulham  2006      8   20
# 5114      Tottenham      Sheffield  2006      8   22
# 5115        Watford       West Ham  2006      8   22
# 5116       Man City     Portsmouth  2006      8   23
# 5117  Middlesbrough        Chelsea  2006      8   23
# 5118       Charlton     Man United  2006      8   23
# 5119    Aston Villa        Reading  2006      8   23
# 5120      Blackburn        Everton  2006      8   23
# ...

# %%
match_data = {
    # ==================== Matchweek 1 (19-20 August 2006) ====================
    ('West Ham', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 1, 'Attendance': 34704
    },  # Source: FBref [1L26-L27], Transfermarkt [1L31-L32]
    ('Sheffield', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1, 'Attendance': 31726
    },  # Source: FBref [2L7-L8], Sky Sports [2L12]
    ('Reading', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 1, 'Attendance': 23802
    },  # Source: FBref [3L11-L12], Transfermarkt [3L7-L8]
    ('Newcastle', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 1, 'Attendance': 52227
    },  # Source: FBref [4L18-L19], sport.de [4L9]
    ('Everton', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 1, 'Attendance': 39691
    },  # Source: FBref [5L24-L25], Transfermarkt [5L9-L10]
    ('Bolton', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1, 'Attendance': 22899
    },  # Source: FBref [8L25-L26]
    ('Arsenal', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1, 'Attendance': 60023
    },  # Source: FBref [6L24-L26]
    ('Portsmouth', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 1, 'Attendance': None  
    },
    ('Chelsea', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 1, 'Attendance': None  
    },
    ('Man United', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 1, 'Attendance': 75115
    },  # Source: FBref [7L19-L21]

    # ==================== Matchweek 2 (22-23 August 2006) ====================
    ('Tottenham', 'Sheffield'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 2, 'Attendance': 35287
    },  # Source: FBref [8L30-L32]
    ('Watford', 'West Ham'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 2, 'Attendance': 18344
    },  # Source: Transfermarkt [12L35-L37]
    ('Man City', 'Portsmouth'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 2, 'Attendance': None  
    },
    ('Middlesbrough', 'Chelsea'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 2, 'Attendance': 29269
    },  # Source: FBref [11L26-L28]
    ('Charlton', 'Man United'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 2, 'Attendance': None  
    },
    ('Aston Villa', 'Reading'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 2, 'Attendance': 37329
    },  # Source: FBref [14L24-L26]
    ('Blackburn', 'Everton'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 2, 'Attendance': None  
    },
    ('Fulham', 'Bolton'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 2, 'Attendance': 18559
    },  # Source: FBref [7L25-L27]

    # ==================== Matchweek 3 (26-28 August 2006) ====================
    ('Watford', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 3, 'Attendance': None  
    },
    ('Tottenham', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': 35540
    },  # Source: FBref [8L35-L37]
    ('Wigan', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': 14834
    },  # Source: FBref [14L29-L31]
    ('Liverpool', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': None  
    },
    ('Fulham', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': 18312
    },  # Source: FBref [7L31-L32], FBref [13L32]
    ('Charlton', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': None  
    },
    ('Man City', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 3, 'Attendance': 40699
    },  # Source: FBref [6L30-L31]
    ('Aston Villa', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 3, 'Attendance': 35141
    },  # Source: FBref [15L27-L29]
    ('Blackburn', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 3, 'Attendance': None  
    },
    ('Middlesbrough', 'Portsmouth'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 3, 'Attendance': 24834
    },  # Source: FBref [11L32-L34]

    # ==================== Matchweek 4 (9-11 September 2006) ====================
    ('Portsmouth', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': None  
    },
    ('Sheffield', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': 29864
    },  # Source: FBref [13L35-L37]
    ('Newcastle', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': 51398
    },  # Source: FBref [15L33-L34]
    ('Arsenal', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': 60007
    },  # Source: FBref [6L36-L37]
    ('Everton', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 4, 'Attendance': None  
    },
    ('Chelsea', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': None  
    },
    ('Bolton', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 4, 'Attendance': None  
    },
    ('Man United', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 4, 'Attendance': None  
    },
    ('West Ham', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 4, 'Attendance': None  
    },
    ('Reading', 'Man City'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 4, 'Attendance': 23924
    },  # Source: FBref [14L35-L37]

    # ==================== Matchweek 5 (16-17 September 2006) ====================
    ('Watford', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None  
    },
    ('Bolton', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None  
    },
    ('Everton', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None  
    },
    ('Charlton', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None  
    },
    ('Sheffield', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 5, 'Attendance': None  
    },
    ('Blackburn', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 5, 'Attendance': None  
    },
    ('Chelsea', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 5, 'Attendance': None  
    },
    ('Man United', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 5, 'Attendance': None  
    },
    ('Tottenham', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 5, 'Attendance': None  
    },
    ('West Ham', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 5, 'Attendance': None  
    },

    # ==================== Matchweek 6 (20 September 2006) ====================
    ('Liverpool', 'Newcastle'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 6, 'Attendance': None  
    },

    # ==================== Matchweek 7 (23-25 September 2006) ====================
    ('Wigan', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None  
    },
    ('Reading', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 7, 'Attendance': None  
    },
    ('Middlesbrough', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None  
    },
    ('Fulham', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None  
    },
    ('Liverpool', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 7, 'Attendance': None  
    },
    ('Aston Villa', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None  
    },
    ('Arsenal', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None  
    },
    ('Man City', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 7, 'Attendance': None  
    },
    ('Newcastle', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 7, 'Attendance': None  
    },
    ('Portsmouth', 'Bolton'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 7, 'Attendance': None  
    },

    # ==================== Matchweek 8 (30 September - 2 October 2006) ====================
    ('Sheffield', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None  
    },
    ('Bolton', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None  
    },
    ('Chelsea', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None  
    },
    ('Charlton', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None  
    },
    ('Everton', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 8, 'Attendance': None  
    },
    ('Tottenham', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 8, 'Attendance': None  
    },
    ('West Ham', 'Reading'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 8, 'Attendance': None  
    },
    ('Blackburn', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 8, 'Attendance': None  
    },
    ('Man United', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 8, 'Attendance': None  
    },
    ('Watford', 'Fulham'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 8, 'Attendance': None  
    },

    # ==================== Matchweek 9 (14-16 October 2006) ====================
    ('Arsenal', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9, 'Attendance': None  
    },
    ('Aston Villa', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9, 'Attendance': None  
    },
    ('Liverpool', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9, 'Attendance': None  
    },
    ('Middlesbrough', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9, 'Attendance': None  
    },
    ('Portsmouth', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9, 'Attendance': None  
    },
    ('Reading', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9, 'Attendance': None  
    },
    ('Wigan', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9, 'Attendance': None  
    },
    ('Man City', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 9, 'Attendance': None  
    },
    ('Newcastle', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 9, 'Attendance': None  
    },
    ('Fulham', 'Charlton'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 9, 'Attendance': None  
    },

    # ==================== Matchweek 10 (21-23 October 2006) ====================
    ('Wigan', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None  
    },
    ('Everton', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None  
    },
    ('Charlton', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None  
    },
    ('Aston Villa', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None  
    },
    ('Chelsea', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 10, 'Attendance': None  
    },
    ('Blackburn', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 10, 'Attendance': None  
    },
    ('Man United', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 10, 'Attendance': None  
    },
    ('Middlesbrough', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 10, 'Attendance': None  
    },
    ('Reading', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 10, 'Attendance': None  
    },
    ('Tottenham', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 10, 'Attendance': None  
    },

    # ==================== Matchweek 11 (28-30 October 2006) ====================
    ('Watford', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None  
    },
    ('Sheffield', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None  
    },
    ('Portsmouth', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None  
    },
    ('Liverpool', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None  
    },
    ('Fulham', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None  
    },
    ('Bolton', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None  
    },
    ('Arsenal', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None  
    },
    ('Newcastle', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11, 'Attendance': None  
    },
    ('West Ham', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 11, 'Attendance': None  
    },
    ('Man City', 'Middlesbrough'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 11, 'Attendance': None  
    },

    # ==================== Matchweek 12 (4 November 2006) ====================
    ('Watford', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12, 'Attendance': None  
    },
}

# 要填充的列
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

# 调用 fill_from_dict 函数
fill_from_dict(
    df,
    season='0607',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5204     Man United     Portsmouth  2006     11    4
# 5205      Newcastle      Sheffield  2006     11    4
# 5206         Fulham        Everton  2006     11    4
# 5207         Bolton          Wigan  2006     11    4
# 5208      Liverpool        Reading  2006     11    4
# 5209       Charlton       Man City  2006     11    4
# 5210      Tottenham        Chelsea  2006     11    5
# 5211       West Ham        Arsenal  2006     11    5
# 5212    Aston Villa      Blackburn  2006     11    5
# 5213      Blackburn     Man United  2006     11   11
# 5214        Chelsea        Watford  2006     11   11
# 5215        Everton    Aston Villa  2006     11   11
# 5216       Man City      Newcastle  2006     11   11
# 5217  Middlesbrough       West Ham  2006     11   11
# 5218     Portsmouth         Fulham  2006     11   11
# 5219      Sheffield         Bolton  2006     11   11
# 5220          Wigan       Charlton  2006     11   11
# ...

# %%
match_data = {
    # -------------------- 4 November 2006 (Matchweek 11) --------------------
    ('Man United', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': 76004
    },  # Source: Sky Sports [19L4-L7], 11v11 [19L14-L17]
    ('Newcastle', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None   
    },
    ('Fulham', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None   
    },
    ('Bolton', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None   
    },
    ('Liverpool', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None   
    },
    ('Charlton', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 11,
        'Attendance': None   
    },
    ('Tottenham', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 11,
        'Attendance': None   
    },
    ('West Ham', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 11,
        'Attendance': None   
    },
    ('Aston Villa', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 11,
        'Attendance': None   
    },

    # -------------------- 11 November 2006 (Matchweek 12) --------------------
    ('Blackburn', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 12,
        'Attendance': None   
    },
    ('Chelsea', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None   
    },
    ('Everton', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None   
    },
    ('Man City', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None   
    },
    ('Middlesbrough', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None   
    },
    ('Portsmouth', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None   
    },
    ('Sheffield', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None   
    },
    ('Wigan', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 12,
        'Attendance': None   
    },
    ('Arsenal', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 12,
        'Attendance': None   
    },
    ('Reading', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 12,
        'Attendance': None   
    },

    # -------------------- 18 November 2006 (Matchweek 13) --------------------
    ('Sheffield', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 13,
        'Attendance': None   
    },
    ('Portsmouth', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None   
    },
    ('Reading', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None   
    },
    ('Man City', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None   
    },
    ('Arsenal', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None   
    },
    ('Everton', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None   
    },
    ('Chelsea', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None   
    },
    ('Middlesbrough', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 13,
        'Attendance': None   
    },
    ('Blackburn', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 13,
        'Attendance': None   
    },
    ('Wigan', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 13,
        'Attendance': None   
    },

    # -------------------- 25 November 2006 (Matchweek 14) --------------------
    ('Bolton', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 14,
        'Attendance': None   
    },
    ('Charlton', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': None   
    },
    ('Fulham', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': None   
    },
    ('Liverpool', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': None   
    },
    ('West Ham', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': None   
    },
    ('Aston Villa', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 14,
        'Attendance': None   
    },

    # -------------------- 26 November 2006 (Matchweek 14) --------------------
    ('Man United', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 14,
        'Attendance': None   
    },
    ('Newcastle', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 14,
        'Attendance': None   
    },
    ('Tottenham', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 14,
        'Attendance': None   
    },

    # -------------------- 28 November 2006 (Matchweek 15) --------------------
    ('Watford', 'Sheffield'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 15,
        'Attendance': None   
    },

    # -------------------- 29 November 2006 (Matchweek 15) --------------------
    ('Aston Villa', 'Man City'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 15,
        'Attendance': None   
    },
    ('Bolton', 'Chelsea'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 15,
        'Attendance': None   
    },
    ('Fulham', 'Arsenal'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 15,
        'Attendance': None   
    },
    ('Liverpool', 'Portsmouth'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 15,
        'Attendance': None   
    },
    ('Man United', 'Everton'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 15,
        'Attendance': None   
    },

    # -------------------- 2 December 2006 (Matchweek 16) --------------------
    ('Sheffield', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None   
    },
    ('Wigan', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 16,
        'Attendance': None   
    },
    ('Reading', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None   
    },
    ('Middlesbrough', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None   
    },
    ('Blackburn', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None   
    },
    ('Arsenal', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 16,
        'Attendance': None   
    },
    ('Portsmouth', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 16,
        'Attendance': None   
    },

    # -------------------- 3 December 2006 (Matchweek 16) --------------------
    ('Everton', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 16,
        'Attendance': None   
    },

    # -------------------- 4 December 2006 (Matchweek 16) --------------------
    ('Man City', 'Watford'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 16,
        'Attendance': None   
    },

    # -------------------- 5 December 2006 (Matchweek 17) --------------------
    ('Charlton', 'Blackburn'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 17,
        'Attendance': None   
    },
    ('Tottenham', 'Middlesbrough'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 17,
        'Attendance': None   
    },

    # -------------------- 6 December 2006 (Matchweek 17) --------------------
    ('Newcastle', 'Reading'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 17,
        'Attendance': None   
    },
    ('West Ham', 'Wigan'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 17,
        'Attendance': None   
    },

    # -------------------- 9 December 2006 (Matchweek 17) --------------------
    ('Watford', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None   
    },
    ('Tottenham', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None   
    },
    ('Portsmouth', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None   
    },
    ('Man United', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 17,
        'Attendance': None   
    },
    ('Liverpool', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None   
    },
    ('Bolton', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None   
    },
    ('Blackburn', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None   
    },
    ('Middlesbrough', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 17,
        'Attendance': None   
    },

    # -------------------- 10 December 2006 (Matchweek 17) --------------------
    ('Chelsea', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 17,
        'Attendance': 41945   # Source: FBref [1L11]
    },

    # -------------------- 11 December 2006 (Matchweek 17) --------------------
    ('Sheffield', 'Aston Villa'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 17,
        'Attendance': None   
    },

    # -------------------- 13 December 2006 (Matchweek 18) --------------------
    ('Chelsea', 'Newcastle'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 18,
        'Attendance': None   
    },
    ('Wigan', 'Arsenal'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 18,
        'Attendance': None   
    },

    # -------------------- 16 December 2006 (Matchweek 18) --------------------
    ('Wigan', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None   
    },
    ('Reading', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None   
    },
    ('Charlton', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None   
    },
    ('Aston Villa', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None   
    },
    ('Arsenal', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None   
    },
    ('Newcastle', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 18,
        'Attendance': None   
    },

    # -------------------- 17 December 2006 (Matchweek 18) --------------------
    ('Everton', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 18,
        'Attendance': None   
    },
    ('Man City', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 18,
        'Attendance': None   
    },
    ('West Ham', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 18,
        'Attendance': None   
    },

    # -------------------- 18 December 2006 (Matchweek 18) --------------------
    ('Fulham', 'Middlesbrough'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 18,
        'Attendance': None   
    },

    # -------------------- 23 December 2006 (Matchweek 19) --------------------
    ('Wigan', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 19,
        'Attendance': None   
    },
    ('Reading', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None   
    },
    ('Portsmouth', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None   
    },
    ('Newcastle', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None   
    },
    ('Man City', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None   
    },
    ('Liverpool', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None   
    },
    ('Fulham', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None   
    },
    ('Aston Villa', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None   
    },
    ('Arsenal', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': 59913   # Source: FBref [3L30-L31]
    },
    ('Middlesbrough', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 19,
        'Attendance': None   
    },

    # -------------------- 26 December 2006 (Matchweek 20) --------------------
    ('West Ham', 'Portsmouth'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 20,
        'Attendance': None   
    },
    ('Watford', 'Arsenal'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 20,
        'Attendance': None   
    },
    ('Tottenham', 'Aston Villa'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 20,
        'Attendance': None   
    },
    ('Chelsea', 'Reading'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 20,
        'Attendance': None   
    },
    ('Man United', 'Wigan'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 20,
        'Attendance': None   
    },
    ('Sheffield', 'Man City'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 20,
        'Attendance': None   
    },
    ('Bolton', 'Newcastle'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 20,
        'Attendance': None   
    },
    ('Blackburn', 'Liverpool'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 20,
        'Attendance': None   
    },
    ('Everton', 'Middlesbrough'): {
        'WeekDay': 'Tue', 'Time': '15:00', 'Round': 20,
        'Attendance': None   
    },

    # -------------------- 27 December 2006 (Matchweek 20) --------------------
    ('Charlton', 'Fulham'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 20,
        'Attendance': None   
    },

    # -------------------- 30 December 2006 (Matchweek 21) --------------------
    ('Charlton', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': None   
    },
}

# Columns to fill
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

fill_from_dict(
    df,
    season='0607',
    data=match_data ,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'WeekDay')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5304        Chelsea         Fulham  2006     12   30
# 5305        Everton      Newcastle  2006     12   30
# 5306     Man United        Reading  2006     12   30
# 5307      Sheffield        Arsenal  2006     12   30
# 5308      Tottenham      Liverpool  2006     12   30
# 5309       West Ham       Man City  2006     12   30
# 5310         Bolton     Portsmouth  2006     12   30
# 5311      Blackburn  Middlesbrough  2006     12   30
# 5312          Wigan      Blackburn  2007      1    1
# 5313        Reading       West Ham  2007      1    1
# 5314     Portsmouth      Tottenham  2007      1    1
# 5315  Middlesbrough      Sheffield  2007      1    1
# 5316       Man City        Everton  2007      1    1
# 5317      Liverpool         Bolton  2007      1    1
# 5318         Fulham        Watford  2007      1    1
# 5319      Newcastle     Man United  2007      1    1
# 5320        Arsenal       Charlton  2007      1    2
# ...

# %%
match_data = {
    # ==================== 30 December 2006 (Matchweek 21) ====================
    ('Chelsea', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': 41934
    },  # Source: FBref [20L7-L8][17L27-L28]
    ('Everton', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': 38682
    },  # Source: FBref [21L21-L23][21L26-L27]
    ('Man United', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': 75910
    },  # Source: FBref [18L7-L8][18L25-L26]
    ('Sheffield', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': 32086
    },  # Source: FBref [22L7-L8][22L27-L28]
    ('Tottenham', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': 36170
    },  # Source: FBref [23L7-L8][23L36-L37]
    ('West Ham', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': 34552
    },  # Source: FBref [24L6-L8][24L16-L18]
    ('Bolton', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': 22447
    },  # Source: FBref [27L24-L25][27L28-L29]
    ('Blackburn', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': 22653
    },  # Source: FBref [28L8-L9][28L28-L29]
    ('Charlton', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 21,
        'Attendance': 26699
    },  # Source: FBref [26L5-L6][16L13-L14]

    # ==================== 1 January 2007 (Matchweek 22) ====================
    ('Wigan', 'Blackburn'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 22,
        'Attendance': 15039
    },  # Source: FBref [29L7-L8][29L11-L12]
    ('Reading', 'West Ham'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 22,
        'Attendance': None   
    },
    ('Portsmouth', 'Tottenham'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 22,
        'Attendance': None   
    },
    ('Middlesbrough', 'Sheffield'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 22,
        'Attendance': None   
    },
    ('Man City', 'Everton'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 22,
        'Attendance': None   
    },
    ('Liverpool', 'Bolton'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 22,
        'Attendance': None   
    },
    ('Fulham', 'Watford'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 22,
        'Attendance': None   
    },
    ('Newcastle', 'Man United'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 22,
        'Attendance': 52302
    },  # Source: FBref [29L21-L22][29L24-L25]

    # ==================== 13 January 2007 (Matchweek 23) ====================
    ('Watford', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23,
        'Attendance': 19740
    },  # Source: FBref [30L11-L12]
    ('Chelsea', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23,
        'Attendance': 40846
    },  # Source: [3L19-L20]
    ('Blackburn', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23,
        'Attendance': 21852
    },  # Source: FBref [30L16-L17][30L26-L27]
    ('West Ham', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23,
        'Attendance': 34552
    },  # Source: FBref [30L21-L22][30L29-L30]
    ('Man United', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23,
        'Attendance': 76073
    },  # Source: FBref [30L34-L35]

    # ==================== 20 January 2007 (Matchweek 24) ====================
    ('Reading', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': None   
    },
    ('Portsmouth', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': None   
    },
    ('Newcastle', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': None   
    },
    ('Middlesbrough', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': None   
    },
    ('Liverpool', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': None   
    },
    ('Fulham', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': None   
    },
    ('Aston Villa', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': 35892
    },  # Source: FBref [31L12-L13]
    ('Man City', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 24,
        'Attendance': 36950
    },  # Source: FBref [31L7-L8]

    # ==================== 21 January 2007 (Matchweek 24) ====================
    ('Arsenal', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 24,
        'Attendance': 60128
    },  # Source: FBref [32L25-L27]
    ('Wigan', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 24,
        'Attendance': None   
    },

    # ==================== 30 January 2007 (Matchweek 25) ====================
    ('West Ham', 'Liverpool'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 25,
        'Attendance': 35278
    },  # Source: FBref [32L13-L14]
    ('Portsmouth', 'Middlesbrough'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 25,
        'Attendance': 19820
    },  # Source: FBref [32L8-L9][32L17-L18]
    ('Sheffield', 'Fulham'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 25,
        'Attendance': 27500
    },  # Source: fussballdaten [32L32-L33]

    # ==================== 31 January 2007 (Matchweek 25) ====================
    ('Newcastle', 'Aston Villa'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 25,
        'Attendance': None   
    },
    ('Bolton', 'Charlton'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 25,
        'Attendance': None   
    },
    ('Chelsea', 'Blackburn'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 25,
        'Attendance': None   
    },
    ('Man United', 'Watford'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 25,
        'Attendance': 76032
    },  # Source: FBref [32L27-L28]

    # ==================== 3 February 2007 (Matchweek 26) ====================
    ('Aston Villa', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26,
        'Attendance': None   
    },
    ('Blackburn', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26,
        'Attendance': None   
    },
    ('Charlton', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26,
        'Attendance': None   
    },
    ('Fulham', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26,
        'Attendance': None   
    },
    ('Liverpool', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 26,
        'Attendance': None   
    },
    ('Middlesbrough', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26,
        'Attendance': None   
    },
    ('Watford', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26,
        'Attendance': None   
    },
    ('Wigan', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26,
        'Attendance': None   
    },
    ('Man City', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 26,
        'Attendance': None   
    },

    # ==================== 4 February 2007 (Matchweek 26) ====================
    ('Tottenham', 'Man United'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 26,
        'Attendance': None   
    },
}

# Columns to fill
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

fill_from_dict(
    df,
    season='0607',
    data=match_data ,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'WeekDay')
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5404         Fulham     Portsmouth  2007      3   31
# 5405      Liverpool        Arsenal  2007      3   31
# 5406     Man United      Blackburn  2007      3   31
# 5407      Newcastle       Man City  2007      3   31
# 5408        Watford        Chelsea  2007      3   31
# 5409       West Ham  Middlesbrough  2007      3   31
# 5410       Charlton          Wigan  2007      3   31
# 5411      Tottenham        Reading  2007      4    1
# 5412    Aston Villa        Everton  2007      4    2
# 5413        Everton         Fulham  2007      4    6
# 5414       Man City       Charlton  2007      4    6
# 5415          Wigan         Bolton  2007      4    7
# 5416      Sheffield      Newcastle  2007      4    7
# 5417        Reading      Liverpool  2007      4    7
# 5418        Arsenal       West Ham  2007      4    7
# 5419  Middlesbrough        Watford  2007      4    7
# 5420        Chelsea      Tottenham  2007      4    7
# ...

# %%
match_data = {
    # ==================== Matchweek 31 (31 March 2007) ====================
    ('Fulham', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 22806
    },  # Source: FBref [9L5-L6]
    ('Liverpool', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 31, 'Attendance': 44845
    },  # Source: FBref [10L13-L14]
    ('Man United', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 31, 'Attendance': 76004
    },  # Source: FBref [8L8-L9]
    ('Newcastle', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 52320
    },  # Source: FBref [11L15-L16]
    ('Watford', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': None
    },
    ('West Ham', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': None
    },
    ('Charlton', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': None
    },
    ('Tottenham', 'Reading'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 31, 'Attendance': None
    },
    ('Aston Villa', 'Everton'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 31, 'Attendance': None
    },

    # ==================== Matchweek 32 (6-7 April 2007) ====================
    ('Everton', 'Fulham'): {
        'WeekDay': 'Fri', 'Time': '19:45', 'Round': 32, 'Attendance': 35612
    },  # Source: FBref [9L7]
    ('Man City', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': None
    },
    ('Wigan', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': None
    },
    ('Sheffield', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': 32572
    },  # Source: FBref [11L16-L17]
    ('Reading', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 32, 'Attendance': 24121
    },  # Source: FBref [10L15-L16]
    ('Arsenal', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': 60098
    },  # Source: FBref [0L14-L15]
    ('Middlesbrough', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': None
    },
    ('Chelsea', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 32, 'Attendance': 41869
    },  # Source: FBref [0L19-L20]
    ('Blackburn', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 32, 'Attendance': None
    },
    ('Portsmouth', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 32, 'Attendance': 20223
    },  # Source: FBref [8L10-L11]

    # ==================== Matchweek 33 (9 April 2007) ====================
    ('Bolton', 'Everton'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 33, 'Attendance': 25179
    },  # Source: FBref [2L11]
    ('Charlton', 'Reading'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 33, 'Attendance': None
    },
    ('Fulham', 'Man City'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 33, 'Attendance': 22435
    },  # Source: FBref [9L8-L9]
    ('Newcastle', 'Arsenal'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 33, 'Attendance': 52299
    },  # Source: FBref [11L17-L18]
    ('Watford', 'Portsmouth'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 33, 'Attendance': None
    },
    ('Aston Villa', 'Wigan'): {
        'WeekDay': 'Mon', 'Time': '15:00', 'Round': 33, 'Attendance': None
    },

    # ==================== Matchweek 34 (14-18 April 2007) ====================
    ('Reading', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': 24082
    },  # Source: FBref [9L10]
    ('Sheffield', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': None
    },
    ('Portsmouth', 'Newcastle'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': 20165
    },  # Source: FBref [11L19]
    ('Man City', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 34, 'Attendance': 45883
    },  # Source: FBref [10L16-L17]
    ('Middlesbrough', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': 26959
    },  # Source: worldfootball [13L22]
    ('Arsenal', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 34, 'Attendance': 60100
    },  # Source: fussballdaten [12L4]
    ('Everton', 'Charlton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 34, 'Attendance': 34000
    },  # Source: fussballdaten [12L5-L6]
    ('Wigan', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 34, 'Attendance': None
    },
    ('Arsenal', 'Man City'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 33, 'Attendance': None
    },
    ('Man United', 'Sheffield'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 33, 'Attendance': 75540
    },  # Source: FBref [8L11-L12]
    ('Blackburn', 'Watford'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 34, 'Attendance': 16000
    },  # Source: fussballdaten [12L17]
    ('Liverpool', 'Middlesbrough'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 33, 'Attendance': 43247
    },  # Source: FBref [10L18]
    ('West Ham', 'Chelsea'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 34, 'Attendance': 35000
    },  # Source: fussballdaten [12L12]
    ('Chelsea', 'Man United'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 33, 'Attendance': 41868
    },  # Source: FBref [8L17]

    # ==================== Matchweek 35 (21 April 2007) ====================
    ('West Ham', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35, 'Attendance': 34900
    },  # Source: fussballdaten [15L18]
    ('Watford', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35, 'Attendance': None
    },
    ('Tottenham', 'Arsenal'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 35, 'Attendance': 36100
    },  # Source: fussballdaten [15L5]
    ('Man United', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 35, 'Attendance': 75967
    },  # Source: FBref [8L13]
    ('Fulham', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35, 'Attendance': 23652
    },  # Source: FBref [9L11-L12]
    ('Charlton', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35, 'Attendance': None
    },
    ('Bolton', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35, 'Attendance': 23500
    },  # Source: fussballdaten [15L8]
    ('Liverpool', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 35, 'Attendance': 45047
    },  # Source: FBref [10L19-L20]
    ('Aston Villa', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 35, 'Attendance': None
    },
    ('Newcastle', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 35, 'Attendance': 52056
    },  # Source: FBref [11L20-L21]

    # ==================== Matchweek 36 (28-30 April 2007) ====================
    ('Wigan', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': None
    },
    ('Sheffield', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': 30700
    },  # Source: fussballdaten [16L16]
    ('Portsmouth', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 36, 'Attendance': 20200
    },  # Source: fussballdaten [16L12]
    ('Man City', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': 40800
    },  # Source: fussballdaten [16L8]
    ('Everton', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 36, 'Attendance': 39682
    },  # Source: FBref [8L14-L15]
    ('Blackburn', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': 24900
    },  # Source: fussballdaten [16L21]
    ('Middlesbrough', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 36, 'Attendance': 27900
    },  # Source: fussballdaten [16L7]
    ('Chelsea', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 36, 'Attendance': 41100
    },  # Source: fussballdaten [15L28]
    ('Arsenal', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 36, 'Attendance': 60043
    },  # Source: FBref [9L13]
    ('Reading', 'Newcastle'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 36, 'Attendance': 24109
    },  # Source: FBref [11L21-L22]

    # ==================== Matchweek 37 (5-10 May 2007) ====================
    ('Aston Villa', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 37, 'Attendance': 42600
    },  # Source: fussballdaten [17L17]
    ('Everton', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 39600
    },  # Source: fussballdaten [17L7]
    ('Fulham', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 24554
    },  # Source: FBref [9L14-L15]
    ('Man City', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 47244
    },  # Source: FBref [8L15-L16]
    ('Newcastle', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 51840
    },  # Source: FBref [11L22-L23]
    ('Reading', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 23300
    },  # Source: fussballdaten [17L6]
    ('West Ham', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': 34400
    },  # Source: fussballdaten [17L14]
    ('Wigan', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 37, 'Attendance': None
    },
    ('Arsenal', 'Chelsea'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 37, 'Attendance': 60102
    },  # Source: FBref [0L16]
    ('Charlton', 'Tottenham'): {
        'WeekDay': 'Mon', 'Time': '20:00', 'Round': 37, 'Attendance': 26300
    },  # Source: fussballdaten [17L22]
    ('Chelsea', 'Man United'): {
        'WeekDay': 'Wed', 'Time': '20:00', 'Round': 33, 'Attendance': 41868
    },  # Source: FBref [8L17]
    ('Tottenham', 'Blackburn'): {
        'WeekDay': 'Thu', 'Time': '20:00', 'Round': 37, 'Attendance': 36000
    },  # Source: fussballdaten [17L27]

    # ==================== Matchweek 38 (13 May 2007) ====================
    ('Blackburn', 'Reading'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': None
    },
    ('Watford', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 19830
    },  # Source: FBref [11L24]
    ('Tottenham', 'Man City'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': None
    },
    ('Sheffield', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 32604
    },  # Source: FBref [7L12-L13]
    ('Bolton', 'Aston Villa'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': None
    },
    ('Middlesbrough', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 29556
    },  # Source: FBref [9L16-L17]
    ('Chelsea', 'Everton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': None
    },
    ('Portsmouth', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': None
    },
    ('Man United', 'West Ham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 75927
    },  # Source: FBref [8L18-L19]
    ('Liverpool', 'Charlton'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 38, 'Attendance': 44657
    },  # Source: FBref [10L23-L24]
}

# 要填充的列
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

# 调用 fill_from_dict 函数
fill_from_dict(
    df,
    season='0607',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'WeekDay')
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5320        Arsenal       Charlton  2007      1    2
# 5321    Aston Villa        Chelsea  2007      1    2
# 5324      Sheffield     Portsmouth  2007      1   13
# 5326       Charlton  Middlesbrough  2007      1   13
# 5327         Bolton       Man City  2007      1   13
# 5330        Everton        Reading  2007      1   14
# 5331      Tottenham      Newcastle  2007      1   14
# 5342        Watford      Blackburn  2007      1   23
# 5344        Reading          Wigan  2007      1   30
# 5361        Reading    Aston Villa  2007      2   10
# 5362       West Ham        Watford  2007      2   10
# 5363      Sheffield      Tottenham  2007      2   10
# 5364     Portsmouth       Man City  2007      2   10
# 5365     Man United       Charlton  2007      2   10
# 5366        Everton      Blackburn  2007      2   10
# 5367        Chelsea  Middlesbrough  2007      2   10
# 5368      Newcastle      Liverpool  2007      2   10
# ...

# %%
match_data = {
    # ==================== 20071 ====================
    ('Arsenal', 'Charlton'): {
        'WeekDay': 'Tue', 'Time': '19:45', 'Round': 22, 'Attendance': 60057
    },  # Source: ESPN [6L5-L7]
    ('Aston Villa', 'Chelsea'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 22, 'Attendance': 41006
    },  # Source: 11v11.com [7L3-L4]
    ('Sheffield', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 23, 'Attendance': 30269
    },  # Source: Global Sports Archive [8L3-L4]
    ('Charlton', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 23, 'Attendance': 26384
    },  # Source: 11v11.com [9L5]
    ('Bolton', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '16:00', 'Round': 23, 'Attendance': 22334
    },  # Source: ESPN [16L5]
    ('Everton', 'Reading'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 23, 'Attendance': 34722
    },  # Source: doingthe92.com [17L5]
    ('Tottenham', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 23, 'Attendance': 35942
    },  # Source: ESPN [18L6]
    ('Watford', 'Blackburn'): {
        'WeekDay': 'Tue', 'Time': '20:45', 'Round': 14, 'Attendance': 13766
    },  # Source: Sky Sports [19L3]
    ('Reading', 'Wigan'): {
        'WeekDay': 'Tue', 'Time': '20:00', 'Round': 25, 'Attendance': 21954
    },  # Source: 11v11.com [14L44-L45]

    # ==================== 20072 ====================
    ('Reading', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27, 'Attendance': None
    },  
    ('West Ham', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27, 'Attendance': 34625
    },  # Source: ESPN [22L6-L7]
    ('Sheffield', 'Tottenham'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 27, 'Attendance': 32144
    },  # Source: ESPN [23L18]
    ('Portsmouth', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '18:15', 'Round': 27, 'Attendance': 19344
    },  # Source: Transfermarkt [24L17]
    ('Man United', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27, 'Attendance': 75883
    },  # Source: footballdatabase.eu [25L8]
    ('Everton', 'Blackburn'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27, 'Attendance': 35593
    },  # Source: Premier League [26L25]
    ('Chelsea', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27, 'Attendance': 41699
    },  # Source: stamford-bridge.com [27L39]
    ('Newcastle', 'Liverpool'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 27, 'Attendance': 52305
    },  # Source: ESPN [28L6]
    ('Arsenal', 'Wigan'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 27, 'Attendance': 60049
    },  # Source: footballgroundsinfocus.com [29L7]
    ('Bolton', 'Fulham'): {
        'WeekDay': 'Sun', 'Time': '14:30', 'Round': 27, 'Attendance': None
    },  
    ('Everton', 'Tottenham'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 25, 'Attendance': 34121
    },  # Source: Sky Sports [31L37]
    ('Watford', 'Wigan'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 21, 'Attendance': 18338
    },  # Source: football-lineups.com [32L24]
    ('Watford', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28, 'Attendance': 18761
    },  # Source: ESPN [33L6]
    ('Liverpool', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28, 'Attendance': 44198
    },  # Source: myliverpoolfc.org [34L6]
    ('Fulham', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '13:45', 'Round': 28, 'Attendance': 24459
    },  # Source: ESPN [35L11]
    ('Charlton', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28, 'Attendance': None
    },  
    ('Middlesbrough', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 28, 'Attendance': 26412
    },  # Source: ESPN [37L7]
    ('Blackburn', 'Portsmouth'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 28, 'Attendance': 17434
    },  # Source: FBref [38L8]
    ('Tottenham', 'Bolton'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 28, 'Attendance': 35747
    },  # Source: ESPN [39L7]
    ('Wigan', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '14:00', 'Round': 28, 'Attendance': 21179
    },  # Source: 11v11.com [40L40-L41]

    # ==================== 20073 ====================
    ('Watford', 'Charlton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29, 'Attendance': 19782
    },  # Source: Sky Sports [41L29]
    ('Portsmouth', 'Chelsea'): {
        'WeekDay': 'Sat', 'Time': '17:15', 'Round': 29, 'Attendance': 20219
    },  # Source: resultdb.com [42L11-L12]
    ('Sheffield', 'Everton'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29, 'Attendance': 32019
    },  # Source: Premier League [43L22]
    ('Man City', 'Wigan'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29, 'Attendance': 39923
    },  # Source: rtfract.com [44L5]
    ('Liverpool', 'Man United'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 29, 'Attendance': None
    },  
    ('Fulham', 'Aston Villa'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29, 'Attendance': 24552
    },  # Source: Sky Sports [46L29]
    ('Arsenal', 'Reading'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29, 'Attendance': 60132
    },  # Source: resultdb.com [47L7]
    ('Newcastle', 'Middlesbrough'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 29, 'Attendance': 52303
    },  # Source: 11v11.com [48L11]
    ('Bolton', 'Blackburn'): {
        'WeekDay': 'Sun', 'Time': '13:00', 'Round': 29, 'Attendance': 21743
    },  # Source: Sky Sports [49L39]
    ('West Ham', 'Tottenham'): {
        'WeekDay': 'Sun', 'Time': '15:00', 'Round': 29, 'Attendance': 34966
    },  # Source: ESPN [50L6-L7]
    ('Man City', 'Chelsea'): {
        'WeekDay': 'Wed', 'Time': '21:00', 'Round': 28, 'Attendance': 39429
    },  # Source: sport.de [51L13]
    ('Aston Villa', 'Arsenal'): {
        'WeekDay': 'Wed', 'Time': '19:45', 'Round': 28, 'Attendance': None
    },  
    ('Man United', 'Bolton'): {
        'WeekDay': 'Sat', 'Time': '12:45', 'Round': 30, 'Attendance': 76058
    },  # Source: ESPN [53L29]
    ('Blackburn', 'West Ham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': None
    },  
    ('Wigan', 'Fulham'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 16001
    },  # Source: Sky Sports [55L39]
    ('Chelsea', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 41897
    },  # Source: resultdb.com [56L11-L12]
    ('Reading', 'Portsmouth'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 24087
    },  # Source: worldfootball.net [57L30]
    ('Middlesbrough', 'Man City'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 26427
    },  # Source: sport.de [58L13]
    ('Tottenham', 'Watford'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 30, 'Attendance': 36051
    },  # Source: resultdb.com [59L6]
    ('Aston Villa', 'Liverpool'): {
        'WeekDay': 'Sun', 'Time': '14:35', 'Round': 30, 'Attendance': 42551
    },  # Source: myliverpoolfc.org [60L6]
    ('Charlton', 'Newcastle'): {
        'WeekDay': 'Sun', 'Time': '13:30', 'Round': 30, 'Attendance': 27028
    },  # Source: ESPN [61L6]
    ('Everton', 'Arsenal'): {
        'WeekDay': 'Sun', 'Time': '16:00', 'Round': 30, 'Attendance': 37162
    },  # Source: resultdb.com [62L6]
    ('Bolton', 'Sheffield'): {
        'WeekDay': 'Sat', 'Time': '15:00', 'Round': 31, 'Attendance': 24312
    },  # Source: resultdb.com [63L6]
}

# 要填充的列
match_cols = ['WeekDay', 'Time', 'Round', 'Attendance']

# 调用 fill_from_dict 函数
fill_from_dict(
    df,
    season='0607',
    data=match_data,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'Attendance')[:115]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5111     Portsmouth      Blackburn  2006      8   19
# 5112        Chelsea       Man City  2006      8   20
# 5116       Man City     Portsmouth  2006      8   23
# 5118       Charlton     Man United  2006      8   23
# 5120      Blackburn        Everton  2006      8   23
# 5122        Watford     Man United  2006      8   26
# 5125      Liverpool       West Ham  2006      8   26
# 5127       Charlton         Bolton  2006      8   26
# 5130      Blackburn        Chelsea  2006      8   27
# 5132     Portsmouth          Wigan  2006      9    9
# 5136        Everton      Liverpool  2006      9    9
# 5137        Chelsea       Charlton  2006      9    9
# 5138         Bolton        Watford  2006      9    9
# 5139     Man United      Tottenham  2006      9    9
# 5140       West Ham    Aston Villa  2006      9   10
# 5142        Watford    Aston Villa  2006      9   16
# 5143         Bolton  Middlesbrough  2006      9   16
# ...

# %%
# Attendance data for the 2006-07 Premier League season
attendance_data = {
    # ==================== 19 August 2006 ====================
    ('Portsmouth', 'Blackburn'): 19502,        # Source: FBref [0L10][0L14]
    # ==================== 20 August 2006 ====================
    ('Chelsea', 'Man City'): 41814,            # Source: Premier League [1L6]
    # ==================== 23 August 2006 ====================
    ('Man City', 'Portsmouth'): 37214,         # Source: ESPN [2L7]
    ('Charlton', 'Man United'): 25422,         # Source: 11v11 [3L11]
    ('Blackburn', 'Everton'): 22015,           # Source: sport.de [4L9]
    # ==================== 26 August 2006 ====================
    ('Watford', 'Man United'): 19453,          # Source: Global Sports Archive [5L7]
    ('Liverpool', 'West Ham'): 43965,          # Source: sport.de [6L9]
    ('Charlton', 'Bolton'): 23638,             # Source: 11v11 [7L19]
    # ==================== 27 August 2006 ====================
    ('Blackburn', 'Chelsea'): 19398,           # Source: 11v11 [8L14]
    # ==================== 9 September 2006 ====================
    ('Portsmouth', 'Wigan'): 19508,            # Source: sport.de [9L9]
    ('Everton', 'Liverpool'): 40004,           # Source: sport.de [10L9]
    ('Chelsea', 'Charlton'): 41194,            # Source: ESPN [11L7]
    ('Bolton', 'Watford'): 21140,              # Source: ESPN [12L6]
    ('Man United', 'Tottenham'): 75453,        # Source: ESPN [13L7]
    # ==================== 10 September 2006 ====================
    ('West Ham', 'Aston Villa'): 34576,        # Source: ESPN [14L7]
    # ==================== 16 September 2006 ====================
    ('Watford', 'Aston Villa'): 18620,         # Source: sport.de [15L9]
    ('Bolton', 'Middlesbrough'): 21164,        # Source: ESPN [16L7]
    ('Everton', 'Wigan'): 37117,               # Source: Sky Sports [17L7]
    ('Charlton', 'Portsmouth'): 26130,         # Source: 11v11 [18L21]
    ('Sheffield', 'Reading'): 25011,           # Source: ESPN [19L6]
    # ==================== 17 September 2006 ====================
    ('Blackburn', 'Man City'): 18403,          # Source: ESPN [20L6]
    ('Chelsea', 'Liverpool'): 41882,           # Source: ESPN [21L7]
    ('Man United', 'Arsenal'): 75595,          # Source: ESPN [22L7]
    ('Tottenham', 'Fulham'): 36131,            # Source: ESPN [23L6]
    ('West Ham', 'Newcastle'): 34938,          # Source: ESPN [24L6]
    # ==================== 20 September 2006 ====================
    ('Liverpool', 'Newcastle'): 43754,         # Source: 11v11 [25L17]
    # ==================== 23 September 2006 ====================
    ('Wigan', 'Watford'): 16359,               # Source: ESPN [26L6]
    ('Reading', 'Man United'): 24098,          # Source: 11v11 [27L17]
    ('Middlesbrough', 'Blackburn'): 24959,     # Source: ESPN [28L17]
    ('Fulham', 'Chelsea'): 24290,              # Source: ESPN [29L7]
    ('Liverpool', 'Tottenham'): 44330,         # Source: Sky Sports [30L11]
    ('Aston Villa', 'Charlton'): 35513,        # Source: ESPN [31L7]
    ('Arsenal', 'Sheffield'): 59912,           # Source: ESPN [32L7]
    ('Man City', 'West Ham'): 41073,           # Source: ESPN [33L6]
    # ==================== 24 September 2006 ====================
    ('Newcastle', 'Everton'): 50107,           # Source: Sky Sports [34L7]
    # ==================== 25 September 2006 ====================
    ('Portsmouth', 'Bolton'): 19105,           # Source: ESPN [35L7]
    # ==================== 30 September 2006 ====================
    ('Sheffield', 'Middlesbrough'): 27483,     # Source: 11v11 [36L11]
    ('Bolton', 'Liverpool'): 25061,            # Source: LFChistory [37L7]
    ('Chelsea', 'Aston Villa'): 41951,         # Source: 11v11 [38L11]
    ('Charlton', 'Arsenal'): 26770,            # Source: ESPN [39L7]
    ('Everton', 'Man City'): 38250,            # Source: sport.de [40L9]
    # ==================== 1 October 2006 ====================
    ('Tottenham', 'Portsmouth'): 36063,        # Source: 11v11 [41L20]
    ('West Ham', 'Reading'): 34872,            # Source: sport.de [42L14]
    ('Blackburn', 'Wigan'): 17859,             # Source: ESPN [43L7]
    ('Man United', 'Newcastle'): 75664,        # Source: worldfootball [44L7]
    # ==================== 2 October 2006 ====================
    ('Watford', 'Fulham'): 17982,              # Source: Sky Sports [45L15]
    # ==================== 14 October 2006 ====================
    ('Arsenal', 'Watford'): 60018,             # Source: Sky Sports [46L7]
    ('Aston Villa', 'Tottenham'): 42551,       # Source: worldfootball [47L6]
    ('Liverpool', 'Blackburn'): 44206,         # Source: Sky Sports [48L7]
    ('Middlesbrough', 'Everton'): 27156,       # Source: ESPN [49L7]
    ('Portsmouth', 'West Ham'): 20142,         # Source: ESPN [50L7]
    ('Reading', 'Chelsea'): 24025,             # Source: Stamford Bridge [51L6]
    ('Wigan', 'Man United'): 20631,            # Source: ESPN [52L7]
    ('Man City', 'Sheffield'): 42192,          # Source: ESPN [53L7]
    # ==================== 15 October 2006 ====================
    ('Newcastle', 'Bolton'): 48145,            # Source: ESPN [54L7]
    # ==================== 16 October 2006 ====================
    ('Fulham', 'Charlton'): 19179,             # Source: ESPN [55L6]
}

# Columns to fill
match_cols = ['Attendance']

fill_from_dict(
    df,
    season='0607',
    data=attendance_data ,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'Attendance')[115:]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5243    Aston Villa       Man City  2006     11   29
# 5244         Bolton        Chelsea  2006     11   29
# 5245         Fulham        Arsenal  2006     11   29
# 5246      Liverpool     Portsmouth  2006     11   29
# 5247     Man United        Everton  2006     11   29
# 5248      Sheffield       Charlton  2006     12    2
# 5249          Wigan      Liverpool  2006     12    2
# 5250        Reading         Bolton  2006     12    2
# 5251  Middlesbrough     Man United  2006     12    2
# 5252      Blackburn         Fulham  2006     12    2
# 5253        Arsenal      Tottenham  2006     12    2
# 5254     Portsmouth    Aston Villa  2006     12    2
# 5255        Everton       West Ham  2006     12    3
# 5256       Man City        Watford  2006     12    4
# 5257       Charlton      Blackburn  2006     12    5
# 5258      Tottenham  Middlesbrough  2006     12    5
# 5259      Newcastle        Reading  2006     12    6
# ...

# %%
match_attendance_data = {
    # ==================== 200611 ====================
    ('Bolton', 'Chelsea'): 23381,                # Source: Global Sports Archive [85L8]
    ('Liverpool', 'Portsmouth'): 44141,          # Source: FBref [85L11-L13]
    ('Aston Villa', 'Man City'): 30100,          # Source: AVFC History [85L27]

    # ==================== 200612 ====================
    ('Arsenal', 'Tottenham'): 60119,             # Source: FBref [87L9-L12]
    ('Arsenal', 'Portsmouth'): 60037,            # Source: FBref [87L28-L30]
    ('Newcastle', 'Watford'): 49640,             # Source: FBref [87L31-L32]

    # ==================== 2007 ====================
    ('Liverpool', 'Charlton'): 44657,            # Source: Global Sports Archive [86L7-L8]
    ('Blackburn', 'Reading'): 22675,             # Source: FBref [86L23-L24]
    ('Portsmouth', 'Arsenal'): 20188,            # Source: FBref [86L18-L19]
    ('Everton', 'Chelsea'): 41818,               # Source: FBref [86L13-L14]
}

fill_from_dict(
    df,
    season='0607',
    data=match_attendance_data ,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'Attendance')[:100]
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5183          Wigan       Man City  2006     10   21
# 5184        Everton      Sheffield  2006     10   21
# 5185       Charlton        Watford  2006     10   21
# 5186    Aston Villa         Fulham  2006     10   21
# 5187        Chelsea     Portsmouth  2006     10   21
# 5188      Blackburn         Bolton  2006     10   22
# 5189     Man United      Liverpool  2006     10   22
# 5190  Middlesbrough      Newcastle  2006     10   22
# 5191        Reading        Arsenal  2006     10   22
# 5192      Tottenham       West Ham  2006     10   22
# 5193        Watford      Tottenham  2006     10   28
# 5194      Sheffield        Chelsea  2006     10   28
# 5195     Portsmouth        Reading  2006     10   28
# 5196      Liverpool    Aston Villa  2006     10   28
# 5197         Fulham          Wigan  2006     10   28
# 5198         Bolton     Man United  2006     10   28
# 5199        Arsenal        Everton  2006     10   28
# ...

# %%
match_attendance_data = {
    # ==================== 20061226 ====================
    ('West Ham', 'Portsmouth'): 34913,           # Source: ESPN [0L7]
    ('Watford', 'Arsenal'): 19750,               # Source: Global Sports Archive [1L12]
    ('Tottenham', 'Aston Villa'): 35293,         # Source: ESPN [2L7]
    ('Chelsea', 'Reading'): 41885,               # Source: ESPN [3L7]
    ('Man United', 'Wigan'): 76018,              # Source: FBref [4L8]
    ('Sheffield', 'Man City'): 32591,            # Source: citytilidie [5L8]
    ('Bolton', 'Newcastle'): 26437,              # Source: ESPN [6L8]
    ('Blackburn', 'Liverpool'): 29342,           # Source: ESPN [7L11-L12]
    ('Everton', 'Middlesbrough'): 38126,         # Source: sport.de [8L9]

    # ==================== 20061227 ====================
    ('Charlton', 'Fulham'): 25203,               # Source: ESPN [9L7-L8]

    # ==================== 200711 ====================
    ('Reading', 'West Ham'): 23992,              # Source: FBref [10L7]
    ('Portsmouth', 'Tottenham'): 20185,          # Source: FBref [11L9]
    ('Middlesbrough', 'Sheffield'): 27963,       # Source: sport.de [12L13-L14]
    ('Man City', 'Everton'): 39836,              # Source: ESPN [13L8]

    # ==================== 2007120 ====================
    ('Reading', 'Sheffield'): 23956,             # Source: FBref [16L7]
    ('Portsmouth', 'Charlton'): 19508,           # Source: FBref [17L8]
    ('Newcastle', 'West Ham'): 52095,            # Source: ESPN [18L7]
    ('Middlesbrough', 'Bolton'): 24634,          # Source: FBref [19L7]
    ('Liverpool', 'Chelsea'): 44969,             # Source: FBref [20L11]
    ('Fulham', 'Tottenham'): 23580,              # Source: ESPN [21L7-L8]

    # ==================== 2007121 ====================
    ('Wigan', 'Everton'): 18149,                 # Source: ESPN [22L7-L8]

    # ==================== 2007131 ====================
    ('Newcastle', 'Aston Villa'): 49438,          # Source: FBref [23L7]
    ('Bolton', 'Charlton'): 22357,               # Source: sport.de [24L10]
    ('Chelsea', 'Blackburn'): 38000,             # Source: ESPN [25L7]

    # ==================== 200723 ====================
    ('Aston Villa', 'West Ham'): 41202,          # Source: FBref [26L7]
    ('Blackburn', 'Sheffield'): 20917,           # Source: ESPN [27L7-L8]
    ('Charlton', 'Chelsea'): 27111,              # Source: Wikipedia [28L8]
    ('Fulham', 'Newcastle'): 24340,              # Source: ESPN [29L7]
    ('Liverpool', 'Everton'): 44957,             # Source: FBref [30L16]
    ('Middlesbrough', 'Arsenal'): 31122,         # Source: FBref [31L9]
    ('Watford', 'Bolton'): 18722,                # Source: FBref [32L12]
    ('Wigan', 'Portsmouth'): 15295,              # Source: FBref [33L11]
    ('Man City', 'Reading'): 38676,              # Source: Hob Nob Anyone? [34L12]

    # ==================== 200724 ====================
    ('Tottenham', 'Man United'): 36146,           # Source: FBref [45L28]

    # ==================== 2007210 ====================
    ('Reading', 'Aston Villa'): 24122,           # Source: ESPN [36L8]

    # ==================== 2007211 ====================
    ('Bolton', 'Fulham'): 24919,                 # Source: FBref [37L7]

    # ==================== 2007224 ====================
    ('Charlton', 'West Ham'): 27111,             # Source: ESPN [38L7]

    # ==================== 200733 ====================
    ('Liverpool', 'Man United'): 44887,          # Source: FBref [39L7]

    # ==================== 2007314 ====================
    ('Aston Villa', 'Arsenal'): 39968,           # Source: web.archive.org [40L8]

    # ==================== 2007317 ====================
    ('Blackburn', 'West Ham'): 18591,            # Source: 11v11 [41L17]

    # ==================== 2007331 ====================
    ('Watford', 'Chelsea'): 19793,               # Source: FBref [42L16]
    ('West Ham', 'Middlesbrough'): 34966,        # Source: ESPN [50L7]
    ('Charlton', 'Wigan'): 26500,                # Source: ESPN [44L11-L12]

    # ==================== 200741 ====================
    ('Tottenham', 'Reading'): 36067,             # Source: ESPN [45L7-L8]

    # ==================== 200742 ====================
    ('Aston Villa', 'Everton'): 36407,           # Source: FBref [46L11]

    # ==================== 200746 ====================
    ('Man City', 'Charlton'): 41424,             # Source: ESPN [47L8]

    # ==================== 200747 ====================
    ('Wigan', 'Bolton'): 18610,                 # Source: sport.de [48L9]
    ('Middlesbrough', 'Watford'): 25534,         # Source: ESPN [49L7]
    ('Blackburn', 'Aston Villa'): 24211,         # Source: ESPN [50L11-L12]

    # ==================== 200749 ====================
    ('Charlton', 'Reading'): 26271,              # Source: encyclopedia.thefreedictionary.com [51L8]
    ('Watford', 'Portsmouth'): 18119,            # Source: ESPN [52L7]
    ('Aston Villa', 'Wigan'): 36407,             # Source: FBref [46L11]

    # ==================== 2007414 ====================
    ('Sheffield', 'West Ham'): 31593,            # Source: sport.de [54L9-L10]

    # ==================== 2007415 ====================
    ('Wigan', 'Tottenham'): 16506,               # Source: thfcdb [55L17]

    # ==================== 2007417 ====================
    ('Arsenal', 'Man City'): 59913,              # Source: FBref [56L7]

    # ==================== 2007421 ====================
    ('Watford', 'Man City'): 18537,              # Source: ESPN [57L7]
    ('Charlton', 'Sheffield'): 27111,            # Source: Wikipedia [58L8]

    # ==================== 2007422 ====================
    ('Aston Villa', 'Portsmouth'): 31745,         # Source: FBref [59L8]

    # ==================== 2007428 ====================
    ('Wigan', 'West Ham'): 24726,                # Source: Wikipedia [60L7-L8]

    # ==================== 20075 ====================
    ('Wigan', 'Middlesbrough'): 21200,           # Source: fussballdaten [61L12-L13]

    # ==================== 200713 ====================
    ('Tottenham', 'Man City'): 35415,            # Source: FBref [62L8]
    ('Bolton', 'Aston Villa'): 26255,            # Source: ESPN [63L8]
    ('Chelsea', 'Everton'): 41818,               # Source: FBref [64L15]
    ('Portsmouth', 'Arsenal'): 20188,            # Source: resultdb [65L7]
}

fill_from_dict(
    df,
    season='0607',
    data=match_attendance_data ,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'Attendance')
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5183          Wigan       Man City  2006     10   21
# 5184        Everton      Sheffield  2006     10   21
# 5185       Charlton        Watford  2006     10   21
# 5186    Aston Villa         Fulham  2006     10   21
# 5187        Chelsea     Portsmouth  2006     10   21
# 5188      Blackburn         Bolton  2006     10   22
# 5189     Man United      Liverpool  2006     10   22
# 5190  Middlesbrough      Newcastle  2006     10   22
# 5191        Reading        Arsenal  2006     10   22
# 5192      Tottenham       West Ham  2006     10   22
# 5193        Watford      Tottenham  2006     10   28
# 5194      Sheffield        Chelsea  2006     10   28
# 5195     Portsmouth        Reading  2006     10   28
# 5196      Liverpool    Aston Villa  2006     10   28
# 5197         Fulham          Wigan  2006     10   28
# 5198         Bolton     Man United  2006     10   28
# 5199        Arsenal        Everton  2006     10   28
# ...

# %%
match_attendance_data = {
    # ==================== 20061021 ====================
    ('Wigan', 'Man City'): 16235,                # Source: sport.de [0L10], 11v11 [0L21-L22]
    ('Everton', 'Sheffield'): 37900,             # Source: sport.de [1L10], Sky Sports [1L13-L14]
    ('Charlton', 'Watford'): 27011,              # Source: ESPN [2L7], 11v11 [2L29]
    ('Aston Villa', 'Fulham'): 30919,            # Source: ESPN [3L6], sport.de [3L13]
    ('Chelsea', 'Portsmouth'): 41838,            # Source: ESPN [4L7], stamford-bridge [4L11]

    # ==================== 20061022 ====================
    ('Blackburn', 'Bolton'): 27662,              # Source: ESPN [5L7], sport.de [5L17]
    ('Man United', 'Liverpool'): 75828,          # Source: ESPN [6L7], sport.de [6L14]
    ('Middlesbrough', 'Newcastle'): 30036,       # Source: FBref [7L9], Sky Sports [7L13]
    ('Reading', 'Arsenal'): 24004,               # Source: ESPN [8L6-L7], sport.de [8L13]
    ('Tottenham', 'West Ham'): 36162,            # Source: ESPN [9L7], 11v11 [9L16]

    # ==================== 20061028 ====================
    ('Watford', 'Tottenham'): 19660,             # Source: sport.de [10L9], Sky Sports [10L13]
    ('Sheffield', 'Chelsea'): 32321,             # Source: ESPN [11L7], sport.de [11L18]
    ('Portsmouth', 'Reading'): 20146,            # Source: sport.de [12L9], Hob Nob Anyone? [12L13]
    ('Liverpool', 'Aston Villa'): 44117,         # Source: ESPN [13L6-L7], LFChistory [13L11]
    ('Fulham', 'Wigan'): 22882,                  # Source: ESPN [14L6], sport.de [14L21]
    ('Bolton', 'Man United'): 27229,             # Source: worldfootball [15L7], ESPN [15L12]
    ('Arsenal', 'Everton'): 60047,               # Source: ESPN [16L6], sport.de [16L16]
    ('Newcastle', 'Charlton'): 48642,            # Source: sport.de [17L14], 11v11 [17L18]
    ('West Ham', 'Blackburn'): 33833,            # Source: ESPN [18L7], sport.de [18L19]
    ('Man City', 'Middlesbrough'): 36720,        # Source: sport.de [19L10], citytilidie [19L14]

    # ==================== 2006114 ====================
    ('Watford', 'Middlesbrough'): 18951,         # Source: Global Sports Archive [20L8], Le Figaro [20L13]
    ('Newcastle', 'Sheffield'): 50188,           # Source: sport.de [21L10], 11v11 [21L14]
    ('Fulham', 'Everton'): 23327,                # Source: Le Figaro [22L7], sport.de [22L19]
    ('Bolton', 'Wigan'): 21255,                  # Source: ESPN [23L7], sport.de [23L13]
    ('Liverpool', 'Reading'): 43741,             # Source: ESPN [24L7], Hob Nob Anyone? [24L17]
    ('Charlton', 'Man City'): 26011,             # Source: ESPN [25L8], Championat [25L21-L22]

    # ==================== 2006115 ====================
    ('Tottenham', 'Chelsea'): 36070,             # Source: ESPN [26L7], stamford-bridge [26L15]
    ('West Ham', 'Arsenal'): 34969,              # Source: ESPN [27L5-L6], sport.de [27L26]
    ('Aston Villa', 'Blackburn'): 30089,         # Source: ESPN [28L8], AVFC History [28L11]

    # ==================== 20061111 ====================
    ('Blackburn', 'Man United'): 26162,          # Source: ESPN [29L8], 11v11 [29L20]
    ('Chelsea', 'Watford'): 41936,              # Source: ESPN [30L6], stamford-bridge [30L11]
    ('Everton', 'Aston Villa'): 36376,           # Source: sport.de [31L10], Sky Sports [31L18]
    ('Man City', 'Newcastle'): 40571,            # Source: ESPN [32L7], sport.de [32L18]
    ('Middlesbrough', 'West Ham'): 25898,        # Source: ESPN [33L6-L7], sport.de [33L14]
    ('Portsmouth', 'Fulham'): 19563,             # Source: Le Figaro [34L17], sport.de [34L21-L22]
    ('Sheffield', 'Bolton'): 28294,              # Source: ESPN [35L7], sport.de [35L14]
    ('Wigan', 'Charlton'): 16572,                # Source: ESPN [36L7], sport.de [36L17]

    # ==================== 20061112 ====================
    ('Arsenal', 'Liverpool'): 60110,             # Source: ESPN [37L6], worldfootball [37L10]
    ('Reading', 'Tottenham'): 24110,             # Source: sport.de [38L9], 11v11 [38L18]

    # ==================== 20061118 ====================
    ('Sheffield', 'Man United'): 32584,          # Source: ESPN [39L7], FBref [39L24]
    ('Portsmouth', 'Watford'): 19728,            # Source: Global Sports Archive [40L8], Le Figaro [40L14]
    ('Reading', 'Charlton'): 24093,              # Source: ESPN [41L7], 11v11 [41L15]
    ('Man City', 'Fulham'): 35776,               # Source: sport.de [42L10], Sky Sports [42L14]
    ('Arsenal', 'Newcastle'): 60058,             # Source: ESPN [43L6], Sky Sports [43L14]
    ('Everton', 'Bolton'): 34417,                # Source: Sky Sports [44L7], Championat [44L16]
    ('Chelsea', 'West Ham'): 41916,              # Source: ESPN [45L7], sport.de [45L17]
    ('Middlesbrough', 'Liverpool'): 31424,       # Source: ESPN [46L7], 11v11 [46L16]

    # ==================== 20061119 ====================
    ('Blackburn', 'Tottenham'): 18083,           # Source: ESPN [47L7], 11v11 [47L16]
    ('Wigan', 'Aston Villa'): 18455,             # Source: sport.de [48L9], 11v11 [48L17]
}


fill_from_dict(
    df,
    season='0607',
    data=match_attendance_data ,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'Attendance')
# Out:
#            HomeTeam       AwayTeam  Year  Month  Day
# 5233         Bolton        Arsenal  2006     11   25
# 5234       Charlton        Everton  2006     11   25
# 5235         Fulham        Reading  2006     11   25
# 5236      Liverpool       Man City  2006     11   25
# 5237       West Ham      Sheffield  2006     11   25
# 5238    Aston Villa  Middlesbrough  2006     11   25
# 5239     Man United        Chelsea  2006     11   26
# 5240      Newcastle     Portsmouth  2006     11   26
# 5241      Tottenham          Wigan  2006     11   26
# 5242        Watford      Sheffield  2006     11   28
# 5245         Fulham        Arsenal  2006     11   29
# 5247     Man United        Everton  2006     11   29
# 5248      Sheffield       Charlton  2006     12    2
# 5249          Wigan      Liverpool  2006     12    2
# 5250        Reading         Bolton  2006     12    2
# 5251  Middlesbrough     Man United  2006     12    2
# 5252      Blackburn         Fulham  2006     12    2
# ...

# %%
match_attendance_data = {
    # ==================== 20061125 ====================
    ('Bolton', 'Arsenal'): 24409,                # Source: ESPN [0L8]
    ('Charlton', 'Everton'): 26435,              # Source: Sky Sports [1L7]
    ('Fulham', 'Reading'): 22673,                # Source: ESPN [2L6]
    ('Liverpool', 'Man City'): 44081,            # Source: ESPN [3L7]
    ('West Ham', 'Sheffield'): 34242,            # Source: FBref [4L31]
    ('Aston Villa', 'Middlesbrough'): 33162,     # Source: ESPN [5L7]

    # ==================== 20061126 ====================
    ('Man United', 'Chelsea'): 75948,            # Source: sport.de [6L10]
    ('Newcastle', 'Portsmouth'): 48743,          # Source: ESPN [7L6]
    ('Tottenham', 'Wigan'): 35205,               # Source: ESPN [8L6]

    # ==================== 20061128 ====================
    ('Watford', 'Sheffield'): 18887,             # Source: Sky Sports [9L8]

    # ==================== 20061129 ====================
    ('Fulham', 'Arsenal'): 24510,                # Source: ESPN [10L6]
    ('Man United', 'Everton'): 75723,            # Source: Sky Sports [11L8]

    # ==================== 2006122 ====================
    ('Sheffield', 'Charlton'): 27368,            # Source: sport.de [12L10]
    ('Wigan', 'Liverpool'): 22089,               # Source: ESPN [13L6]
    ('Reading', 'Bolton'): 23556,                # Source: sport.de [14L9]
    ('Middlesbrough', 'Man United'): 31238,      # Source: Sky Sports [15L8]
    ('Blackburn', 'Fulham'): 16799,              # Source: Sky Sports [16L7]
    ('Portsmouth', 'Aston Villa'): 20042,        # Source: Sky Sports [17L7]
    ('Everton', 'West Ham'): 32968,              # Source: Sky Sports [18L7]
    ('Man City', 'Watford'): 35915,              # Source: Sky Sports [19L7]

    # ==================== 2006125 ====================
    ('Charlton', 'Blackburn'): 23423,            # Source: ESPN [20L6]
    ('Tottenham', 'Middlesbrough'): 34154,       # Source: Sky Sports [21L7]

    # ==================== 2006126 ====================
    ('Newcastle', 'Reading'): 48182,             # Source: Sky Sports [22L7]
    ('West Ham', 'Wigan'): 33805,                # Source: ESPN [23L12-L13]

    # ==================== 2006129 ====================
    ('Watford', 'Reading'): 19223,               # Source: ESPN [24L7]
    ('Tottenham', 'Charlton'): 35565,            # Source: Sky Sports [25L7]
    ('Portsmouth', 'Everton'): 19526,            # Source: Sky Sports [26L7]
    ('Man United', 'Man City'): 75858,           # Source: Sky Sports [27L8]
    ('Liverpool', 'Fulham'): 43189,              # Source: sport.de [28L9]
    ('Bolton', 'West Ham'): 22283,               # Source: sport.de [29L9]
    ('Blackburn', 'Newcastle'): 19225,           # Source: ESPN [30L7]
    ('Middlesbrough', 'Wigan'): 23638,           # Source: FBref [31L7-L8]

    # ==================== 20061211 ====================
    ('Sheffield', 'Aston Villa'): 30957,         # Source: Sky Sports [32L7]

    # ==================== 20061213 ====================
    ('Chelsea', 'Newcastle'): 41945,             # Source: Sky Sports [33L7]
    ('Wigan', 'Arsenal'): 15311,                 # Source: ESPN [34L7]

    # ==================== 20061216 ====================
    ('Wigan', 'Sheffield'): 16322,               # Source: Sky Sports [35L7]
    ('Reading', 'Blackburn'): 23074,             # Source: sport.de [36L9]
    ('Charlton', 'Liverpool'): 27111,            # Source: Sky Sports [37L7]
    ('Aston Villa', 'Bolton'): 27450,            # Source: Sky Sports [38L7]

    # ==================== 20061217 ====================
    ('Man City', 'Tottenham'): 39825,            # Source: Sky Sports [39L8]
    ('West Ham', 'Man United'): 34966,           # Source: sport.de [40L10]

    # ==================== 20061218 ====================
    ('Fulham', 'Middlesbrough'): 17000,          # Source: ESPN [41L6]

}

fill_from_dict(
    df,
    season='0607',
    data=match_attendance_data ,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'Attendance')
# Out:
#            HomeTeam    AwayTeam  Year  Month  Day
# 5283          Wigan     Chelsea  2006     12   23
# 5284        Reading     Everton  2006     12   23
# 5285     Portsmouth   Sheffield  2006     12   23
# 5286      Newcastle   Tottenham  2006     12   23
# 5287       Man City      Bolton  2006     12   23
# 5288      Liverpool     Watford  2006     12   23
# 5289         Fulham    West Ham  2006     12   23
# 5290    Aston Villa  Man United  2006     12   23
# 5292  Middlesbrough    Charlton  2006     12   23
# 5317      Liverpool      Bolton  2007      1    1
# 5318         Fulham     Watford  2007      1    1

# %%
match_attendance_data = {
    # ==================== 20061223（19） ====================
    ('Wigan', 'Chelsea'): 22077,                 # Source: ESPN [0L6-L7], 11v11 [0L11], sport.de [0L24-L25]
    ('Reading', 'Everton'): 24053,               # Source: 11v11 [1L7], Sky Sports [1L19]
    ('Portsmouth', 'Sheffield'): 20164,          # Source: sport.de [2L9], football-lineups [2L12]
    ('Newcastle', 'Tottenham'): 52079,           # Source: ESPN [3L6], 11v11 [3L26]
    ('Man City', 'Bolton'): 40157,               # Source: ESPN [4L6-L7], sport.de [4L17]
    ('Liverpool', 'Watford'): 42807,             # Source: sport.de [5L9], championat [5L13]
    ('Fulham', 'West Ham'): 22452,               # Source: ESPN [6L7], championat [6L33]
    ('Aston Villa', 'Man United'): 42551,        # Source: sport.de [7L9], AVFC History [7L20]
    ('Middlesbrough', 'Charlton'): None,         

    # ==================== 200711（22） ====================
    ('Liverpool', 'Bolton'): 41370,              # Source: sport.de [16L9], Sky Sports [16L17]
    ('Fulham', 'Watford'): 19698,               # Source: ESPN [17L7], sport.de [17L17]
}


fill_from_dict(
    df,
    season='0607',
    data=match_attendance_data ,
    value_col=match_cols,
    inplace=True
)

# %%
null_rows(df, "0607", 'Attendance')
# Out:
#            HomeTeam  AwayTeam  Year  Month  Day
# 5292  Middlesbrough  Charlton  2006     12   23

# %%
match_attendance_data = {
    ('Middlesbrough', 'Charlton'): 32013,               # Source: EPL
}

fill_from_dict(
    df,
    season='0607',
    data=match_attendance_data ,
    value_col=match_cols,
    inplace=True
)

# %%
df.to_csv("Data/Data6.csv", index=False)

# %% [markdown]
# ---
